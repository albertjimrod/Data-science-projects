# %% [markdown]
# ## Profitable App Profiles for the App Store and Google Play Markets
#
# **Context**:
#
# Data analyst working for a company that **only build free apps to download and install** on Android and iOS mobile apps available on Google Play and in the App Store, our main source of revenue consists of in-app ads.
#
# This means that the number of users of our apps determines our revenue for any given app — the more users who see and engage with the ads, the better.
#
# Our goal for this project is to collect and analyze data to understand what type of apps are likely to attract more users.

# %% [markdown]
# ## 2. Opening and Exploring the Data
#
# In the previous step, we outlined that our aim is to help our developers understand what type of apps are likely to attract more users on Google Play and the App Store. To do this, we'll need to collect and analyze data about mobile apps available on Google Play and the App Store.
#
#
#
# Now let's open the two data sets and explore them.

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
        dataset_slice = dataset[start:end]    
        for row in dataset_slice:
            print(row)
            print('\n') # adds a new (empty) line after each row

        if rows_and_columns:
            print('Number of rows:', len(dataset))
            print('Number of columns:', len(dataset[0]))

# %% [markdown]
# #### Instructions
#
# 1. Open the two data sets we mentioned above, and save both as lists of lists.
#
# - The App Store data set is stored in a CSV file named AppleStore.csv, and the Google Play data set is stored in a CSV file named googleplaystore.csv.
#
#
# - Both CSV files can be opened directly in the Jupyter Notebook interface you see on the right of the screen.
#
#
# - If you run into an error named UnicodeDecodeError, add encoding="utf8" to the open() function (for instance, use open('AppleStore.csv', encoding='utf8')).
#
#
# 2. Explore both data sets using the explore_data() function.
#
#
# - Print the first few rows of each data set.
#
#
# - Find the number of rows and columns of each data set (recall that the function assumes the argument for the dataset parameter doesn't have a header row).
#
#
# 3. Print the column names and try to identify the columns that could help us with our analysis. Use the documentation of the data sets if you're having trouble understanding what a column describes. Add a link to the documentation for readers if you think the column names are not descriptive enough.

# %% [markdown]
# #### 1 - Open the two data sets we mentioned above, and save both as lists of lists.

# %%
from csv import reader

# %% [markdown]
# ### from csv import reader

# %%
AppleStore = open('AppleStore.csv', encoding='utf8')
AppleStore = reader(AppleStore)
AppleStore = list(AppleStore)
header_AppleStore = AppleStore[:1]
AppleStore = AppleStore[1:]

# %%
GooglePlay = open('googleplaystore.csv', encoding='utf8')
GooglePlay = reader(GooglePlay)
GooglePlay = list(GooglePlay)
header_GooglePlay = GooglePlay[:1]
GooglePlay = GooglePlay[1:]

# %% [markdown]
# #### 2. Explore both data sets using the explore_data() function.

# %% [markdown]
# #### 2.1 Print the first few rows of each data set.

# %%
explore_data(AppleStore, 0,3)
# Out:
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']

# %%
explore_data(GooglePlay, 0,3)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']

# %% [markdown]
# #### 2.2 Find the number of rows and columns of each data set (recall that the function assumes the argument for the dataset parameter doesn't have a header row).

# %%
row_AppleStore = len(AppleStore)
print(row_AppleStore)
# Out:
# 7197

# %%
columns_AppleStore = len(header_AppleStore[0][:-1])
print(columns_AppleStore)
# Out:
# 15

# %%
row_GooglePlay = len(GooglePlay)
print(row_GooglePlay)
# Out:
# 10841

# %%
columns_GooglePlay = len(header_GooglePlay[0][:-1])
print(columns_GooglePlay)
# Out:
# 12

# %% [markdown]
# #### 3. Print the column names and try to identify the columns that could help us with our analysis

# %%
header_AppleStore
# Out:
# [['id',
#   'track_name',
#   'size_bytes',
#   'currency',
#   'price',
#   'rating_count_tot',
#   'rating_count_ver',
#   'user_rating',
#   'user_rating_ver',
#   'ver',
#   'cont_rating',
#   'prime_genre',
#   'sup_devices.num',
#   'ipadSc_urls.num',
#   'lang.num',
#   'vpp_lic']]

# %% [markdown]
#     Content: appleStore.csv
#
#         "id" : App ID
#      !  "track_name": App Name
#      !  "size_bytes": Size (in Bytes)
#      !  "currency": Currency Type
#      !  "price": Price amount
#      !  "ratingcounttot": User Rating counts (for all version)
#      !  "ratingcountver": User Rating counts (for current version)
#         "user_rating" : Average User Rating value (for all version)
#         "userratingver": Average User Rating value (for current version)
#         "ver" : Latest version code
#         "cont_rating": Content Rating
#      !  "prime_genre": Primary Genre
#         "sup_devices.num": Number of supporting devices
#         "ipadSc_urls.num": Number of screenshots showed for display
#         "lang.num": Number of supported languages
#         "vpp_lic": Vpp Device Based Licensing Enabled

# %%
header_GooglePlay
# Out:
# [['App',
#   'Category',
#   'Rating',
#   'Reviews',
#   'Size',
#   'Installs',
#   'Type',
#   'Price',
#   'Content Rating',
#   'Genres',
#   'Last Updated',
#   'Current Ver',
#   'Android Ver']]

# %% [markdown]
#     Content: googleplaystore.csv
#
#     ! Application name
#     ! Category: Category the app belongs to
#       Rating: Overall user rating of the app (as when scraped)
#     ! Reviews: Number of user reviews for the app (as when scraped)
#       Size: Size of the app (as when scraped)
#     ! Installs: Number of user downloads/installs for the app (as when scraped)
#     ! Type: Paid or Free
#     ! Price: Price of the app (as when scraped)
#       Content Rating: Age group the app is targeted at - Children / Mature 21+ / Adult
#     ! Genres: An app can belong to multiple genres (apart from its main category).For eg
#         a musical family game will belong to

# %% [markdown]
# ## 3. Deleting Wrong Data
#
# In the previous step, we opened the two data sets and performed a brief exploration of the data. Before beginning our analysis, we need to make sure the data we analyze is accurate, otherwise the results of our analysis will be wrong. This means that we need to:
#
# Detect inaccurate data, and correct or remove it.
# Detect duplicate data, and remove the duplicates.
# Recall that at our company, we only build apps that are free to download and install, and that are directed toward an English-speaking audience. This means that we'll need to:
#
# Remove non-English apps like 爱奇艺PPS -《欢乐颂2》电视剧热播.
# Remove apps that aren't free.
# This process of preparing our data for analysis is called data cleaning. Data cleaning is done before the analysis; it includes removing or correcting wrong data, removing duplicate data, and modifying the data to fit the purpose of our analysis.
#
# It's often said that data scientists spend around 80% of their time cleaning data, and only about 20% actually analyzing (cleaned) data. In this project, we'll see that this is not far from the truth.
#
# Let's begin by detecting and deleting wrong data. For this guided project, we'll guide you throughout the entire data cleaning process. In later courses, we'll learn more about data cleaning, and you'll be able to perform data cleaning without any guidance.

# %% [markdown]
# #### Instructions
#
# The Google Play data set has a dedicated discussion section, and we can see that one of the discussions describes an error for a certain row.
#
# - 1 Read the discussion and find out what the index of the row is.
#
# - 2 Print the row at that index to check whether it's indeed incorrect. Take into account the user reporting the error might or might have not removed the header row, so the index number might vary.
#
# - 3 If the row has an error, **remove** the row using the del statement. For instance, to remove the row with the index 149 from a data set data that is stored as a list of list, you can use the code del data[149].
#
# - 4 Make sure you don't run the del statement more than once, otherwise you'll delete more than one row.
#
# - 5 Read the discussion section for the App Store data set, and see whether you can find any reports of wrong data.

# %% [markdown]
# - 2 Print the row at that index to check whether it's indeed incorrect.

# %%
index = 0
for row in GooglePlay:
    long_row = len(row[:-1])
    
    if long_row != columns_GooglePlay:
        
        print("index:",index,'\n',"Application name:",row)
    index +=1
# Out:
# index: 10472
#  Application name: ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']

# %%
del GooglePlay[10472]

# %% [markdown]
# Checking if row has been removed properlly.

# %%
GooglePlay[10472]
# Out:
# ['osmino Wi-Fi: free WiFi',
#  'TOOLS',
#  '4.2',
#  '134203',
#  '4.1M',
#  '10,000,000+',
#  'Free',
#  '0',
#  'Everyone',
#  'Tools',
#  'August 7, 2018',
#  '6.06.14',
#  '4.4 and up']

# %% [markdown]
# ## 4. Removing Duplicate Entries: Part One
#
# In the last step, we started the data cleaning process and deleted a row with incorrect data from the Google Play data set. If you explore the Google Play data set long enough or look at the discussions section, you'll notice some apps have duplicate entries. For instance, Instagram has four entries:

# %%
for app in GooglePlay:
    name = app[0]
    if name == 'Instagram':
        print(app)
# Out:
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577446', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66509917', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']

# %% [markdown]
# In total, there are 1,181 cases where an app occurs more than once:

# %%
unique_apps = []
duplicate_apps = []

for app in GooglePlay:
    name = app[0]
    if name in unique_apps:
        duplicate_apps.append(name)
    else:
        unique_apps.append(name)
        
print('Number of duplicate apps:',len(duplicate_apps))
print('\n')
print('Examples of duplicate apps:', duplicate_apps[:8])
# Out:
# Number of duplicate apps: 1181
#
#
# Examples of duplicate apps: ['Quick PDF Scanner + OCR FREE', 'Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings', 'Box', 'Zenefits', 'Google Ads']

# %% [markdown]
# We don't want to count certain apps **more than once** when we analyze data, so we need to remove the duplicate entries and keep only one entry per app. One thing we could do is remove the duplicate rows randomly, but we could probably find a better way.
#
# If you examine the rows we printed for the Instagram app, **the main difference happens on the fourth position of each row, which corresponds to the number of reviews**.
#
# The different numbers show the data was collected at different times.

# %% [markdown]
# **Instructions**
#
# 1 - Mediante una combinación de narración y código, explique al lector que el conjunto de datos de Google Play tiene entradas duplicadas. Imprime algunas filas duplicadas para confirmarlo.
#
# 2 - Cuenta el número de duplicados utilizando la técnica que aprendimos anteriormente.
#
# 3 - Explica que no vas a eliminar los duplicados al azar. Describe el criterio que vas a utilizar para eliminar los duplicados.
#
# - Ya hemos sugerido un criterio más arriba, pero puedes proponer otro si lo deseas. Asegúrate de apoyar tu criterio con al menos un argumento.

# %% [markdown]
# ## 5. Removing Duplicate Entries: Part Two
#
# En la pantalla anterior, hemos recorrido el conjunto de datos de Google Play y hemos descubierto que hay 1.181 duplicados. Una vez eliminados los duplicados, nos quedarán 9.659 filas:

# %%
print('Longitud esperada', len(GooglePlay) - 1181)
# Out:
# Longitud esperada 9659

# %% [markdown]
# To remove the duplicates, we will:
#
# - Crea un diccionario, donde cada clave del diccionario es un nombre único de aplicación y el valor correspondiente del diccionario es el número más alto de reseñas de esa aplicación.
#
#
# - Utiliza la información almacenada en el diccionario y crea un nuevo conjunto de datos, que sólo tendrá una entrada por app (y para cada app, sólo seleccionaremos la entrada con el mayor número de reseñas).
#
# Para convertir los pasos anteriores en código, necesitaremos utilizar el operador not in. El operador not in es lo contrario del operador in. Por ejemplo, 'z' en ['a', 'b', 'c'] devuelve False porque 'z' no está en ['a', 'b', 'c'], pero 'z' no en ['a', 'b', 'c'] devuelve True porque es cierto que 'z' no está en la lista ['a', 'b', 'c'].

# %% [markdown]
# **Instrucciones**
#
# - 1.Cree un diccionario en el que cada clave sea un nombre de aplicación único y el valor correspondiente del diccionario sea el número máximo de reseñas de esa aplicación.
#
#
# - Comience por crear un diccionario vacío llamado **reviews_max**.
#
#
# - Recorre el conjunto de datos de Google Play (asegúrate de no incluir la fila de la cabecera). Para cada iteración:
#
#
# - Asigna el nombre de la aplicación a una variable llamada **name**.
#
#
# - Convierte el número de reseñas en un **valor flotante**. Asignarlo a una variable llamada **n_reviews**.
#
#
# - Si **name** ya existe como clave en el diccionario  **reviews_max** y  **reviews_max[name] <  n_reviews**, actualiza el número de revisiones para esa entrada en el diccionario  **reviews_max**.
#
#
# - Si el nombre **no está** en el diccionario **reviews_max** como clave, cree una nueva entrada en el diccionario donde la clave sea el nombre de la aplicación y el valor sea el número de revisiones. Asegúrese de no utilizar una cláusula **else** aquí, de lo contrario el número de reseñas se actualizará incorrectamente siempre que **reviews_max[nombre] < n_reviews** se evalúe como False.
#
#
# - Inspeccione el diccionario para asegurarse de que todo ha ido como se esperaba. Mida la longitud del diccionario - recuerde que la longitud esperada es de 9.659 entradas.

# %%
reviews_max = {}

for row in GooglePlay:
    name = row[0]
    n_reviews = float(row[3])
    
    if name in reviews_max and reviews_max[name] < n_reviews:
        reviews_max[name] = n_reviews
    if name is not reviews_max:
        reviews_max[name] = n_reviews
        
print('length of the dictionary:',len(reviews_max))
# Out:
# length of the dictionary: 9659

# %% [markdown]
#
# - 2.Utilice el diccionario que creó anteriormente para eliminar las filas duplicadas:
#
#
# - Comienza creando dos listas vacías: **android_clean** (que almacenará nuestro nuevo conjunto de datos limpiado) y **already_added** (que sólo almacenará los nombres de las aplicaciones).
#
#
# - Recorre el conjunto de datos de Google Play (asegúrate de no incluir la fila de la cabecera) y, en cada iteración:
#
#
# - Asigna el nombre de la aplicación a una variable llamada **name**.
#
#
# - Convierte el número de reseñas en un **valor flotante** y asígnalo a una variable llamada **n_reviews**.
#
#
# - Si **n_revisiones** es el mismo que el número de revisiones máximas de la aplicación **name** (el número se puede encontrar en el diccionario **reviews_max**) y **name** no está ya en la lista **already_added** (lee el cuaderno de soluciones para saber por qué necesitamos esta condición suplementaria):
#
#
# - Anexar la fila completa a la lista **android_clean** (que finalmente será una lista de lista y almacenará nuestro conjunto de datos limpiados).
#
#
# - Anexar el **name** de la aplicación a la lista **already_added** - esto nos ayuda a mantener un seguimiento de las aplicaciones que ya hemos añadido.

# %%
android_clean = []
already_added = []

for row in GooglePlay:
    name = row[0]
    n_reviews = float(row[3])
    
    if n_reviews == reviews_max[name] and name not in already_added:
        android_clean.append(row)
        already_added.append(name)

# %% [markdown]
# - 3.Explora el conjunto de datos **android_clean** para asegurarte de que todo ha ido como se esperaba. El conjunto de datos debería tener 9.659 filas. Los dos pasos anteriores son un poco más complicados, así que asegúrate de utilizar Markdown para explicar a los lectores los pasos que has seguido.

# %%
print('length of the android_clean dictionary:',len(android_clean))
# Out:
# length of the android_clean dictionary: 9659

# %%
android_clean[:2]
# Out:
# [['Photo Editor & Candy Camera & Grid & ScrapBook',
#   'ART_AND_DESIGN',
#   '4.1',
#   '159',
#   '19M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'January 7, 2018',
#   '1.0.0',
#   '4.0.3 and up'],
#  ['U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#   'ART_AND_DESIGN',
#   '4.7',
#   '87510',
#   '8.7M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'August 1, 2018',
#   '1.2.4',
#   '4.0.3 and up']]

# %% [markdown]
# ## 6. Removing Non-English Apps: Part One

# %% [markdown]
# En el paso anterior, hemos conseguido eliminar las entradas de aplicaciones duplicadas en el conjunto de datos de Google Play. No necesitamos hacer lo mismo con los datos de la App Store porque no hay duplicados - puedes comprobarlo tú mismo utilizando **la columna id** (no la columna track_name).
#
# Recuerda que utilizamos el inglés para las aplicaciones que desarrollamos en nuestra empresa, y nos gustaría analizar sólo las aplicaciones dirigidas a un público de habla inglesa. Sin embargo, si exploramos los datos lo suficiente, encontraremos que ambos conjuntos de datos tienen aplicaciones con nombres que sugieren que no están dirigidas a un público de habla inglesa.

# %%
print(AppleStore[813][1])
print(AppleStore[6731][1])
print('\n')
print(android_clean[4412][0])
print(android_clean[7940][0])
# Out:
# 爱奇艺PPS -《欢乐颂2》电视剧热播
# 【脱出ゲーム】絶対に最後までプレイしないで 〜謎解き＆ブロックパズル〜
#
#
# Just a Line - Draw Anywhere, with AR
# DEM DZ

# %% [markdown]
# No nos interesa mantener estas aplicaciones, así que las eliminaremos.
#
# **Una forma de hacerlo es eliminar todas las aplicaciones cuyo nombre contenga un símbolo que no se utilice habitualmente en el texto en inglés**: el texto en inglés suele incluir letras del alfabeto inglés, números compuestos por dígitos del 0 al 9, signos de puntuación (., !, ?, ;) y otros símbolos (+, *, /).
#
# Entre bastidores, cada carácter que utilizamos en una cadena tiene asociado un número correspondiente. Por ejemplo, el número correspondiente del carácter "a" es 97, el del carácter "A" es 65, y el del carácter "爱" es 29.233.
#
# Podemos obtener el número correspondiente de cada carácter utilizando la función incorporada **ord().**

# %%
print(ord('a'))
print(ord('A'))
print(ord('爱'))
print(ord('5'))
print(ord('+'))
# Out:
# 97
# 65
# 29233
# 53
# 43

# %% [markdown]
# Los números correspondientes a los caracteres que utilizamos habitualmente en un texto en inglés están todos en el rango de 0 a 127, según el sistema ASCII (American Standard Code for Information Interchange). Basándonos en este rango de números, podemos construir una función que detecte si un carácter pertenece al conjunto de caracteres comunes del inglés o no.
#
# **Si el número es igual o inferior a 127, el carácter pertenece al conjunto de caracteres ingleses comunes. Si el nombre de una aplicación contiene un carácter mayor que 127, probablemente significa que la aplicación tiene un nombre no inglés.**
#
# **Sin embargo, los nombres de nuestras aplicaciones se almacenan como cadenas, así que ¿cómo podríamos tomar cada carácter individual de una cadena y comprobar su número correspondiente?**
#
# En Python, las cadenas son indexables e iterables, lo que significa que podemos utilizar la indexación para seleccionar un carácter individual, y también podemos iterar sobre la cadena utilizando un bucle for.

# %%
string = 'abc'
print(string[0])
print(string[1])
print(string[2])
# Out:
# a
# b
# c

# %%
for character in string:
    print(character)
# Out:
# a
# b
# c

# %% [markdown]
# Intentemos primero escribir la función de la que hablamos antes, y en la siguiente pantalla eliminaremos las filas correspondientes a las aplicaciones no inglesas.

# %% [markdown]
# Instructions
#
# - 1 Escribe una función que tome una cadena y devuelva False si hay algún carácter en la cadena que no pertenezca al conjunto de caracteres comunes del inglés, en caso contrario devuelve True.
#
#    - Dentro de la función, iterar sobre la cadena de entrada. En cada iteración comprueba si el número asociado al carácter es mayor que 127. Cuando un carácter es mayor que 127, la función debería devolver inmediatamente False - el nombre de la aplicación probablemente no es inglés ya que contiene un carácter que no pertenece al conjunto de caracteres ingleses comunes.
#
#  - Si el bucle termina de ejecutarse sin que se ejecute la declaración de retorno, significa que ningún carácter tenía un número correspondiente superior a 127 - el nombre de la app es probablemente inglés, por lo que las funciones deberían devolver True.

# %%
def english_speak(string):
    for character in string:
        valor_character = ord(character)
        if valor_character > 127:
            return False
        else:
            return True

# %% [markdown]
# - 2 Utilice su función para comprobar si estos nombres de aplicaciones se detectan como ingleses o no ingleses:
#
#  - 'Instagram'
#
#  - '爱奇艺PPS -《欢乐颂2》电视剧热播'
#
#  - 'Docs To Go™ Free Office Suite'
#
#  - 'Instachat 😜'

# %%
english_speak('Instagram')
# Out:
# True

# %%
english_speak('爱奇艺PPS -《欢乐颂2》电视剧热播')
# Out:
# False

# %%
english_speak('Docs To Go™ Free Office Suite')
# Out:
# True

# %%
english_speak('Instachat 😜')
# Out:
# True

# %% [markdown]
# ## 7. Removing Non-English Apps: Part Two

# %% [markdown]
# En la pantalla anterior, escribimos una función que detecta los nombres de aplicaciones no inglesas, pero vimos que la función no podía identificar correctamente ciertos nombres de aplicaciones inglesas como 'Docs To Go™ Free Office Suite' e 'Instachat 😜'. Esto se debe a que los emojis y los caracteres como ™ quedan fuera del rango ASCII y tienen números correspondientes superiores a 127.

# %%
print(ord('™'))
print(ord('😜'))
# Out:
# 8482
# 128540

# %% [markdown]
# Si vamos a utilizar la función que hemos creado, perderemos datos útiles, ya que muchas aplicaciones inglesas se etiquetarán incorrectamente como no inglesas. Para minimizar el impacto de la pérdida de datos, **sólo eliminaremos una aplicación si su nombre tiene más de tres caracteres con los números correspondientes fuera del rango ASCII**. Esto significa que todas las aplicaciones inglesas con hasta tres emoji u otros caracteres especiales seguirán siendo etiquetadas como inglesas. Nuestra función de filtrado aún no es perfecta, pero debería ser bastante eficaz.
#
# Vamos a editar la función que creamos en la pantalla anterior y a utilizarla para filtrar las aplicaciones no inglesas.

# %% [markdown]
# **Instructions**
#
# - 1. Cambie la función que creó en la pantalla anterior. **Si la cadena de entrada tiene más de tres caracteres que caen fuera del rango ASCII (0 - 127), entonces la función debería devolver False (identificar la cadena como no inglesa), de lo contrario debería devolver True.**

# %%
def english_speak(cadena):
    non_validchar = []
    for character in cadena:
        valor_character = ord(character)
        if valor_character > 127:
            non_validchar.append(valor_character)
    if len(non_validchar) >= 3:
        return False
    else:
        return True

# %% [markdown]
# - 2. Utiliza la nueva función para comprobar si estos nombres de app se detectan como ingleses o no ingleses:
#
#     -  'Docs To Go™ Free Office Suite'
#     -  'Instachat 😜'
#     -  '爱奇艺PPS -《欢乐颂2》电视剧热播'

# %%
english_speak('Docs To Go™ Free Office Suite')
# Out:
# True

# %%
english_speak('Instachat 😜')
# Out:
# True

# %%
english_speak('爱奇艺PPS -《欢乐颂2》电视剧热播')
# Out:
# False

# %%
english_speak('Instachat 😜 😜 😜')
# Out:
# False

# %%
english_speak('Instachat 😜 😜 😜')
# Out:
# False

# %%
print(ord('😜'))
# Out:
# 128540

# %%
english_speak('insta 😜😜😜😜😜')
# Out:
# False

# %% [markdown]
# - 3. Utiliza la nueva función para filtrar las aplicaciones no inglesas de ambos conjuntos de datos. Haz un bucle en cada conjunto de datos. Si el nombre de una aplicación se identifica como inglés, añade la fila completa a una lista separada.

# %%
# AppleStore 1
# android_clean 0

list_AppleStore = []

for row in AppleStore:
    nombre = row[1]
    if english_speak(nombre):
        list_AppleStore.append(row)
    else:
        pass
    
list_android_clean = []

for row in android_clean:
    nombre = row[0]
    if english_speak(nombre):
        list_android_clean.append(row)
    else:
        pass

# %% [markdown]
# ----

# %% [markdown]
# ### IMPORTANTE
#
# Cuando intentaba hacer una funcion para que funcionase con los dos conjuntos de datos, intentaba sacar por el return el valor de 'row' para que esa salida fuera aprovechada por append y asi hacer que la funcion retornara los valores a append.
#
# La sorpresa ha sido cuando unicamente me daba un valor y lo que he pensado ha sido que unicamente da un valor porque solamente se hace una llamada a la funcion, ,es decir filter_app funciona correctamente pero como la llamo desde:
#
# - **xxx.append(filter_app(dataset, 1))**
#
# como resultado solo hace una iteracion.
#
# Esto debo de comentarlo en el foro.

# %% [markdown]
# def filter_app(dataset = True, columna = True):
#     for row in dataset:
#         nombre = row[columna]
#         if english_speak(nombre):
#             return row
#         else:
#             pass

# %% [markdown]
# list_AppleStore = []
# list_android_clean = []
#
# resultado_1 = filter_app(AppleStore, 1)
#
# list_AppleStore.append(resultado_1)
# len(list_AppleStore)

# %% [markdown]
# ----

# %% [markdown]
# - 4. Explore los conjuntos de datos y vea cuántas filas le quedan para cada conjunto de datos.

# %%
list_AppleStore[:1]
# Out:
# [['284882215',
#   'Facebook',
#   '389879808',
#   'USD',
#   '0.0',
#   '2974676',
#   '212',
#   '3.5',
#   '3.5',
#   '95.0',
#   '4+',
#   'Social Networking',
#   '37',
#   '1',
#   '29',
#   '1']]

# %%
len(list_AppleStore)
# Out:
# 6155

# %%
len(list_android_clean)
# Out:
# 9597

# %% [markdown]
# ## 8. Isolating the Free Apps
#
# Hasta ahora, en el proceso de limpieza de datos, hemos
#
# - eliminado los datos inexactos
#
# - eliminado entradas de aplicaciones duplicadas.
#
# - eliminado las aplicaciones que no están en inglés.
#
# Como mencionamos en la introducción, sólo creamos aplicaciones que se pueden descargar e instalar de forma gratuita, y nuestra principal fuente de ingresos consiste en los anuncios dentro de la aplicación.
#
# **Nuestros conjuntos de datos contienen aplicaciones gratuitas y no gratuitas; tendremos que aislar sólo las aplicaciones gratuitas para nuestro análisis.**
#
# Aislar las aplicaciones gratuitas será nuestro último paso en el proceso de limpieza de datos. En la siguiente pantalla, vamos a empezar a analizar los datos.

# %% [markdown]
# **Instructions**
#
# 1 Recorre cada conjunto de datos para aislar las aplicaciones gratuitas en listas separadas.
#
# - Asegúrate de identificar correctamente las columnas que describen el precio de la aplicación.
#
# - Los precios aparecen como cadenas ('0', 0,99 dólares, 2,99 dólares, etc.), así que asegúrate de que no estás comprobando un entero o un flotante en tus declaraciones condicionales.
#
#
# 2 Después de aislar las aplicaciones gratuitas, comprueba la longitud de cada conjunto de datos para ver cuántas aplicaciones te quedan.

# %%
free_AppleStore = [] # 7

for row in list_AppleStore:
    precio = row[4]
 
    if precio == '0.0' or precio == '0':
        free_AppleStore.append(row)
    else:
        pass
    
len(free_AppleStore)
# Out:
# 3203

# %%
free_android_clean = [] 

for row in list_android_clean:
    precio = row[7]
    if precio == '0.0' or precio == '0':
        free_android_clean.append(row)
    else:
        pass
    
len(free_android_clean)
# Out:
# 8848

# %% [markdown]
# ## 9. Most Common Apps by Genre: Part One
#
# Hasta ahora, hemos dedicado una buena cantidad de tiempo a la limpieza de datos, y:
#
# - Eliminado los datos inexactos
# - Eliminado entradas de aplicaciones duplicadas
# - Eliminado las aplicaciones que no están en inglés.
# - Aislado las aplicaciones gratuitas
#
# Como mencionamos en la introducción, nuestro objetivo es determinar los tipos de aplicaciones que probablemente atraigan a más usuarios, ya que nuestros ingresos están muy influidos por el número de personas que utilizan nuestras aplicaciones.
#
# Para minimizar los riesgos y los gastos generales, nuestra estrategia de validación de una idea de aplicación consta de tres pasos:
#
# 1 Crear una versión mínima de la aplicación para Android y añadirla a Google Play.
#
# 2 Si la aplicación tiene una buena respuesta de los usuarios, la desarrollamos más.
#
# 3 Si la aplicación es rentable después de seis meses, construimos una versión de la aplicación para iOS y la añadimos a la App Store.
#
# Como nuestro objetivo final es añadir la aplicación tanto en Google Play como en la App Store, tenemos que encontrar perfiles de aplicaciones que tengan éxito en ambos mercados. Por ejemplo, un perfil que funcione bien en ambos mercados podría ser una aplicación de productividad que haga uso de la gamificación.
#
# Comencemos el análisis por tener una idea de cuáles son los géneros más comunes para cada mercado. Para ello, tendremos que construir tablas de frecuencia para algunas columnas de nuestros conjuntos de datos.

# %% [markdown]
# **Intruccciones:**
#
# 1 Dar a los lectores más contexto sobre por qué queremos encontrar un perfil de aplicación que se adapte tanto a la App Store como a Google Play. Explica nuestra estrategia de validación para una idea de aplicación.
#
# 2 Inspecciona ambos conjuntos de datos e identifica las columnas que podrías utilizar para generar tablas de frecuencia y averiguar cuáles son los géneros más comunes en cada mercado.

# %%
header_AppleStore
# Out:
# [['id',
#   'track_name',
#   'size_bytes',
#   'currency',
#   'price',
#   'rating_count_tot',
#   'rating_count_ver',
#   'user_rating',
#   'user_rating_ver',
#   'ver',
#   'cont_rating',
#   'prime_genre',
#   'sup_devices.num',
#   'ipadSc_urls.num',
#   'lang.num',
#   'vpp_lic']]

# %%
header_GooglePlay
# Out:
# [['App',
#   'Category',
#   'Rating',
#   'Reviews',
#   'Size',
#   'Installs',
#   'Type',
#   'Price',
#   'Content Rating',
#   'Genres',
#   'Last Updated',
#   'Current Ver',
#   'Android Ver']]

# %% [markdown]
#        "id" : App ID
#      ! si  "track_name": App Name
#      !  "size_bytes": Size (in Bytes)
#      !  "currency": Currency Type
#      !  "price": Price amount
#      !  "ratingcounttot": User Rating counts (for all version)
#      ! si "ratingcountver": User Rating counts (for current version)
#         "user_rating" : Average User Rating value (for all version)
#         "userratingver": Average User Rating value (for current version)
#         "ver" : Latest version code
#         "cont_rating": Content Rating
#      !  "prime_genre": Primary Genre
#         "sup_devices.num": Number of supporting devices
#         "ipadSc_urls.num": Number of screenshots showed for display
#         "lang.num": Number of supported languages
#         "vpp_lic": Vpp Device Based Licensing Enabled
#
#
#
#
#
#      [['App',
#        'Category',
#        'Rating',
#        'Reviews',
#        'Size',
#        'Installs',
#        'Type',
#        'Price',
#        'Content Rating',
#        'Genres',
#        'Last Updated',
#        'Current Ver',
#        'Android Ver']])

# %% [markdown]
# ## 10. Most Common Apps by Genre: Part Two
#
# En la pantalla anterior, vimos nuestra estrategia de validación para una idea de aplicación, y **luego inspeccionamos los conjuntos de datos para identificar las columnas que podrían ser útiles para averiguar cuáles son los géneros más comunes en cada mercado.**
#
# Nuestra conclusión fue:
#
# Necesitaremos construir una tabla de frecuencias para:
#
# - **prime_genre** del conjunto de datos de App Store,
#
# - **columnas Genres y Category** del conjunto de datos de **Google Play**.
#
# Construiremos dos funciones que podemos utilizar para analizar las tablas de frecuencia:
#
# - Una función para generar tablas de frecuencia que muestren porcentajes
#
# - Otra función que podemos utilizar para mostrar los porcentajes en orden descendente
#
# Ya hemos aprendido a generar tablas de frecuencias que muestren porcentajes, y vamos a construir una función para ello en el siguiente ejercicio. Sin embargo, los diccionarios no tienen orden, y será muy difícil analizar las tablas de frecuencia. Necesitaremos construir una segunda función que nos ayude a mostrar las entradas de la tabla de frecuencias en orden descendente.
#
# Para ello, tendremos que hacer uso de la función incorporada **sorted()**. Esta función toma un tipo de datos iterable (como una lista, un diccionario, una tupla, etc.) y devuelve una lista de los elementos de ese iterable ordenados de forma ascendente o descendente (el parámetro inverso controla si el orden es ascendente o descendente).

# %%
a_list = [50,20,100]
print(sorted(a_list))
print(sorted(a_list, reverse = True))
# Out:
# [20, 50, 100]
# [100, 50, 20]

# %% [markdown]
# The sorted() function doesn't work too well with dictionaries because it only considers and returns the dictionary keys.

# %%
freq_table_1 = {'Genre_1': 50,'Genre_3': 20,'Genre_2': 100}
sorted(freq_table_1)
# Out:
# ['Genre_1', 'Genre_2', 'Genre_3']

# %% [markdown]
# Sin embargo, la función sorted() funciona bien si transformamos el diccionario en una lista de tuplas, donde cada tupla contiene una clave del diccionario junto con su correspondiente valor del diccionario. Para que la ordenación funcione correctamente, el valor del diccionario va primero y la clave del diccionario va después:

# %%
freq_table_1 = {'Genre_1': 50,'Genre_3': 20,'Genre_2': 100}
freq_table_1_as_tuple = [(50,'Genre_1'),(20,'Genre_3'),(100, 'Genre_2')]
sorted(freq_table_1_as_tuple)
# Out:
# [(20, 'Genre_3'), (50, 'Genre_1'), (100, 'Genre_2')]

# %% [markdown]
# Esto es un poco exagerado para sólo ordenar un diccionario, pero hay maneras mucho más simples de hacer esto una vez que aprendemos técnicas más avanzadas.
#
# Usando la solución anterior, escribimos una función de ayuda llamada **display_table()**, que podrás combinar con la función que vas a escribir en el siguiente ejercicio. La función display_table() que ves a continuación:
#
# - Toma dos parámetros: **dataset** e **index**. Se espera que el conjunto de datos sea una lista de listas, y que el índice sea un número entero.
#
# - Genera una tabla de frecuencias utilizando la función **freq_table()** (que vas a escribir como ejercicio).
#
# - Transforma la tabla de frecuencias en una lista de tuplas, y luego ordena la lista en orden descendente.
#
# - Imprime las entradas de la tabla de frecuencias en orden descendente.
#
# def display_table(dataset, index):
#     table = freq_table(dataset, index)
#     table_display = []
#     for key in table:
#         key_val_as_tuple = (table[key], key)
#         table_display.append(key_val_as_tuple)
#
#     table_sorted = sorted(table_display, reverse = True)
#     for entry in table_sorted:
#         print(entry[1], ':', entry[0])

# %% [markdown]
# Creemos ahora una función para generar tablas de frecuencias, y utilicémosla en combinación con la función display_table().

# %% [markdown]
# **Instrucciones**
#
# 1 Cree una función llamada **freq_table()** que reciba dos entradas: **dataset** (que se espera que sea una lista de listas) e **index** (que se espera que sea un número entero).
#
# - La función debe devolver la tabla de frecuencias (como un diccionario) para cualquier columna que queramos. Las frecuencias también deben expresarse como porcentajes.
#
# - Ya aprendimos a construir tablas de frecuencias en la misión sobre diccionarios.
#
# 2 Copie la función **display_table()** que escribimos anteriormente.
# Utilízala para mostrar la tabla de frecuencias de las columnas:
#
#
#    **prime_genre**
#
#    **Genres**
#
#    **Category**
#
#
# Analizaremos las tablas resultantes en la siguiente pantalla.

# %%
def freq_table(dataset, index):
    table = {}
    total = 0
    
    for row in dataset:
        total +=1
        value = row[index]
        if value in table:
            table[value] +=1
        else:
            table[value] = 1
        
    table_percentages = {}
    for key in table:
        percentage = (table[key] / total ) * 100
        table_percentages[key]=percentage
            
    return table_percentages

# %%
def display_table(dataset, index):
    table = freq_table(dataset, index)
    table_display = []
    for key in table:
        key_val_as_tuple = (table[key], key)
        table_display.append(key_val_as_tuple)

    table_sorted = sorted(table_display, reverse = True)
    for entry in table_sorted:
        print(entry[1], ':', entry[0])

# %%
# free_android_clean free_AppleStore

# %%
display_table(free_AppleStore,11)
# Out:
# Games : 58.25788323446769
# Entertainment : 7.836403371838902
# Photo & Video : 4.995316890415236
# Education : 3.6840462066812365
# Social Networking : 3.3093974399000934
# Shopping : 2.5913206369029034
# Utilities : 2.466437714642523
# Sports : 2.1542304089915705
# Music : 2.0605682172962845
# Health & Fitness : 2.0293474867311896
# Productivity : 1.7483609116453322
# Lifestyle : 1.5610365282547611
# News : 1.3424914142990947
# Travel : 1.248829222603809
# Finance : 1.0927255697783327
# Weather : 0.8741804558226661
# Food & Drink : 0.8117389946924758
# Reference : 0.5307524196066188
# Business : 0.5307524196066188
# Book : 0.3746487667811427
# Navigation : 0.18732438339057134
# Medical : 0.18732438339057134
# Catalogs : 0.1248829222603809

# %%
display_table(free_AppleStore,9)
# Out:
# 1.0 : 3.5279425538557603
# 1.1 : 3.4030596315953794
# 1.2 : 2.5600999063378085
# 1.3 : 1.9981267561660945
# 1.0.1 : 1.5610365282547611
# 1.4 : 1.4673743365594756
# 2.0 : 1.1863877614736185
# 1.0.3 : 1.0302841086481422
# 1.0.2 : 1.0302841086481422
# 1.5 : 0.9678426475179519
# 2.1 : 0.9366219169528567
# 1.1.1 : 0.8741804558226661
# 1.2.1 : 0.8429597252575711
# 1.6 : 0.8117389946924758
# 1.7 : 0.7492975335622853
# 1.0.0 : 0.7492975335622853
# 1.3.0 : 0.6868560724320949
# 1.1.0 : 0.6868560724320949
# 1.2.0 : 0.6556353418669997
# 1.2.2 : 0.6244146113019045
# 1.0.5 : 0.6244146113019045
# 1.8 : 0.5931938807368092
# 1.4.0 : 0.5931938807368092
# 1.1.2 : 0.5931938807368092
# 1.0.4 : 0.5931938807368092
# 2.5 : 0.5307524196066188
# 1.0.6 : 0.5307524196066188
# 2.2 : 0.4995316890415236
# 2.0.1 : 0.4995316890415236
# 1.5.1 : 0.46831095847642834
# 3.0 : 0.43709022791133306
# 2.4 : 0.43709022791133306
# 2.3 : 0.43709022791133306
# 2.1.1 : 0.43709022791133306
# 1.9 : 0.43709022791133306
# 1.5.0 : 0.43709022791133306
# 4.0 : 0.4058694973462379
# 2.0.0 : 0.4058694973462379
# 1.4.1 : 0.4058694973462379
# 1.3.2 : 0.4058694973462379
# 1.1.3 : 0.4058694973462379
# 1.5.2 : 0.3746487667811427
# 1.3.1 : 0.3746487667811427
# 1.7.1 : 0.34342803621604745
# 1.4.2 : 0.34342803621604745
# 1.0.7 : 0.34342803621604745
# 4.0.1 : 0.3122073056509522
# 2.7 : 0.3122073056509522
# 2.2.1 : 0.3122073056509522
# 2.1.0 : 0.3122073056509522
# 1.6.0 : 0.3122073056509522
# 1.1.4 : 0.3122073056509522
# 5.0 : 0.280986575085857
# 4.1.1 : 0.280986575085857
# 3.4 : 0.280986575085857
# 2.2.0 : 0.280986575085857
# 1.2.4 : 0.280986575085857
# 1.12 : 0.280986575085857
# 1.1.5 : 0.280986575085857
# 5.3 : 0.2497658445207618
# 3.2 : 0.2497658445207618
# 3.1.0 : 0.2497658445207618
# 2.4.1 : 0.2497658445207618
# 2.1.2 : 0.2497658445207618
# 2.0.2 : 0.2497658445207618
# 1.6.1 : 0.2497658445207618
# 1.4.3 : 0.2497658445207618
# 1.11 : 0.2497658445207618
# 1.10 : 0.2497658445207618
# 1.0.9 : 0.2497658445207618
# 3.0.0 : 0.21854511395566653
# 2.5.0 : 0.21854511395566653
# 1.8.3 : 0.21854511395566653
# 1.7.2 : 0.21854511395566653
# 1.2.3 : 0.21854511395566653
# 1.0.8 : 0.21854511395566653
# 4.5.1 : 0.18732438339057134
# 4.2 : 0.18732438339057134
# 4.1.2 : 0.18732438339057134
# 4.1.0 : 0.18732438339057134
# 4.1 : 0.18732438339057134
# 3.5 : 0.18732438339057134
# 3.4.1 : 0.18732438339057134
# 3.4.0 : 0.18732438339057134
# 3.1.1 : 0.18732438339057134
# 2.8 : 0.18732438339057134
# 2.6.1 : 0.18732438339057134
# 2.5.1 : 0.18732438339057134
# 2.4.2 : 0.18732438339057134
# 2.0.6 : 0.18732438339057134
# 2.0.3 : 0.18732438339057134
# 1.8.0 : 0.18732438339057134
# 1.7.4 : 0.18732438339057134
# 1.6.2 : 0.18732438339057134
# 1.5.4 : 0.18732438339057134
# 1.4.4 : 0.18732438339057134
# 1.3.4 : 0.18732438339057134
# 1.2.5 : 0.18732438339057134
# 1.03 : 0.18732438339057134
# 5.4.1 : 0.1561036528254761
# 5.4 : 0.1561036528254761
# 4.0.0 : 0.1561036528254761
# 3.6.2 : 0.1561036528254761
# 3.6 : 0.1561036528254761
# 3.5.1 : 0.1561036528254761
# 3.3.1 : 0.1561036528254761
# 3.3.0 : 0.1561036528254761
# 3.2.5 : 0.1561036528254761
# 3.1 : 0.1561036528254761
# 3.0.9 : 0.1561036528254761
# 3.0.5 : 0.1561036528254761
# 3.0.4 : 0.1561036528254761
# 2.9.1 : 0.1561036528254761
# 2.9.0 : 0.1561036528254761
# 2.9 : 0.1561036528254761
# 2.7.1 : 0.1561036528254761
# 2.6 : 0.1561036528254761
# 2.5.4 : 0.1561036528254761
# 2.4.0 : 0.1561036528254761
# 2.3.4 : 0.1561036528254761
# 2.3.2 : 0.1561036528254761
# 2.2.2 : 0.1561036528254761
# 1.9.0 : 0.1561036528254761
# 1.7.3 : 0.1561036528254761
# 1.6.6 : 0.1561036528254761
# 1.4.5 : 0.1561036528254761
# 1.3.7 : 0.1561036528254761
# 1.3.5 : 0.1561036528254761
# 1.23 : 0.1561036528254761
# 1.13 : 0.1561036528254761
# 1.12.1 : 0.1561036528254761
# 1.1.8 : 0.1561036528254761
# 1.04 : 0.1561036528254761
# 1.02 : 0.1561036528254761
# 9.12.0000 : 0.1248829222603809
# 6.0.1 : 0.1248829222603809
# 5.5.0 : 0.1248829222603809
# 5.5 : 0.1248829222603809
# 5.3.1 : 0.1248829222603809
# 5.1.1 : 0.1248829222603809
# 5.1 : 0.1248829222603809
# 5.0.3 : 0.1248829222603809
# 4.2.2 : 0.1248829222603809
# 4.2.0 : 0.1248829222603809
# 3.9.0 : 0.1248829222603809
# 3.8.2 : 0.1248829222603809
# 3.7.2 : 0.1248829222603809
# 3.7.1 : 0.1248829222603809
# 3.5.0 : 0.1248829222603809
# 3.4.3 : 0.1248829222603809
# 3.4.2 : 0.1248829222603809
# 3.2.1 : 0.1248829222603809
# 3.2.0 : 0.1248829222603809
# 3.1.2 : 0.1248829222603809
# 3.0.1 : 0.1248829222603809
# 2.8.2 : 0.1248829222603809
# 2.8.0 : 0.1248829222603809
# 2.6.5 : 0.1248829222603809
# 2.6.3 : 0.1248829222603809
# 2.6.2 : 0.1248829222603809
# 2.3.3 : 0.1248829222603809
# 2.3.1 : 0.1248829222603809
# 2.2.3 : 0.1248829222603809
# 2.10.0 : 0.1248829222603809
# 1.9.2 : 0.1248829222603809
# 1.9.1 : 0.1248829222603809
# 1.8.1 : 0.1248829222603809
# 1.7.0 : 0.1248829222603809
# 1.3.9 : 0.1248829222603809
# 1.3.6 : 0.1248829222603809
# 1.2.6 : 0.1248829222603809
# 1.17 : 0.1248829222603809
# 1.15 : 0.1248829222603809
# 1.10.0 : 0.1248829222603809
# 1.1.7 : 0.1248829222603809
# 1.1.6 : 0.1248829222603809
# 1.01 : 0.1248829222603809
# 1.0.10 : 0.1248829222603809
# 8.6.1 : 0.09366219169528567
# 8.6 : 0.09366219169528567
# 7.5.1 : 0.09366219169528567
# 7.4.0 : 0.09366219169528567
# 7.3.3 : 0.09366219169528567
# 6.3.1 : 0.09366219169528567
# 6.3 : 0.09366219169528567
# 6.2 : 0.09366219169528567
# 5.9.0 : 0.09366219169528567
# 5.7.0 : 0.09366219169528567
# 5.3.0 : 0.09366219169528567
# 5.2.2 : 0.09366219169528567
# 5.2.0 : 0.09366219169528567
# 5.10.0 : 0.09366219169528567
# 5.0.5 : 0.09366219169528567
# 5.0.1 : 0.09366219169528567
# 4.8 : 0.09366219169528567
# 4.6.1 : 0.09366219169528567
# 4.6 : 0.09366219169528567
# 4.4.1 : 0.09366219169528567
# 4.3.2 : 0.09366219169528567
# 4.3.1 : 0.09366219169528567
# 4.3.0 : 0.09366219169528567
# 4.2.5 : 0.09366219169528567
# 4.2.1 : 0.09366219169528567
# 4.11 : 0.09366219169528567
# 4.0.2 : 0.09366219169528567
# 3.9.1 : 0.09366219169528567
# 3.3.3 : 0.09366219169528567
# 3.3 : 0.09366219169528567
# 3.11 : 0.09366219169528567
# 3.1.5 : 0.09366219169528567
# 3.0.2 : 0.09366219169528567
# 2.8.1 : 0.09366219169528567
# 2.7.4 : 0.09366219169528567
# 2.7.0 : 0.09366219169528567
# 2.6.8 : 0.09366219169528567
# 2.6.7 : 0.09366219169528567
# 2.6.0 : 0.09366219169528567
# 2.5.2 : 0.09366219169528567
# 2.4.6 : 0.09366219169528567
# 2.3.0 : 0.09366219169528567
# 2.2.7 : 0.09366219169528567
# 2.2.12 : 0.09366219169528567
# 2.17 : 0.09366219169528567
# 2.16 : 0.09366219169528567
# 2.06 : 0.09366219169528567
# 2.0.8 : 0.09366219169528567
# 1.9.9 : 0.09366219169528567
# 1.9.6 : 0.09366219169528567
# 1.8.8 : 0.09366219169528567
# 1.8.5 : 0.09366219169528567
# 1.8.2 : 0.09366219169528567
# 1.7.5 : 0.09366219169528567
# 1.6.4 : 0.09366219169528567
# 1.55 : 0.09366219169528567
# 1.5.8 : 0.09366219169528567
# 1.5.3 : 0.09366219169528567
# 1.41 : 0.09366219169528567
# 1.4.9 : 0.09366219169528567
# 1.4.6 : 0.09366219169528567
# 1.35 : 0.09366219169528567
# 1.31 : 0.09366219169528567
# 1.3.3 : 0.09366219169528567
# 1.2.13 : 0.09366219169528567
# 1.18.0 : 0.09366219169528567
# 1.16 : 0.09366219169528567
# 1.15.0 : 0.09366219169528567
# 1.12.0 : 0.09366219169528567
# 1.05 : 0.09366219169528567
# 9.8 : 0.06244146113019045
# 9.11.1000 : 0.06244146113019045
# 9.0 : 0.06244146113019045
# 8.9 : 0.06244146113019045
# 8.4.1 : 0.06244146113019045
# 8.4 : 0.06244146113019045
# 8.2.2 : 0.06244146113019045
# 8.1 : 0.06244146113019045
# 7.6 : 0.06244146113019045
# 7.5.2 : 0.06244146113019045
# 7.3.8 : 0.06244146113019045
# 7.2 : 0.06244146113019045
# 7.1.0 : 0.06244146113019045
# 7.0.4 : 0.06244146113019045
# 6.9 : 0.06244146113019045
# 6.6.1 : 0.06244146113019045
# 6.6 : 0.06244146113019045
# 6.5.14 : 0.06244146113019045
# 6.5 : 0.06244146113019045
# 6.4.5 : 0.06244146113019045
# 6.35.1 : 0.06244146113019045
# 6.2.0 : 0.06244146113019045
# 6.1.3 : 0.06244146113019045
# 6.1.1 : 0.06244146113019045
# 6.1 : 0.06244146113019045
# 6.0.5 : 0.06244146113019045
# 6.0.3 : 0.06244146113019045
# 6.0.0 : 0.06244146113019045
# 5.9.4 : 0.06244146113019045
# 5.9.2 : 0.06244146113019045
# 5.8.0 : 0.06244146113019045
# 5.6.0 : 0.06244146113019045
# 5.6 : 0.06244146113019045
# 5.5.3 : 0.06244146113019045
# 5.5.1 : 0.06244146113019045
# 5.4.2 : 0.06244146113019045
# 5.24 : 0.06244146113019045
# 5.2.7 : 0.06244146113019045
# 5.2.3 : 0.06244146113019045
# 5.2.1 : 0.06244146113019045
# 5.2 : 0.06244146113019045
# 5.11.0 : 0.06244146113019045
# 5.1.4 : 0.06244146113019045
# 5.1.0 : 0.06244146113019045
# 5.0.4 : 0.06244146113019045
# 5.0.0 : 0.06244146113019045
# 4.9.705 : 0.06244146113019045
# 4.9 : 0.06244146113019045
# 4.8.0 : 0.06244146113019045
# 4.6.7 : 0.06244146113019045
# 4.6.0 : 0.06244146113019045
# 4.4.0 : 0.06244146113019045
# 4.3 : 0.06244146113019045
# 4.12 : 0.06244146113019045
# 4.10.1 : 0.06244146113019045
# 4.0.9 : 0.06244146113019045
# 4 : 0.06244146113019045
# 3.9.5 : 0.06244146113019045
# 3.8.1 : 0.06244146113019045
# 3.8 : 0.06244146113019045
# 3.6.9 : 0.06244146113019045
# 3.6.3 : 0.06244146113019045
# 3.5.6 : 0.06244146113019045
# 3.5.2 : 0.06244146113019045
# 3.3.8 : 0.06244146113019045
# 3.3.2 : 0.06244146113019045
# 3.2.3 : 0.06244146113019045
# 3.2.2 : 0.06244146113019045
# 3.17 : 0.06244146113019045
# 3.16.0 : 0.06244146113019045
# 3.15.0 : 0.06244146113019045
# 3.15 : 0.06244146113019045
# 3.1.6 : 0.06244146113019045
# 3.01 : 0.06244146113019045
# 3.0.6 : 0.06244146113019045
# 3.0.3 : 0.06244146113019045
# 3 : 0.06244146113019045
# 27.0 : 0.06244146113019045
# 2.9.8 : 0.06244146113019045
# 2.9.3 : 0.06244146113019045
# 2.7.2 : 0.06244146113019045
# 2.6.6 : 0.06244146113019045
# 2.6.4 : 0.06244146113019045
# 2.5.3 : 0.06244146113019045
# 2.4.5 : 0.06244146113019045
# 2.23 : 0.06244146113019045
# 2.22.0 : 0.06244146113019045
# 2.21.0 : 0.06244146113019045
# 2.21 : 0.06244146113019045
# 2.2.4 : 0.06244146113019045
# 2.16.6 : 0.06244146113019045
# 2.16.1 : 0.06244146113019045
# 2.13.0 : 0.06244146113019045
# 2.11 : 0.06244146113019045
# 2.10.1 : 0.06244146113019045
# 2.10 : 0.06244146113019045
# 2.1.5 : 0.06244146113019045
# 2.0.7 : 0.06244146113019045
# 2.0.5 : 0.06244146113019045
# 2 : 0.06244146113019045
# 16.1 : 0.06244146113019045
# 12.0 : 0.06244146113019045
# 11.0 : 0.06244146113019045
# 10.2.2 : 0.06244146113019045
# 1.96 : 0.06244146113019045
# 1.9.5 : 0.06244146113019045
# 1.9.4 : 0.06244146113019045
# 1.8.7 : 0.06244146113019045
# 1.71 : 0.06244146113019045
# 1.7.8 : 0.06244146113019045
# 1.7.6 : 0.06244146113019045
# 1.6.9 : 0.06244146113019045
# 1.6.3 : 0.06244146113019045
# 1.6.12 : 0.06244146113019045
# 1.5.7 : 0.06244146113019045
# 1.5.6 : 0.06244146113019045
# 1.5.11 : 0.06244146113019045
# 1.5.10 : 0.06244146113019045
# 1.43 : 0.06244146113019045
# 1.4.8 : 0.06244146113019045
# 1.29.1 : 0.06244146113019045
# 1.26 : 0.06244146113019045
# 1.21.1 : 0.06244146113019045
# 1.2017.20204 : 0.06244146113019045
# 1.2.17 : 0.06244146113019045
# 1.19.0 : 0.06244146113019045
# 1.19 : 0.06244146113019045
# 1.18 : 0.06244146113019045
# 1.16.0 : 0.06244146113019045
# 1.14.0 : 0.06244146113019045
# 1.111 : 0.06244146113019045
# 1.11.3 : 0.06244146113019045
# 1.11.0 : 0.06244146113019045
# 1.1.11 : 0.06244146113019045
# 1.09 : 0.06244146113019045
# 1.0.32 : 0.06244146113019045
# 1.0.26 : 0.06244146113019045
# 1.0.24 : 0.06244146113019045
# 1.0.23 : 0.06244146113019045
# 1.0.20 : 0.06244146113019045
# 1.0.14 : 0.06244146113019045
# 0.9 : 0.06244146113019045
# 0.8 : 0.06244146113019045
# v2.2.21 : 0.031220730565095226
# v2.13.9 : 0.031220730565095226
# v1.865 : 0.031220730565095226
# Update 1.1 : 0.031220730565095226
# 95.0 : 0.031220730565095226
# 9.8.5 : 0.031220730565095226
# 9.5.1 : 0.031220730565095226
# 9.5 : 0.031220730565095226
# 9.25 : 0.031220730565095226
# 9.24.12 : 0.031220730565095226
# 9.21.3 : 0.031220730565095226
# 9.2.2 : 0.031220730565095226
# 9.2.1 : 0.031220730565095226
# 9.13.0 : 0.031220730565095226
# 9.12.0002 : 0.031220730565095226
# 9.12.0001 : 0.031220730565095226
# 9.10.0 : 0.031220730565095226
# 9.1.5 : 0.031220730565095226
# 9.1.32 : 0.031220730565095226
# 9.1.10 : 0.031220730565095226
# 9.1.0 : 0.031220730565095226
# 9.0.701 : 0.031220730565095226
# 9.0.0 : 0.031220730565095226
# 8.9.6 : 0.031220730565095226
# 8.9.1423 : 0.031220730565095226
# 8.70 : 0.031220730565095226
# 8.5.6 : 0.031220730565095226
# 8.5.1 : 0.031220730565095226
# 8.5.0 : 0.031220730565095226
# 8.4.3 : 0.031220730565095226
# 8.3.17 : 0.031220730565095226
# 8.3.1 : 0.031220730565095226
# 8.3.0 : 0.031220730565095226
# 8.21.0 : 0.031220730565095226
# 8.2.3 : 0.031220730565095226
# 8.2.19371 : 0.031220730565095226
# 8.19.2 : 0.031220730565095226
# 8.16 : 0.031220730565095226
# 8.11 : 0.031220730565095226
# 8.0.6 : 0.031220730565095226
# 8.0.353 : 0.031220730565095226
# 8.0.263 : 0.031220730565095226
# 8.0.2 : 0.031220730565095226
# 8.0.12 : 0.031220730565095226
# 8.0.0 : 0.031220730565095226
# 7.91 : 0.031220730565095226
# 7.8.5 : 0.031220730565095226
# 7.8.2 : 0.031220730565095226
# 7.8.0 : 0.031220730565095226
# 7.7.0 : 0.031220730565095226
# 7.50 : 0.031220730565095226
# 7.5.8 : 0.031220730565095226
# 7.5.0 : 0.031220730565095226
# 7.5 : 0.031220730565095226
# 7.4.57 : 0.031220730565095226
# 7.4.3 : 0.031220730565095226
# 7.32.3 : 0.031220730565095226
# 7.3.11 : 0.031220730565095226
# 7.3.0 : 0.031220730565095226
# 7.3 : 0.031220730565095226
# 7.22 : 0.031220730565095226
# 7.2.8 : 0.031220730565095226
# 7.2.1 : 0.031220730565095226
# 7.2.0 : 0.031220730565095226
# 7.19.46 : 0.031220730565095226
# 7.16 : 0.031220730565095226
# 7.12.17 : 0.031220730565095226
# 7.11.0 : 0.031220730565095226
# 7.11 : 0.031220730565095226
# 7.10.1 : 0.031220730565095226
# 7.1.6 : 0.031220730565095226
# 7.1.4 : 0.031220730565095226
# 7.1.3 : 0.031220730565095226
# 7.0.84 : 0.031220730565095226
# 7.0.57 : 0.031220730565095226
# 7.0.3 : 0.031220730565095226
# 7.0.2 : 0.031220730565095226
# 7.0.1 : 0.031220730565095226
# 7.0.0 : 0.031220730565095226
# 62.20.102 : 0.031220730565095226
# 6.9.0 : 0.031220730565095226
# 6.80 : 0.031220730565095226
# 6.8.9 : 0.031220730565095226
# 6.8.4 : 0.031220730565095226
# 6.79.1 : 0.031220730565095226
# 6.7.0 : 0.031220730565095226
# 6.6.3 : 0.031220730565095226
# 6.6.0 : 0.031220730565095226
# 6.52 : 0.031220730565095226
# 6.50.110 : 0.031220730565095226
# 6.50.10 : 0.031220730565095226
# 6.5.8 : 0.031220730565095226
# 6.5.7 : 0.031220730565095226
# 6.5.3 : 0.031220730565095226
# 6.5.2 : 0.031220730565095226
# 6.5.1 : 0.031220730565095226
# 6.5.0 : 0.031220730565095226
# 6.4.0 : 0.031220730565095226
# 6.4 : 0.031220730565095226
# 6.3.5 : 0.031220730565095226
# 6.3.1519 : 0.031220730565095226
# 6.3.0 : 0.031220730565095226
# 6.26 : 0.031220730565095226
# 6.20 : 0.031220730565095226
# 6.2.3 : 0.031220730565095226
# 6.2.1 : 0.031220730565095226
# 6.19.0 : 0.031220730565095226
# 6.12.0 : 0.031220730565095226
# 6.1.80 : 0.031220730565095226
# 6.1.5 : 0.031220730565095226
# 6.1.13 : 0.031220730565095226
# 6.1.0 : 0.031220730565095226
# 6.0.8 : 0.031220730565095226
# 6.0.2 : 0.031220730565095226
# 6.0 : 0.031220730565095226
# 6 : 0.031220730565095226
# 58.0.3029.113 : 0.031220730565095226
# 54 : 0.031220730565095226
# 50.2 : 0.031220730565095226
# 5.90 : 0.031220730565095226
# 5.9.3 : 0.031220730565095226
# 5.9.1 : 0.031220730565095226
# 5.9 : 0.031220730565095226
# 5.8.8 : 0.031220730565095226
# 5.8.6 : 0.031220730565095226
# 5.8.5 : 0.031220730565095226
# 5.8.2 : 0.031220730565095226
# 5.8.1 : 0.031220730565095226
# 5.8 : 0.031220730565095226
# 5.72 : 0.031220730565095226
# 5.7.6 : 0.031220730565095226
# 5.7.5 : 0.031220730565095226
# 5.7.3 : 0.031220730565095226
# 5.7.2 : 0.031220730565095226
# 5.7.1150 : 0.031220730565095226
# 5.7.1 : 0.031220730565095226
# 5.7 : 0.031220730565095226
# 5.6.15 : 0.031220730565095226
# 5.5.2 : 0.031220730565095226
# 5.5.101 : 0.031220730565095226
# 5.4.4 : 0.031220730565095226
# 5.4.0 : 0.031220730565095226
# 5.35 : 0.031220730565095226
# 5.29.0 : 0.031220730565095226
# 5.25 : 0.031220730565095226
# 5.24.1 : 0.031220730565095226
# 5.21.1 : 0.031220730565095226
# 5.20.1 : 0.031220730565095226
# 5.20.0 : 0.031220730565095226
# 5.2.6 : 0.031220730565095226
# 5.2.4 : 0.031220730565095226
# 5.19.1 : 0.031220730565095226
# 5.19.0 : 0.031220730565095226
# 5.17.4 : 0.031220730565095226
# 5.16 : 0.031220730565095226
# 5.12.1 : 0.031220730565095226
# 5.12 : 0.031220730565095226
# 5.11 : 0.031220730565095226
# 5.10.3 : 0.031220730565095226
# 5.10 : 0.031220730565095226
# 5.1.3 : 0.031220730565095226
# 5.1.10 : 0.031220730565095226
# 5.01 : 0.031220730565095226
# 5.0.34 : 0.031220730565095226
# 5.0.25 : 0.031220730565095226
# 5.0.170507 : 0.031220730565095226
# 5.0.14 : 0.031220730565095226
# 5.0.11 : 0.031220730565095226
# 5 : 0.031220730565095226
# 43.0.1 : 0.031220730565095226
# 4.99.6 : 0.031220730565095226
# 4.981 : 0.031220730565095226
# 4.98.98 : 0.031220730565095226
# 4.96.1 : 0.031220730565095226
# 4.9.6 : 0.031220730565095226
# 4.9.2 : 0.031220730565095226
# 4.8.4 : 0.031220730565095226
# 4.8.3 : 0.031220730565095226
# 4.8.1 : 0.031220730565095226
# 4.7.2 : 0.031220730565095226
# 4.7 : 0.031220730565095226
# 4.66 : 0.031220730565095226
# 4.6.8 : 0.031220730565095226
# 4.6.6 : 0.031220730565095226
# 4.6.3 : 0.031220730565095226
# 4.57.1 : 0.031220730565095226
# 4.50.17 : 0.031220730565095226
# 4.5.7 : 0.031220730565095226
# 4.5.3 : 0.031220730565095226
# 4.45 : 0.031220730565095226
# 4.420 : 0.031220730565095226
# 4.40 : 0.031220730565095226
# 4.4.9 : 0.031220730565095226
# 4.4.6.1 : 0.031220730565095226
# 4.4.5 : 0.031220730565095226
# 4.4 : 0.031220730565095226
# 4.39 : 0.031220730565095226
# 4.33.3 : 0.031220730565095226
# 4.31.1 : 0.031220730565095226
# 4.30.5 : 0.031220730565095226
# 4.30 : 0.031220730565095226
# 4.3.9 : 0.031220730565095226
# 4.3.7 : 0.031220730565095226
# 4.3.5 : 0.031220730565095226
# 4.3.41 : 0.031220730565095226
# 4.3.3 : 0.031220730565095226
# 4.27.0 : 0.031220730565095226
# 4.25 : 0.031220730565095226
# 4.24.2 : 0.031220730565095226
# 4.24 : 0.031220730565095226
# 4.23 : 0.031220730565095226
# 4.22.260026988 : 0.031220730565095226
# 4.21 : 0.031220730565095226
# 4.2017.17212 : 0.031220730565095226
# 4.20.9 : 0.031220730565095226
# 4.2.7 : 0.031220730565095226
# 4.2.3 : 0.031220730565095226
# 4.2.11 : 0.031220730565095226
# 4.18.1 : 0.031220730565095226
# 4.169 : 0.031220730565095226
# 4.16.1 : 0.031220730565095226
# 4.15.0 : 0.031220730565095226
# 4.14.3 : 0.031220730565095226
# 4.14.1 : 0.031220730565095226
# 4.13.2 : 0.031220730565095226
# 4.12.23 : 0.031220730565095226
# 4.12.0 : 0.031220730565095226
# 4.11.2 : 0.031220730565095226
# 4.11.1 : 0.031220730565095226
# 4.11.0 : 0.031220730565095226
# 4.10.004 : 0.031220730565095226
# 4.10.0 : 0.031220730565095226
# 4.10 : 0.031220730565095226
# 4.1.7 : 0.031220730565095226
# 4.1.5 : 0.031220730565095226
# 4.1.4.1 : 0.031220730565095226
# 4.1.3 : 0.031220730565095226
# 4.1.219400 : 0.031220730565095226
# 4.1.19 : 0.031220730565095226
# 4.1.11 : 0.031220730565095226
# 4.1.10 : 0.031220730565095226
# 4.04 : 0.031220730565095226
# 4.0.8 : 0.031220730565095226
# 4.0.7 : 0.031220730565095226
# 4.0.55 : 0.031220730565095226
# 4.0.5 : 0.031220730565095226
# 4.0.45 : 0.031220730565095226
# 4.0.4 : 0.031220730565095226
# 4.0.3 : 0.031220730565095226
# 4.0.16 : 0.031220730565095226
# 4.0.14 : 0.031220730565095226
# 4.0.127 : 0.031220730565095226
# 4.0.12 : 0.031220730565095226
# 4.0.05066 : 0.031220730565095226
# 38.0 : 0.031220730565095226
# 3348 : 0.031220730565095226
# 31.31.840 : 0.031220730565095226
# 30.125 : 0.031220730565095226
# 3.98 : 0.031220730565095226
# 3.91 : 0.031220730565095226
# 3.901 : 0.031220730565095226
# 3.9.90 : 0.031220730565095226
# 3.9.3 : 0.031220730565095226
# 3.9.21 : 0.031220730565095226
# 3.9.2 : 0.031220730565095226
# 3.9.12 : 0.031220730565095226
# 3.8.7 : 0.031220730565095226
# 3.8.10 : 0.031220730565095226
# 3.735 : 0.031220730565095226
# 3.70.20429 : 0.031220730565095226
# 3.7.5 : 0.031220730565095226
# 3.7.3 : 0.031220730565095226
# 3.7.0 : 0.031220730565095226
# 3.7 : 0.031220730565095226
# 3.620 : 0.031220730565095226
# 3.6.4 : 0.031220730565095226
# 3.6.20 : 0.031220730565095226
# 3.6.0 : 0.031220730565095226
# 3.58 : 0.031220730565095226
# 3.55 : 0.031220730565095226
# 3.52.1 : 0.031220730565095226
# 3.5.4 : 0.031220730565095226
# 3.5.3 : 0.031220730565095226
# 3.5.13 : 0.031220730565095226
# 3.43 : 0.031220730565095226
# 3.4.7 : 0.031220730565095226
# 3.4.176411 : 0.031220730565095226
# 3.4.11 : 0.031220730565095226
# 3.32.162 : 0.031220730565095226
# 3.32.0 : 0.031220730565095226
# 3.31 : 0.031220730565095226
# 3.3.9 : 0.031220730565095226
# 3.3.6 : 0.031220730565095226
# 3.3.4 : 0.031220730565095226
# 3.3.12 : 0.031220730565095226
# 3.26.1007 : 0.031220730565095226
# 3.26.0 : 0.031220730565095226
# 3.25 : 0.031220730565095226
# 3.247.2 : 0.031220730565095226
# 3.22.515 : 0.031220730565095226
# 3.22.510 : 0.031220730565095226
# 3.21 : 0.031220730565095226
# 3.20.6 : 0.031220730565095226
# 3.20.2 : 0.031220730565095226
# 3.20 : 0.031220730565095226
# 3.2.8 : 0.031220730565095226
# 3.2.7 : 0.031220730565095226
# 3.2.16 : 0.031220730565095226
# 3.2.12 : 0.031220730565095226
# 3.2.11 : 0.031220730565095226
# 3.19 : 0.031220730565095226
# 3.18.3 : 0.031220730565095226
# 3.18 : 0.031220730565095226
# 3.17.1 : 0.031220730565095226
# 3.158.1 : 0.031220730565095226
# 3.14.2 : 0.031220730565095226
# 3.14 : 0.031220730565095226
# 3.13.0 : 0.031220730565095226
# 3.12.4 : 0.031220730565095226
# 3.12.2 : 0.031220730565095226
# 3.12.0 : 0.031220730565095226
# 3.11.3 : 0.031220730565095226
# 3.11.25 : 0.031220730565095226
# 3.10.0 : 0.031220730565095226
# 3.10 : 0.031220730565095226
# 3.1.9 : 0.031220730565095226
# 3.1.83 : 0.031220730565095226
# 3.1.3 : 0.031220730565095226
# 3.1.18 : 0.031220730565095226
# 3.1.14 : 0.031220730565095226
# 3.1.11 : 0.031220730565095226
# 3.03 : 0.031220730565095226
# 3.02.25 : 0.031220730565095226
# 3.0.8 : 0.031220730565095226
# 3.0.26 : 0.031220730565095226
# 3.0.20 : 0.031220730565095226
# 3.0.19 : 0.031220730565095226
# 3.0.18 : 0.031220730565095226
# 27.0.84 : 0.031220730565095226
# 26.0 : 0.031220730565095226
# 24.92.0 : 0.031220730565095226
# 24.0 : 0.031220730565095226
# 23.5 : 0.031220730565095226
# 22.00.08 : 0.031220730565095226
# 22 : 0.031220730565095226
# 21.1 : 0.031220730565095226
# 2017.6 : 0.031220730565095226
# 2017.5.1 : 0.031220730565095226
# 2013.4.3 : 0.031220730565095226
# 20.8 : 0.031220730565095226
# 2.972 : 0.031220730565095226
# 2.95 : 0.031220730565095226
# 2.901.17125 : 0.031220730565095226
# 2.9.5 : 0.031220730565095226
# 2.9.4 : 0.031220730565095226
# 2.9.2 : 0.031220730565095226
# 2.80 : 0.031220730565095226
# 2.8.24 : 0.031220730565095226
# 2.8.12 : 0.031220730565095226
# 2.72.16 : 0.031220730565095226
# 2.70 : 0.031220730565095226
# 2.7.9 : 0.031220730565095226
# 2.7.8 : 0.031220730565095226
# 2.7.7 : 0.031220730565095226
# 2.7.6 : 0.031220730565095226
# 2.7.5 : 0.031220730565095226
# 2.7.3 : 0.031220730565095226
# 2.7.13 : 0.031220730565095226
# 2.610 : 0.031220730565095226
# 2.6.9 : 0.031220730565095226
# 2.6.042 : 0.031220730565095226
# 2.6.041 : 0.031220730565095226
# 2.53 : 0.031220730565095226
# 2.50 : 0.031220730565095226
# 2.5.9 : 0.031220730565095226
# 2.5.6 : 0.031220730565095226
# 2.5.59 : 0.031220730565095226
# 2.5.5 : 0.031220730565095226
# 2.5.11 : 0.031220730565095226
# 2.44.2 : 0.031220730565095226
# 2.44.0 : 0.031220730565095226
# 2.43 : 0.031220730565095226
# 2.42.0 : 0.031220730565095226
# 2.40 : 0.031220730565095226
# 2.4.4.1 : 0.031220730565095226
# 2.4.3 : 0.031220730565095226
# 2.4.151 : 0.031220730565095226
# 2.4.11 : 0.031220730565095226
# 2.396 : 0.031220730565095226
# 2.37.6 : 0.031220730565095226
# 2.36 : 0.031220730565095226
# 2.31.0 : 0.031220730565095226
# 2.3.8 : 0.031220730565095226
# 2.3.7804 : 0.031220730565095226
# 2.3.6 : 0.031220730565095226
# 2.3.5 : 0.031220730565095226
# 2.3.3006 : 0.031220730565095226
# 2.293.126451 : 0.031220730565095226
# 2.29.0 : 0.031220730565095226
# 2.282 : 0.031220730565095226
# 2.28.0 : 0.031220730565095226
# 2.27.0 : 0.031220730565095226
# 2.27 : 0.031220730565095226
# 2.26 : 0.031220730565095226
# 2.25 : 0.031220730565095226
# 2.2017.21202 : 0.031220730565095226
# 2.2.9 : 0.031220730565095226
# 2.2.6 : 0.031220730565095226
# 2.2.5 : 0.031220730565095226
# 2.2.22 : 0.031220730565095226
# 2.19.13 : 0.031220730565095226
# 2.18 : 0.031220730565095226
# 2.17.22 : 0.031220730565095226
# 2.17.0 : 0.031220730565095226
# 2.15.2 : 0.031220730565095226
# 2.15.1 : 0.031220730565095226
# 2.14.3 : 0.031220730565095226
# 2.14 : 0.031220730565095226
# 2.13.2 : 0.031220730565095226
# 2.13 : 0.031220730565095226
# 2.12.1 : 0.031220730565095226
# 2.12 : 0.031220730565095226
# 2.11.3 : 0.031220730565095226
# 2.11.1 : 0.031220730565095226
# 2.11.0 : 0.031220730565095226
# 2.10.17 : 0.031220730565095226
# 2.10.14 : 0.031220730565095226
# 2.10.0106 : 0.031220730565095226
# 2.1.9 : 0.031220730565095226
# 2.1.6471 : 0.031220730565095226
# 2.1.3 : 0.031220730565095226
# 2.1.24 : 0.031220730565095226
# 2.1.19 : 0.031220730565095226
# 2.1.12 : 0.031220730565095226
# 2.1.11 : 0.031220730565095226
# 2.09.00 : 0.031220730565095226
# 2.08 : 0.031220730565095226
# 2.032 : 0.031220730565095226
# 2.02 : 0.031220730565095226
# 2.0000 : 0.031220730565095226
# 2.0.9 : 0.031220730565095226
# 2.0.65 : 0.031220730565095226
# 2.0.4 : 0.031220730565095226
# 2.0.2478 : 0.031220730565095226
# 2.0.19 : 0.031220730565095226
# 2.0.13 : 0.031220730565095226
# 2.0.11 : 0.031220730565095226
# 2.0.10 : 0.031220730565095226
# 18.97 : 0.031220730565095226
# 18.32 : 0.031220730565095226
# 1705.522.332 : 0.031220730565095226
# 17.8 : 0.031220730565095226
# 17.7 : 0.031220730565095226
# 17.4 : 0.031220730565095226
# 17.3 : 0.031220730565095226
# 17.22 : 0.031220730565095226
# 17.21 : 0.031220730565095226
# 17.2.4 : 0.031220730565095226
# 17.10 : 0.031220730565095226
# 17.05.23 : 0.031220730565095226
# 17.05.15 : 0.031220730565095226
# 17.05.01 : 0.031220730565095226
# 17.04.00 : 0.031220730565095226
# 17.0.631 : 0.031220730565095226
# 17.0.2 : 0.031220730565095226
# 17.0 : 0.031220730565095226
# 16.2 : 0.031220730565095226
# 16.0.0 : 0.031220730565095226
# 16.0 : 0.031220730565095226
# 150 : 0.031220730565095226
# 15 : 0.031220730565095226
# 14.80.6 : 0.031220730565095226
# 14.4 : 0.031220730565095226
# 14.1.4 : 0.031220730565095226
# 14.0.4 : 0.031220730565095226
# 14.0 : 0.031220730565095226
# 13.7.1 : 0.031220730565095226
# 13.25.0 : 0.031220730565095226
# 13.1.0 : 0.031220730565095226
# 12.8.0 : 0.031220730565095226
# 12.21 : 0.031220730565095226
# 12.1.1.0 : 0.031220730565095226
# 12.1.1 : 0.031220730565095226
# 12.1 : 0.031220730565095226
# 119.0 : 0.031220730565095226
# 11.9 : 0.031220730565095226
# 11.21.0 : 0.031220730565095226
# 11.2 : 0.031220730565095226
# 11.15.0 : 0.031220730565095226
# 11.0.3 : 0.031220730565095226
# 11.0.1 : 0.031220730565095226
# 11 : 0.031220730565095226
# 10.9.2.0 : 0.031220730565095226
# 10.8.0 : 0.031220730565095226
# 10.6.1 : 0.031220730565095226
# 10.5.4 : 0.031220730565095226
# 10.4.5 : 0.031220730565095226
# 10.4.1 : 0.031220730565095226
# 10.3.1 : 0.031220730565095226
# 10.23 : 0.031220730565095226
# 10.18.0 : 0.031220730565095226
# 10.15 : 0.031220730565095226
# 10.12 : 0.031220730565095226
# 10.11.0 : 0.031220730565095226
# 10.1.0 : 0.031220730565095226
# 10.1 : 0.031220730565095226
# 10.0.33 : 0.031220730565095226
# 10.0.15 : 0.031220730565095226
# 10.0.0.984 : 0.031220730565095226
# 1.98 : 0.031220730565095226
# 1.97 : 0.031220730565095226
# 1.966 : 0.031220730565095226
# 1.91.5 : 0.031220730565095226
# 1.91 : 0.031220730565095226
# 1.90 : 0.031220730565095226
# 1.9.83 : 0.031220730565095226
# 1.9.8 : 0.031220730565095226
# 1.9.763 : 0.031220730565095226
# 1.9.7 : 0.031220730565095226
# 1.9.3 : 0.031220730565095226
# 1.9.29 : 0.031220730565095226
# 1.9.28 : 0.031220730565095226
# 1.9.24 : 0.031220730565095226
# 1.9.23 : 0.031220730565095226
# 1.9.22 : 0.031220730565095226
# 1.9.15 : 0.031220730565095226
# 1.9.13 : 0.031220730565095226
# 1.89 : 0.031220730565095226
# 1.86.1 : 0.031220730565095226
# 1.85.1 : 0.031220730565095226
# 1.82 : 0.031220730565095226
# 1.80 : 0.031220730565095226
# 1.8.9 : 0.031220730565095226
# 1.8.6 : 0.031220730565095226
# 1.8.4 : 0.031220730565095226
# 1.8.21 : 0.031220730565095226
# 1.78 : 0.031220730565095226
# 1.75 : 0.031220730565095226
# 1.74 : 0.031220730565095226
# 1.72.1 : 0.031220730565095226
# 1.72 : 0.031220730565095226
# 1.70 : 0.031220730565095226
# 1.7.9 : 0.031220730565095226
# 1.7.248694 : 0.031220730565095226
# 1.7.15 : 0.031220730565095226
# 1.64 : 0.031220730565095226
# 1.62 : 0.031220730565095226
# 1.61 : 0.031220730565095226
# 1.60 : 0.031220730565095226
# 1.6.5 : 0.031220730565095226
# 1.6.401 : 0.031220730565095226
# 1.6.1600 : 0.031220730565095226
# 1.6.1.002 : 0.031220730565095226
# 1.597 : 0.031220730565095226
# 1.59 : 0.031220730565095226
# 1.56.0 : 0.031220730565095226
# 1.52 : 0.031220730565095226
# 1.51 : 0.031220730565095226
# 1.50 : 0.031220730565095226
# 1.5.61 : 0.031220730565095226
# 1.5.5 : 0.031220730565095226
# 1.5.12 : 0.031220730565095226
# 1.48.3 : 0.031220730565095226
# 1.45 : 0.031220730565095226
# 1.44 : 0.031220730565095226
# 1.42.13 : 0.031220730565095226
# 1.42.1 : 0.031220730565095226
# 1.42.0 : 0.031220730565095226
# 1.406 : 0.031220730565095226
# 1.40.23 : 0.031220730565095226
# 1.4.7 : 0.031220730565095226
# 1.4.69 : 0.031220730565095226
# 1.4.44 : 0.031220730565095226
# 1.4.393 : 0.031220730565095226
# 1.4.3673 : 0.031220730565095226
# 1.4.100 : 0.031220730565095226
# 1.4.10 : 0.031220730565095226
# 1.38.1012249 : 0.031220730565095226
# 1.38 : 0.031220730565095226
# 1.37 : 0.031220730565095226
# 1.34.7 : 0.031220730565095226
# 1.34.60 : 0.031220730565095226
# 1.34.3 : 0.031220730565095226
# 1.34 : 0.031220730565095226
# 1.33.134 : 0.031220730565095226
# 1.33.1 : 0.031220730565095226
# 1.33.0 : 0.031220730565095226
# 1.32.3 : 0.031220730565095226
# 1.32.2 : 0.031220730565095226
# 1.31.2 : 0.031220730565095226
# 1.300 : 0.031220730565095226
# 1.30.10 : 0.031220730565095226
# 1.30.0 : 0.031220730565095226
# 1.3.8 : 0.031220730565095226
# 1.3.32 : 0.031220730565095226
# 1.3.205 : 0.031220730565095226
# 1.3.20 : 0.031220730565095226
# 1.3.18 : 0.031220730565095226
# 1.3.170423 : 0.031220730565095226
# 1.3.10 : 0.031220730565095226
# 1.29.0 : 0.031220730565095226
# 1.28.4 : 0.031220730565095226
# 1.28.1 : 0.031220730565095226
# 1.27.1 : 0.031220730565095226
# 1.26.010 : 0.031220730565095226
# 1.25.2500 : 0.031220730565095226
# 1.25.0 : 0.031220730565095226
# 1.25 : 0.031220730565095226
# 1.24.130666 : 0.031220730565095226
# 1.24.0 : 0.031220730565095226
# 1.24 : 0.031220730565095226
# 1.23.905 : 0.031220730565095226
# 1.21.2 : 0.031220730565095226
# 1.21.0 : 0.031220730565095226
# 1.21 : 0.031220730565095226
# 1.2017.20203 : 0.031220730565095226
# 1.20 : 0.031220730565095226
# 1.2.99 : 0.031220730565095226
# 1.2.92 : 0.031220730565095226
# 1.2.7 : 0.031220730565095226
# 1.2.58 : 0.031220730565095226
# 1.2.34 : 0.031220730565095226
# 1.2.25 : 0.031220730565095226
# 1.2.150 : 0.031220730565095226
# 1.2.14 : 0.031220730565095226
# 1.2.12 : 0.031220730565095226
# 1.2.118 : 0.031220730565095226
# 1.2.02 : 0.031220730565095226
# 1.2.008 : 0.031220730565095226
# 1.19.4 : 0.031220730565095226
# 1.19.1 : 0.031220730565095226
# 1.18.1 : 0.031220730565095226
# 1.175 : 0.031220730565095226
# 1.172 : 0.031220730565095226
# 1.171.11 : 0.031220730565095226
# 1.17.6 : 0.031220730565095226
# 1.17.0 : 0.031220730565095226
# 1.16.94 : 0.031220730565095226
# 1.16.9309 : 0.031220730565095226
# 1.16.3 : 0.031220730565095226
# 1.16.1 : 0.031220730565095226
# 1.15.4 : 0.031220730565095226
# 1.14.9 : 0.031220730565095226
# 1.14.13 : 0.031220730565095226
# 1.14 : 0.031220730565095226
# 1.130 : 0.031220730565095226
# 1.13.891 : 0.031220730565095226
# 1.13.24 : 0.031220730565095226
# 1.13.14 : 0.031220730565095226
# 1.13.1301 : 0.031220730565095226
# 1.13.1 : 0.031220730565095226
# 1.13.0 : 0.031220730565095226
# 1.127 : 0.031220730565095226
# 1.121 : 0.031220730565095226
# 1.12.6 : 0.031220730565095226
# 1.12.383 : 0.031220730565095226
# 1.12.2 : 0.031220730565095226
# 1.119.0 : 0.031220730565095226
# 1.117 : 0.031220730565095226
# 1.112 : 0.031220730565095226
# 1.11.5 : 0.031220730565095226
# 1.11.4 : 0.031220730565095226
# 1.11.38 : 0.031220730565095226
# 1.11.2 : 0.031220730565095226
# 1.11.1430 : 0.031220730565095226
# 1.11.04 : 0.031220730565095226
# 1.102.1 : 0.031220730565095226
# 1.102 : 0.031220730565095226
# 1.101.0 : 0.031220730565095226
# 1.10.6 : 0.031220730565095226
# 1.10.4 : 0.031220730565095226
# 1.10.3 : 0.031220730565095226
# 1.10.14 : 0.031220730565095226
# 1.10.1 : 0.031220730565095226
# 1.1.9 : 0.031220730565095226
# 1.1.85.1581 : 0.031220730565095226
# 1.1.6.4.3 : 0.031220730565095226
# 1.1.5768 : 0.031220730565095226
# 1.1.55 : 0.031220730565095226
# 1.1.44 : 0.031220730565095226
# 1.1.43 : 0.031220730565095226
# 1.1.25 : 0.031220730565095226
# 1.1.20 : 0.031220730565095226
# 1.1.13 : 0.031220730565095226
# 1.1.122 : 0.031220730565095226
# 1.1.12 : 0.031220730565095226
# 1.07 : 0.031220730565095226
# 1.05.005 : 0.031220730565095226
# 1.025b : 0.031220730565095226
# 1.025 : 0.031220730565095226
# 1.02.51 : 0.031220730565095226
# 1.02.08 : 0.031220730565095226
# 1.00.01 : 0.031220730565095226
# 1.0.97 : 0.031220730565095226
# 1.0.88463 : 0.031220730565095226
# 1.0.833 : 0.031220730565095226
# 1.0.83 : 0.031220730565095226
# 1.0.7541 : 0.031220730565095226
# 1.0.62 : 0.031220730565095226
# 1.0.5761 : 0.031220730565095226
# 1.0.45 : 0.031220730565095226
# 1.0.418 : 0.031220730565095226
# 1.0.37 : 0.031220730565095226
# 1.0.35 : 0.031220730565095226
# 1.0.31 : 0.031220730565095226
# 1.0.27 : 0.031220730565095226
# 1.0.2551 : 0.031220730565095226
# 1.0.243903 : 0.031220730565095226
# 1.0.228 : 0.031220730565095226
# 1.0.226816 : 0.031220730565095226
# 1.0.22 : 0.031220730565095226
# 1.0.205806 : 0.031220730565095226
# 1.0.19 : 0.031220730565095226
# 1.0.15 : 0.031220730565095226
# 1.0.138 : 0.031220730565095226
# 1.0.13 : 0.031220730565095226
# 1.0.12 : 0.031220730565095226
# 1.0.11 : 0.031220730565095226
# 1.0.1.5 : 0.031220730565095226
# 01.19 : 0.031220730565095226
# 01.03.00 : 0.031220730565095226
# 0.93 : 0.031220730565095226
# 0.81 : 0.031220730565095226
# 0.8.8 : 0.031220730565095226
# 0.8.3 : 0.031220730565095226
# 0.8.0 : 0.031220730565095226
# 0.6.41 : 0.031220730565095226
# 0.57.3 : 0.031220730565095226
# 0.5.7961 : 0.031220730565095226
# 0.5.7 : 0.031220730565095226
# 0.4.400 : 0.031220730565095226
# 0.39 : 0.031220730565095226
# 0.3 : 0.031220730565095226
# 0.23.25 : 0.031220730565095226
# 0.2 : 0.031220730565095226
# 0.14.87 : 0.031220730565095226
# 0.13 : 0.031220730565095226
# 0.0.15 : 0.031220730565095226

# %%
display_table(free_AppleStore,1)
# Out:
# VR Roller Coaster : 0.06244146113019045
# Mannequin Challenge : 0.06244146113019045
# 飞猪 : 0.031220730565095226
# 铁路12306 : 0.031220730565095226
# 豆瓣 : 0.031220730565095226
# 花札Online : 0.031220730565095226
# 秒速 : 0.031220730565095226
# 知乎 : 0.031220730565095226
# 机でGOLF : 0.031220730565095226
# 指神 : 0.031220730565095226
# 天猫HD : 0.031220730565095226
# 京东 HD : 0.031220730565095226
# ▻Sudoku : 0.031220730565095226
# ▻Solitaire : 0.031220730565095226
# ■ Square it! : 0.031220730565095226
# ⋆Solitaire⋆ : 0.031220730565095226
# ⋆Solitaire : 0.031220730565095226
# ∞ Infinity Loop : 0.031220730565095226
# wetter.com : 0.031220730565095226
# vente-privee : 0.031220730565095226
# theSkimm : 0.031220730565095226
# striker – dropping balls : 0.031220730565095226
# splix.io! : 0.031220730565095226
# slither.io : 0.031220730565095226
# skyticket - Reserve Best Valued Air Tickets : 0.031220730565095226
# shopkick - Shopping Rewards & Discounts : 0.031220730565095226
# real happy majiang-all stars majiang,mahjong : 0.031220730565095226
# radio.de - Der Radioplayer : 0.031220730565095226
# ooVoo – Free Video Call, Text and Voice : 0.031220730565095226
# niconico ch : 0.031220730565095226
# niconico : 0.031220730565095226
# n-tv Nachrichten : 0.031220730565095226
# myChevrolet : 0.031220730565095226
# myCANAL - la TV by CANAL en direct et replay : 0.031220730565095226
# myAT&T : 0.031220730565095226
# my KONAMI Slots - Vegas Casino Slot Machine Games : 0.031220730565095226
# musical.ly - your video social network : 0.031220730565095226
# minne - shopping handmade item : 0.031220730565095226
# lollicam - photo, video, and selfie camera : 0.031220730565095226
# live.ly - live video streaming : 0.031220730565095226
# letgo: Buy & Sell Second Hand Stuff : 0.031220730565095226
# ipsy - Makeup, subscription and beauty tips : 0.031220730565095226
# intoLive - Custom Live Photos wallpaper maker : 0.031220730565095226
# in-capturing moments in life : 0.031220730565095226
# imo video calls and chat : 0.031220730565095226
# ikouhoushi : 0.031220730565095226
# ibis Paint X - speed painting : 0.031220730565095226
# iWeather - World weather forecast : 0.031220730565095226
# iTunes U : 0.031220730565095226
# iTranslate - Language Translator & Dictionary : 0.031220730565095226
# iSwap Faces LITE : 0.031220730565095226
# iSleeping by iSommeil SARL : 0.031220730565095226
# iSlash Heroes : 0.031220730565095226
# iPlum Business Phone Number for Calling & Texting : 0.031220730565095226
# iPaint uPaint : 0.031220730565095226
# iHeartRadio – Free Music & Radio Stations : 0.031220730565095226
# iGun Pro HD - The Original Gun Application : 0.031220730565095226
# iFunny :) : 0.031220730565095226
# iExit Interstate Exit Guide : 0.031220730565095226
# happn — Dating app — Find and meet your crush : 0.031220730565095226
# gogogo : 0.031220730565095226
# go90 – Stream TV & Live Sports : 0.031220730565095226
# francetv JO – Regarder les Jeux Olympiques de Rio 2016 : 0.031220730565095226
# franceinfo - l'actualité & les élections en direct : 0.031220730565095226
# edjing Mix:DJ turntable to remix and scratch music : 0.031220730565095226
# eHarmony™ Dating App - Meet Singles : 0.031220730565095226
# eBay: Best App to Buy, Sell, Save! Online Shopping : 0.031220730565095226
# eBay Kleinanzeigen - Free. Easy. Local. : 0.031220730565095226
# diep.io : 0.031220730565095226
# cute icon&wallpaper dressup - CocoPPa : 0.031220730565095226
# codeSpark Academy with The Foos - coding for kids : 0.031220730565095226
# camera for filter : 0.031220730565095226
# caRRage : 0.031220730565095226
# botman - Real time video chat : 0.031220730565095226
# boohoo.com : 0.031220730565095226
# bit-tube - Live Stream Video Chat : 0.031220730565095226
# ameli, l'Assurance Maladie : 0.031220730565095226
# airweave sleep analysis : 0.031220730565095226
# adidas Confirmed : 0.031220730565095226
# aa : 0.031220730565095226
# a. - Physical Simulation Puzzle Game : 0.031220730565095226
# Zootopia Crime Files: Hidden Object : 0.031220730565095226
# Zoopla Property Search -UK Homes for Sale and Rent : 0.031220730565095226
# Zombies Chasing Me : 0.031220730565095226
# Zombie Tsunami : 0.031220730565095226
# Zombie Town Story : 0.031220730565095226
# Zombie Highway 2 : 0.031220730565095226
# Zombie Frontier 3 – Top Zombie Shooting Game : 0.031220730565095226
# Zombie Catchers : 0.031220730565095226
# Zombie Castaways : 0.031220730565095226
# Zombie Anarchy: Survival Strategy Game : 0.031220730565095226
# Zillow Real Estate - Homes for Sale & for Rent : 0.031220730565095226
# ZigZag : 0.031220730565095226
# Zig Zag Boom : 0.031220730565095226
# Zenly - Locate your friends in realtime : 0.031220730565095226
# ZenDots 2 - One Dot’s Journey : 0.031220730565095226
# Zen Pinball : 0.031220730565095226
# Zen : 0.031220730565095226
# Zappos: shop shoes & clothes, fast free shipping : 0.031220730565095226
# Zap Zombies : 0.031220730565095226
# Zaim : 0.031220730565095226
# ZaZa Remote-Universal Remote Control : 0.031220730565095226
# ZEDGE™ Wallpapers : 0.031220730565095226
# ZEDGE™ Ringtones : 0.031220730565095226
# ZDFmediathek : 0.031220730565095226
# ZARA : 0.031220730565095226
# ZAGA : 0.031220730565095226
# Z Buster : 0.031220730565095226
# Yurekuru Call : 0.031220730565095226
# Yurei Ninja : 0.031220730565095226
# Yup - Homework Help with Math & Science Tutors : 0.031220730565095226
# Yummy Birthday - Party Food Maker : 0.031220730565095226
# Yu-Gi-Oh! Duel Links : 0.031220730565095226
# Youmiam : 0.031220730565095226
# Youku HD : 0.031220730565095226
# YouTurbo : 0.031220730565095226
# YouTube Music : 0.031220730565095226
# YouTube Kids : 0.031220730565095226
# YouTube - Watch Videos, Music, and Live Streams : 0.031220730565095226
# YouNow: Live Stream Video Chat : 0.031220730565095226
# YouCam Perfect - Photo & Selfie Editor : 0.031220730565095226
# YouCam Makeup: Magic Makeup Selfie Cam : 0.031220730565095226
# YouCam Fun - Live Selfie Video Filters : 0.031220730565095226
# You Stupid : 0.031220730565095226
# You Doodle - draw on photos & pictures, add text : 0.031220730565095226
# Yoshirt - Design Your Own Custom Tshirt, Tote Bag, Socks and More : 0.031220730565095226
# Yelp - Nearby Restaurants, Shopping & Services : 0.031220730565095226
# Yellow - Make new friends : 0.031220730565095226
# Yahoo Weather : 0.031220730565095226
# Yahoo Sports - Teams, Scores, News & Highlights : 0.031220730565095226
# Yahoo Mail - Keeps You Organized! : 0.031220730565095226
# Yahoo Fantasy Sports : 0.031220730565095226
# YO-KAI WATCH Wibble Wobble : 0.031220730565095226
# YAZIO – Calorie Counter & Nutrition Tracker : 0.031220730565095226
# YAHTZEE® With Buddies: The Classic Dice Game : 0.031220730565095226
# Xmas Swipe - Christmas Match 3 Puzzle : 0.031220730565095226
# Xbox : 0.031220730565095226
# XFINITY Stream : 0.031220730565095226
# X-War: Clash of Zombies : 0.031220730565095226
# Wrassling : 0.031220730565095226
# Would You Rather? : 0.031220730565095226
# Worm.is: The Game : 0.031220730565095226
# World of Tanks Blitz : 0.031220730565095226
# World of Cubes Survival Craft : 0.031220730565095226
# World Spin - Create & Play : 0.031220730565095226
# World Craft HD : 0.031220730565095226
# World Craft - Epic Dream Island : 0.031220730565095226
# World Chef: Restaurant & Cooking Game : 0.031220730565095226
# Workflow: Powerful Automation Made Simple : 0.031220730565095226
# Words with Friends – Best Word Game : 0.031220730565095226
# Words Crush: Hidden Words! : 0.031220730565095226
# Wordalot – Picture Crossword : 0.031220730565095226
# WordWhizzle Search : 0.031220730565095226
# WordWhizzle : 0.031220730565095226
# WordNerd - The picture puzzle game for word nerds : 0.031220730565095226
# WordBubbles! : 0.031220730565095226
# WordBrain 2 : 0.031220730565095226
# WordBrain : 0.031220730565095226
# Word Trek  - WordTrek Brain game & Word puzzles : 0.031220730565095226
# Word Search Colorful : 0.031220730565095226
# Word Flow Keyboard - GIF, swipe, custom theme : 0.031220730565095226
# Word Cookies! : 0.031220730565095226
# Wooden Block Puzzle - Wood jigsaw fit 1010 matrix : 0.031220730565095226
# Wonderball - One Touch Endless Ball Arcade Action : 0.031220730565095226
# Wonder Tactics : 0.031220730565095226
# Wonder Keyboard: Sound Smart & Funny with AI : 0.031220730565095226
# WoW Legion Companion : 0.031220730565095226
# Wizard of OZ: Magic Match : 0.031220730565095226
# Wizard Swipe : 0.031220730565095226
# Within - VR (Virtual Reality) : 0.031220730565095226
# Wishbone - Compare Anything : 0.031220730565095226
# Wish - Shopping Made Fun : 0.031220730565095226
# Wire de Coins 2 : 0.031220730565095226
# Wire Bounce : 0.031220730565095226
# Winterstate : 0.031220730565095226
# Winter Fugitives 2: Chronicles : 0.031220730565095226
# Win the White House : 0.031220730565095226
# Willy Wonka Slots: Vegas Casino Slot Machines : 0.031220730565095226
# Wild City Rush - Urban Jungle Adventure : 0.031220730565095226
# Why You Lying? : 0.031220730565095226
# Whole Foods Market : 0.031220730565095226
# White Tiles 4: Piano Master (All mini games in 1) : 0.031220730565095226
# White Tiles 2 : Piano Master ( Don't Hit The White Tiles 4 ) - Free Music Game : 0.031220730565095226
# Whisper - Share, Express, Meet : 0.031220730565095226
# Where's My What? Free : 0.031220730565095226
# Where's My Water? 2 : 0.031220730565095226
# Where is Santa Lite - Santa Tracker : 0.031220730565095226
# WhenToPost: Best Time to Post Photos for Instagram : 0.031220730565095226
# When you clear one,million yen CHANCE!! : 0.031220730565095226
# Wheel of Fortune: Game Show Word Puzzles : 0.031220730565095226
# Wheel of Fortune Slots Casino with Vanna White : 0.031220730565095226
# WhatsApp Messenger : 0.031220730565095226
# Whataburger : 0.031220730565095226
# What Jump - Free Pop Arcade Game : 0.031220730565095226
# What Dog A Microsoft Garage Project : 0.031220730565095226
# Werewolf "Nightmare in Prison" : 0.031220730565095226
# Wells Fargo for iPad : 0.031220730565095226
# Wells Fargo Mobile : 0.031220730565095226
# Wellbeyond Meditation for Kids : 0.031220730565095226
# Welcome to Virtual Reality : 0.031220730565095226
# Weirdwood Manor : 0.031220730565095226
# Weight Watchers : 0.031220730565095226
# Weibo HD : 0.031220730565095226
# Weibo : 0.031220730565095226
# Weed Firm: RePlanted : 0.031220730565095226
# Weed Firm 2: Back To College : 0.031220730565095226
# Wedding Planner - Dress Up, Makeup & Cake Design : 0.031220730565095226
# Webcams – EarthCam : 0.031220730565095226
# Webcams Viewer - Live Video Surveillance IP Cams : 0.031220730565095226
# WebMD for iPad : 0.031220730565095226
# WeatherBug - Local Weather, Radar, Maps, Alerts : 0.031220730565095226
# Weather Underground: Custom Forecast & Local Radar : 0.031220730565095226
# Weather Live Free - Weather Forecast & Alerts : 0.031220730565095226
# Weather - Radar - Storm with Morecast App : 0.031220730565095226
# Weather & Radar : 0.031220730565095226
# WeChat : 0.031220730565095226
# We Heart It - Fashion, wallpapers, quotes, tattoos : 0.031220730565095226
# Waze - GPS Navigation, Maps & Real-time Traffic : 0.031220730565095226
# Wayfair - Shop Furniture, Home Decor, Daily Sales : 0.031220730565095226
# Wave : 0.031220730565095226
# Waterlogged - Daily Hydration Tracker : 0.031220730565095226
# Water Bottle Flip Challenge: Flippy Bottle Diving : 0.031220730565095226
# Water Bottle Flip Challenge : Endless Diving 2K16 : 0.031220730565095226
# Water Bottle Flip Challenge : 2k16 : 0.031220730565095226
# Water Bottle Flip Challenge 2 : 0.031220730565095226
# Water Bottle Flip Challenge - 2k16 Pro! : 0.031220730565095226
# Water Bottle Flip Challenge : 0.031220730565095226
# Water Bottle Flip AK 2016 : 0.031220730565095226
# WatchESPN : 0.031220730565095226
# Watch TNT : 0.031220730565095226
# Watch TBS : 0.031220730565095226
# Watch OWN : 0.031220730565095226
# Watch NFL Network : 0.031220730565095226
# Warriors of Glory : 0.031220730565095226
# Warrior Balls : 0.031220730565095226
# Warp Shift : 0.031220730565095226
# WarnWetter : 0.031220730565095226
# Warlords - Turn Based Strategy : 0.031220730565095226
# Warhammer 40,000: Freeblade : 0.031220730565095226
# Warcher Defenders : 0.031220730565095226
# War of Warship:Pacific War : 0.031220730565095226
# War Tortoise : 0.031220730565095226
# War Robots : 0.031220730565095226
# War Machines: 3D Multiplayer Tank Shooting Game : 0.031220730565095226
# War Dragons : 0.031220730565095226
# War Commander: Rogue Assault : 0.031220730565095226
# Wappoi Room Escape : 0.031220730565095226
# Walmart: Free 2-Day Shipping,* Easy Store Shopping : 0.031220730565095226
# Walls & Balls : 0.031220730565095226
# Wallpapers for Me - Themes & Background Images : 0.031220730565095226
# Wall Switch : 0.031220730565095226
# Walking for Weight Loss: training plans, GPS, tips : 0.031220730565095226
# Walk for a Dog : 0.031220730565095226
# Walgreens – Pharmacy, Photo, Coupons and Shopping : 0.031220730565095226
# Waiit : 0.031220730565095226
# WWF Together : 0.031220730565095226
# WWE SuperCard : 0.031220730565095226
# WWE Immortals : 0.031220730565095226
# WWE : 0.031220730565095226
# WWDC : 0.031220730565095226
# WSVN Hurricane Tracker : 0.031220730565095226
# WRAL Weather Alert : 0.031220730565095226
# WKC Dog Show 2017 : 0.031220730565095226
# WIRED Magazine : 0.031220730565095226
# WIND runner adventure : 0.031220730565095226
# WGT Golf Game by Topgolf : 0.031220730565095226
# WEB.DE Mail : 0.031220730565095226
# WEAR - Fashion Lookbook : 0.031220730565095226
# VyStar Mobile Banking for iPhone : 0.031220730565095226
# VyStar Mobile Banking for iPad : 0.031220730565095226
# Vudu - Movies & TV : 0.031220730565095226
# Voyages-sncf.com : book train and bus tickets : 0.031220730565095226
# VoiceTra(Voice Translator) : 0.031220730565095226
# Voice Recorder (FREE) : 0.031220730565095226
# Voice Changer Plus : 0.031220730565095226
# Vlogger Go Viral - Clicker Game & Vlog Simulator : 0.031220730565095226
# Viva™ Slots Las Vegas Classic Casino Games : 0.031220730565095226
# VivaVideo - Best Video Editor & Photo Movie Maker : 0.031220730565095226
# Visage makeup editor plus photo teeth whitener : 0.031220730565095226
# Virtual Regatta Offshore : 0.031220730565095226
# Virtual Reality Roller Coaster for Google Cardboard VR : 0.031220730565095226
# Virtual Reality Moon for Google Cardboard VR : 0.031220730565095226
# Virry Educational. Play, learn with real animals : 0.031220730565095226
# Virginia Tech Emoji : 0.031220730565095226
# Vintage Slots Las Vegas - Old Slot Machine Games! : 0.031220730565095226
# Vine Camera : 0.031220730565095226
# Village Life: Love, Marriage and Babies : 0.031220730565095226
# Vikings: War of Clans : 0.031220730565095226
# Video speed editor - VBooster : 0.031220730565095226
# Video Smith - A Powerful video editing tool set : 0.031220730565095226
# Video Call Santa Claus Christmas - Catch Kids Wish : 0.031220730565095226
# Video & TV Cast for Chromecast: Best Browser to cast and stream webvideos and local videos on TV & Displays : 0.031220730565095226
# Victoria’s Secret – The Sexiest Bras & Lingerie : 0.031220730565095226
# Vice Lipstick : 0.031220730565095226
# Viber Messenger – Text & Call : 0.031220730565095226
# Viator Tours & Activities : 0.031220730565095226
# Vestiaire Collective - Pre-Owned Luxury Fashion : 0.031220730565095226
# Versus Run : 0.031220730565095226
# Versus - Multiplayer Game (2 players) : 0.031220730565095226
# Verizon Cloud : 0.031220730565095226
# Venmo : 0.031220730565095226
# Vendée Globe 2016 : 0.031220730565095226
# Vehicles & Weapons Mods for Minecraft PC Edition - Best Pocket Wiki & Tools for MCPC : 0.031220730565095226
# VeeR VR - Virtual Reality : 0.031220730565095226
# Vector 2 : 0.031220730565095226
# Vault! : 0.031220730565095226
# Valley of Fear Virtual Reality : 0.031220730565095226
# Vainglory : 0.031220730565095226
# VSCO : 0.031220730565095226
# VS. Racing 2 : 0.031220730565095226
# VR-Crazy Car Traffic Racing : 0.031220730565095226
# VR Water Park:Water Stunt & Ride For VirtualGlasse : 0.031220730565095226
# VR Video World - Virtual Reality : 0.031220730565095226
# VR Tube - Virtual Reality 360 Video Player : 0.031220730565095226
# VR Thrills: Roller Coaster 360 (Google Cardboard) : 0.031220730565095226
# VR Street Jump for Google Cardboard : 0.031220730565095226
# VR SNIPER : 0.031220730565095226
# VR Roller-Coaster : 0.031220730565095226
# VR Roller Coaster for Google Cardboard : 0.031220730565095226
# VR Roller Coaster World - Virtual Reality : 0.031220730565095226
# VR Horror Maze Walk :Horror Fever For VR Cardboard : 0.031220730565095226
# VR Haunted House 3D : 0.031220730565095226
# VR HORROR : 0.031220730565095226
# VR Flight Simulator for Google Cardboard : 0.031220730565095226
# VR Death Simulator : 0.031220730565095226
# VR Crazy Bike Race: Traffic Racing Free : 0.031220730565095226
# VR Car Driving Simulator for Google Cardboard : 0.031220730565095226
# VR Ball for Google Cardboard Virtual Reality : 0.031220730565095226
# VPN SecureLine - privacy & security by Avast : 0.031220730565095226
# VPN Proxy Master - Unlimited WiFi security VPN : 0.031220730565095226
# VPN Go - Safe Fast & Stable VPN Proxy : 0.031220730565095226
# VPN Express : 0.031220730565095226
# VOEZ : 0.031220730565095226
# VIZIO SmartCast™ - Cast & Control Movies & TV Show : 0.031220730565095226
# VIDO - Rewards, Music and Videos for YouTube : 0.031220730565095226
# VIBO RealMassager : 0.031220730565095226
# V LIVE - Broadcasting App : 0.031220730565095226
# Urlaubspiraten : 0.031220730565095226
# Upperland : 0.031220730565095226
# Univision NOW – Stream TV en Vivo y On Demand : 0.031220730565095226
# Univision Deportes: Liga MX, MLS, Fútbol En Vivo : 0.031220730565095226
# United Airlines : 0.031220730565095226
# Unison League : 0.031220730565095226
# Uncolored Boy : 0.031220730565095226
# Ultimate Briefcase : 0.031220730565095226
# Ulterior : 0.031220730565095226
# Ugly : 0.031220730565095226
# UberEATS: Uber for Food Delivery : 0.031220730565095226
# Uber Driver : 0.031220730565095226
# Uber : 0.031220730565095226
# USAA Mobile : 0.031220730565095226
# USA TODAY : 0.031220730565095226
# US Presidential Election 2016 - Polls : 0.031220730565095226
# UNiDAYS: Student Discounts for Shopping Top Brands : 0.031220730565095226
# UNO ™ & Friends : 0.031220730565095226
# UNKILLED: MULTIPLAYER ZOMBIE SURVIVAL SHOOTER GAME : 0.031220730565095226
# UNCHARTED: Fortune Hunter™ : 0.031220730565095226
# UFC ® : 0.031220730565095226
# UE BOOM : 0.031220730565095226
# UA Shop by Under Armour : 0.031220730565095226
# U by BB&T : 0.031220730565095226
# U Compass ( North, South, East and West ) : 0.031220730565095226
# Tynker - Learn to Code. Programming Made Easy. : 0.031220730565095226
# Two Dots : 0.031220730565095226
# Twitter : 0.031220730565095226
# Twitch : 0.031220730565095226
# TwitCasting Viewer - Watch Live Video & Radio : 0.031220730565095226
# Twisty Wheel : 0.031220730565095226
# Twisty Board : 0.031220730565095226
# Twisty Arrow - Shoot the Circle Wheel : 0.031220730565095226
# Twist : 0.031220730565095226
# TwinSpires Official Kentucky Derby Wagering App : 0.031220730565095226
# Twin Shooter - Invaders : 0.031220730565095226
# Twin Moons Society™: Hidden Mystery : 0.031220730565095226
# TurboTax Tax Return App - File 2016 income taxes : 0.031220730565095226
# Turbo Dismount® : 0.031220730565095226
# TuneIn Radio - MLB NBA Audiobooks Podcasts Music : 0.031220730565095226
# Tumblr : 0.031220730565095226
# Tubi TV - Watch Free Movies & TV Shows : 0.031220730565095226
# Tubex - Videos and Music for YouTube : 0.031220730565095226
# Truth or Dare · : 0.031220730565095226
# Truth Or Dare — Party Game : 0.031220730565095226
# Trump On The Run : 0.031220730565095226
# Trump Hoverboard Sim - Mannequin Race Challenge : 0.031220730565095226
# Trump Dump ⁢ : 0.031220730565095226
# Trump Bounce : 0.031220730565095226
# Truecaller - Spam Identification & Block : 0.031220730565095226
# Trucker Parking Simulator 2 a Real Monster Truck & Lorry Driving Test : 0.031220730565095226
# Tropical Wars - Pirate Battles : 0.031220730565095226
# Tropical Twist : 0.031220730565095226
# Trolls: Crazy Party Forest! : 0.031220730565095226
# Troll Face Quest Video Memes : 0.031220730565095226
# Troll Face Quest Video Games : 0.031220730565095226
# Trivia Crack Kingdoms : 0.031220730565095226
# Trivia Crack : 0.031220730565095226
# TripAdvisor Hotels Flights Restaurants : 0.031220730565095226
# Trio : 0.031220730565095226
# Triller - Music Video & Film Maker : 0.031220730565095226
# Trigger Fist : 0.031220730565095226
# Triennale Game Collection : 0.031220730565095226
# Tricky Test 2™: Genius Brain? : 0.031220730565095226
# Trials Frontier : 0.031220730565095226
# Trial Xtreme 4 : 0.031220730565095226
# Trello : 0.031220730565095226
# Trebel Music - Unlimited Music Downloader : 0.031220730565095226
# TraptionBakery : 0.031220730565095226
# Trapdoors : 0.031220730565095226
# Transformers: Earth Wars : 0.031220730565095226
# TransParent Compass : 0.031220730565095226
# Trainline UK: Live Train Times, Tickets & Planner : 0.031220730565095226
# Train Conductor World : 0.031220730565095226
# Trailer Truck Parking with Real City Traffic Car Driving Sim : 0.031220730565095226
# Trail Jump : 0.031220730565095226
# Traffic Rider : 0.031220730565095226
# Traffic Racer : 0.031220730565095226
# Tracky Train : 0.031220730565095226
# Toy Blocks Game for Brain Traning -TSUMIKI- : 0.031220730565095226
# Toy Blast : 0.031220730565095226
# Township : 0.031220730565095226
# TownWiFi - WiFi Everywhere : 0.031220730565095226
# Tower Knights! : 0.031220730565095226
# Tower Conquest : 0.031220730565095226
# Touchdown Hero : 0.031220730565095226
# Total War Battles: KINGDOM : 0.031220730565095226
# Total - Free browser with file manager and cloud storage support : 0.031220730565095226
# Torque Burnout : 0.031220730565095226
# TopBuzz: Best Viral Videos, GIFs, TV & News : 0.031220730565095226
# Top Tier : 0.031220730565095226
# Top Model - Next Fashion Star : 0.031220730565095226
# Top Hat Lecture : 0.031220730565095226
# Top Eleven 2017 - Be a Soccer Manager : 0.031220730565095226
# Tooth Fairy Princess - Magical Adventure : 0.031220730565095226
# Toon Shooters 2: The Freelancers : 0.031220730565095226
# Tomb of the Mask : 0.031220730565095226
# Tom's Love Letters : 0.031220730565095226
# TohTum : 0.031220730565095226
# TodayAir : 0.031220730565095226
# Toca Kitchen Monsters : 0.031220730565095226
# Toca Hair Salon - Christmas Gift : 0.031220730565095226
# Toca Dance Free : 0.031220730565095226
# Toast Girl : 0.031220730565095226
# Titan Slots™ III : 0.031220730565095226
# Titan Brawl : 0.031220730565095226
# Tip Tap Soccer : 0.031220730565095226
# Tinycards - Learn with Fun, Free Flashcards : 0.031220730565095226
# Tiny Tower - Free City Building : 0.031220730565095226
# Tiny Sea Adventure : 0.031220730565095226
# Tiny Rails : 0.031220730565095226
# Tiny Miners : 0.031220730565095226
# Tiny Bone : 0.031220730565095226
# Tiny Archers : 0.031220730565095226
# Tinker Island: Survival Adventure : 0.031220730565095226
# Tinder : 0.031220730565095226
# Tina's Diary: Spring Outing : 0.031220730565095226
# Tina's Diary - Star Fever : 0.031220730565095226
# Timehop : 0.031220730565095226
# Timberman : 0.031220730565095226
# Tile - Find & track your lost phone, wallet, keys : 0.031220730565095226
# Tidal Rider : 0.031220730565095226
# Ticketmaster - Tickets for Concerts, Sports, Shows : 0.031220730565095226
# Ticket Scanner for Powerball & MegaMillions Pool : 0.031220730565095226
# Thumb Drift - Furious One Touch Car Racing : 0.031220730565095226
# Through The Fog! : 0.031220730565095226
# Thomas & Friends™: Read & Play : 0.031220730565095226
# Thomas & Friends: Race On! : 0.031220730565095226
# Thomas & Friends: Magical Tracks - Kids Train Set : 0.031220730565095226
# There's no tablecloth I can't pull!! : 0.031220730565095226
# Theory of evolution : 0.031220730565095226
# Themeboard : 0.031220730565095226
# ThemeOut : 0.031220730565095226
# The Weather Channel: Forecast, Radar & Alerts : 0.031220730565095226
# The Weather Channel App for iPad – best local forecast, radar map, and storm tracking : 0.031220730565095226
# The Washington Post Classic : 0.031220730565095226
# The Walls : 0.031220730565095226
# The Walking Dead: Road to Survival - Strategy Game : 0.031220730565095226
# The Walking Dead: No Man's Land : 0.031220730565095226
# The Walking Dead: Dead Yourself : 0.031220730565095226
# The Walk VR : 0.031220730565095226
# The Voice Official App on NBC : 0.031220730565095226
# The Trail : 0.031220730565095226
# The Singing Machine Mobile Karaoke App : 0.031220730565095226
# The Sims™ FreePlay : 0.031220730565095226
# The Simpsons™: Tapped Out : 0.031220730565095226
# The Silent Age : 0.031220730565095226
# The Secret Society® - Hidden Mystery : 0.031220730565095226
# The Sandbox Evolution - Craft a 2D Pixel Universe : 0.031220730565095226
# The Sandbox - Building & Crafting a Pixel World! : 0.031220730565095226
# The Rock Clock™ : 0.031220730565095226
# The Robot Factory by Tinybop : 0.031220730565095226
# The Quest Keeper : 0.031220730565095226
# The Pocket Quiz for Pokemon : 0.031220730565095226
# The Pit : 0.031220730565095226
# The Paranormal Society™: Hidden Adventure : 0.031220730565095226
# The Open : 0.031220730565095226
# The Olympics - Official App for the Olympic Games : 0.031220730565095226
# The Moron Test : 0.031220730565095226
# The Maze Runner ™ : 0.031220730565095226
# The Masters Tournament : 0.031220730565095226
# The Line Zen : 0.031220730565095226
# The Last Vikings : 0.031220730565095226
# The Krustashians : 0.031220730565095226
# The Impossible Quiz! : 0.031220730565095226
# The Impossible Letter Game : 0.031220730565095226
# The Higher Lower Game : 0.031220730565095226
# The Guardian : 0.031220730565095226
# The Counter Of Death : 0.031220730565095226
# The Cooking Game- With Cute iMessage Food Stickers : 0.031220730565095226
# The Clymb — Gear Deals : 0.031220730565095226
# The Championships, Wimbledon 2016 - Tennis Grand Slam : 0.031220730565095226
# The Calculator - Free and Easy Calculating! : 0.031220730565095226
# The CW : 0.031220730565095226
# The Bomb! : 0.031220730565095226
# The Blacklist: Conspiracy : 0.031220730565095226
# The Battle of Polytopia : 0.031220730565095226
# The Bad Man Tipster - Betting Tips : 0.031220730565095226
# TextNow - Unlimited Text + Calls : 0.031220730565095226
# Text Free: Free Texting + Calling + MMS : 0.031220730565095226
# Tetro Blocks - Beat IQ with Tetrix-style-puzzle. : 0.031220730565095226
# Tetris® Blitz : 0.031220730565095226
# Tetminos - Classic Puzzle Game : 0.031220730565095226
# TestNav : 0.031220730565095226
# TestFlight : 0.031220730565095226
# Tesla Tubes: Solve our Logic Games & Brain Puzzles : 0.031220730565095226
# Terra Monsters 3 : 0.031220730565095226
# Tentacles - Enter the Mind : 0.031220730565095226
# Tennis Champs Returns : 0.031220730565095226
# Tennis Bits : 0.031220730565095226
# Temple Run 2 : 0.031220730565095226
# Temple Run : 0.031220730565095226
# Telegram Messenger : 0.031220730565095226
# Teeter – Endless Arcade Balancer : 0.031220730565095226
# Teenage Mutant Ninja Turtles: Legends : 0.031220730565095226
# Teen Titans Go Arcade : 0.031220730565095226
# Team USA App : 0.031220730565095226
# Team GB Live : 0.031220730565095226
# Tchapper Messenger - Keep it private : 0.031220730565095226
# Tayasui Sketches : 0.031220730565095226
# Taxi Sim 2016 : 0.031220730565095226
# TaxCaster – Free tax refund calculator : 0.031220730565095226
# Target Acquired : 0.031220730565095226
# Target : 0.031220730565095226
# Taps to Riches : 0.031220730565095226
# Tapping Monsters : 0.031220730565095226
# Tapage by My Little App : 0.031220730565095226
# Tap the Blocks : 0.031220730565095226
# Tap Tycoon - Country vs Country : 0.031220730565095226
# Tap Titans 2 : 0.031220730565095226
# Tap Titans : 0.031220730565095226
# Tap Tap Trillionaire : 0.031220730565095226
# Tap Tap Fish - Abyssrium : 0.031220730565095226
# Tap Tap Dash : 0.031220730565095226
# Tap Tap Builder : 0.031220730565095226
# Tap Sports Baseball 2016 : 0.031220730565095226
# Tap Smiths : 0.031220730565095226
# Tap Quest : Gate Keeper : 0.031220730565095226
# Tap My Katamari - Endless Cosmic Clicker : 0.031220730565095226
# Tap Hero : 0.031220730565095226
# Tap Cats: Idle Warfare : 0.031220730565095226
# Tantan : 0.031220730565095226
# Tankio - Battle Arena : 0.031220730565095226
# Tank.io war - Free Classic Tank games : 0.031220730565095226
# Tank.IO War - Free Tank games of snake : 0.031220730565095226
# Tank War - Geometry Go Shot Color Dot.IO : 0.031220730565095226
# Tango - Free Video Call, Voice and Chat : 0.031220730565095226
# Tangled Up! - Valentine Special : 0.031220730565095226
# Talking Tom Jetski : 0.031220730565095226
# Talking Tom Gold Run: Fun & Endless Running Game : 0.031220730565095226
# Talking Tom Cat for iPad : 0.031220730565095226
# Talking Tom Cat 2 for iPad : 0.031220730565095226
# Talking Tom Bubble Shooter : 0.031220730565095226
# Talking Tom & Ben News for iPad : 0.031220730565095226
# Talking Pierre the Parrot for iPad : 0.031220730565095226
# Talking Ginger for iPad : 0.031220730565095226
# Talking Ginger 2 : 0.031220730565095226
# Talking Ben the Dog for iPad : 0.031220730565095226
# Talking Angela for iPad : 0.031220730565095226
# Talented Pets Show : 0.031220730565095226
# Tagesschau : 0.031220730565095226
# Tactile Wars : 0.031220730565095226
# TV SPIELFILM - TV Programm mit Live TV : 0.031220730565095226
# TRUTH or DARE!!! - FREE : 0.031220730565095226
# TRUMP'S WALL - Build it Huge : 0.031220730565095226
# TRUMP Yo'Self! Make Your Hair Great Again! : 0.031220730565095226
# TLMJ, Tout Le Monde Joue : 0.031220730565095226
# TLC GO - Watch Full Episodes and Live TV : 0.031220730565095226
# TIME LOCKER - Shooter : 0.031220730565095226
# TIDAL : 0.031220730565095226
# TETRIS® FREE : 0.031220730565095226
# TENOSEL+ : 0.031220730565095226
# TEDiSUB - Enjoy TED Talks with Subtitles : 0.031220730565095226
# TED : 0.031220730565095226
# TCS NYC Marathon : 0.031220730565095226
# TALES OF LINK : 0.031220730565095226
# T-Mobile Tuesdays : 0.031220730565095226
# T-Mobile : 0.031220730565095226
# Symmetrica - Minimalistic arcade game : 0.031220730565095226
# Sworkit - Custom Workouts for Exercise & Fitness : 0.031220730565095226
# Swoopy Space : 0.031220730565095226
# Switchy Sides : 0.031220730565095226
# Swiperoo : 0.031220730565095226
# Swing : 0.031220730565095226
# Swift Playgrounds : 0.031220730565095226
# Sweet Tales: Match 3 Christmas : 0.031220730565095226
# Sweet Tales : 0.031220730565095226
# Sweet Princess Makeup Party - Girls Dressup Games : 0.031220730565095226
# Sweet Princess Beauty Salon : 0.031220730565095226
# Sweat: Kayla Itsines' Bikini Body Fitness Workouts : 0.031220730565095226
# SwapperFace - Face Swap Free, Live Mask Effects : 0.031220730565095226
# Swap Ball - Endless Arcade Bouncer : 0.031220730565095226
# Swamp Attack : 0.031220730565095226
# Swaggy Ninja : 0.031220730565095226
# Suрer Toss The Turtle : 0.031220730565095226
# Survivors: the Quest® : 0.031220730565095226
# Survivor: Prologue : 0.031220730565095226
# Surfingers : 0.031220730565095226
# Suppin Detective: Expose their true visage! : 0.031220730565095226
# Supermodel Star - Rule the Runway : 0.031220730565095226
# Supermarket Girl - Shopping Fun! : 0.031220730565095226
# Superdrug : 0.031220730565095226
# SuperPhoto - Photo Effects & Filters : 0.031220730565095226
# Super Stickman Golf 3 : 0.031220730565095226
# Super Stickman Golf 2 : 0.031220730565095226
# Super Smash the Office - Endless Destruction! : 0.031220730565095226
# Super Slime Blitz – Gumball Endless Arcade Climber : 0.031220730565095226
# Super Phantom Cat - Be a jumping bro. : 0.031220730565095226
# Super Mario Run : 0.031220730565095226
# Super Knock and Run : 0.031220730565095226
# Super Jabber Jump : 0.031220730565095226
# Super Fashion Show - Girls Makeup, Dressup Games : 0.031220730565095226
# Super Duper Punch : 0.031220730565095226
# Super Cat Tales : 0.031220730565095226
# Super Candy: Let's Fix it! : 0.031220730565095226
# Super Atomic : 0.031220730565095226
# Super Adventures World HD : 0.031220730565095226
# Sunken Secrets : 0.031220730565095226
# Sunday Ticket : 0.031220730565095226
# Summoners War : 0.031220730565095226
# Summer Vacation - Fun at the Beach : 0.031220730565095226
# Sumikko gurashi-Puzzling Ways : 0.031220730565095226
# Suicide Squad: Special Ops : 0.031220730565095226
# Suica : 0.031220730565095226
# Sugar Smash: Book of Life : 0.031220730565095226
# Sugar Slide: The Path Home : 0.031220730565095226
# Subway Surfers : 0.031220730565095226
# Stylish School Timetable : 0.031220730565095226
# Stupid Zombies 3 : 0.031220730565095226
# Stupid Test! : 0.031220730565095226
# Stupid Again : 0.031220730565095226
# StubHub - Tickets to Sports, Concerts and Theatre : 0.031220730565095226
# String Rush : 0.031220730565095226
# Stretch Dungeon : 0.031220730565095226
# Stress Release Grenade : 0.031220730565095226
# Street Fighter Puzzle Spirits : 0.031220730565095226
# Strawberry Shortcake Holiday Hair - Fashion World : 0.031220730565095226
# Strawberry Shortcake Dress Up Dreams : 0.031220730565095226
# Strawberry Shortcake Candy Garden : 0.031220730565095226
# Stormfall: Rise of Balur : 0.031220730565095226
# Storm Radar : 0.031220730565095226
# Stop! Thief!! : 0.031220730565095226
# Stop Curry : 0.031220730565095226
# Stop - Fun Categories Word Game : 0.031220730565095226
# Stony Road : 0.031220730565095226
# Stirfry Stunts – We Bare Bears Cooking Game Starring Chef Ice Bear : 0.031220730565095226
# StickyBalls Deluxe - Addicting Fall Down Game : 0.031220730565095226
# Stickninja Smash : 0.031220730565095226
# Stickman Soccer 2016 : 0.031220730565095226
# Stickman Ice Hockey : 0.031220730565095226
# Stickman Forest Swing : 0.031220730565095226
# Stickman Football : 0.031220730565095226
# Stickman Cubed : 0.031220730565095226
# Stickman Basketball 2017 : 0.031220730565095226
# Stickman Base Jumper 2 : 0.031220730565095226
# Sticklings : 0.031220730565095226
# Stick Soccer 2 : 0.031220730565095226
# Stick Hero : 0.031220730565095226
# Steve - The Jumping Dinosaur Widget Arcade Game : 0.031220730565095226
# Steps! - Hardest Action Game Ever! : 0.031220730565095226
# Steps : 0.031220730565095226
# Steppy Pants : 0.031220730565095226
# Stay in the Line - Free : 0.031220730565095226
# State Council - Official Chinese government app : 0.031220730565095226
# Stash Invest: Investing & Financial Education : 0.031220730565095226
# Starfall Learn to Read : 0.031220730565095226
# Starfall FREE : 0.031220730565095226
# Starbucks Keyboard : 0.031220730565095226
# Starbucks : 0.031220730565095226
# Star Wars™: Galaxy of Heroes : 0.031220730565095226
# Star Wars™: Commander : 0.031220730565095226
# Star Wars™ Force Band™ by Sphero : 0.031220730565095226
# Star Walk 2 Ads+ Night Sky Map - Stars and Planets : 0.031220730565095226
# Star Trek ® - Wrath of Gems : 0.031220730565095226
# Star Trek Timelines : 0.031220730565095226
# Star Skater : 0.031220730565095226
# Star Cheerleader - High School Tryouts : 0.031220730565095226
# Star Chart : 0.031220730565095226
# StageCameraHD : 0.031220730565095226
# Stage Rush: Imagine Dragons : 0.031220730565095226
# Stack : 0.031220730565095226
# Squaready for Video - Convert Rectangle Movie Clip into Square Shape for Instagram : 0.031220730565095226
# Square Cash - Send Money for Free : 0.031220730565095226
# Sprinkle of Jesus : 0.031220730565095226
# Spring Festival by BabyBus : 0.031220730565095226
# Spotify Music : 0.031220730565095226
# SportsManias: Sports Emojis, Fantasy & Team News : 0.031220730565095226
# Sports Hero : 0.031220730565095226
# Spoon Pet Collector : 0.031220730565095226
# Splish Splash Pong : 0.031220730565095226
# Splice - Video Editor + Movie Maker by GoPro : 0.031220730565095226
# Splat Wars : 0.031220730565095226
# Splashy Cats: Endless Zigzag Arcade Water Game : 0.031220730565095226
# Splash Pop : 0.031220730565095226
# Splash Cars : 0.031220730565095226
# Splash : 0.031220730565095226
# Spirit Rush : 0.031220730565095226
# Spiral Tower : 0.031220730565095226
# Spiral Splatter : 0.031220730565095226
# Spinrilla - Mixtapes For Free : 0.031220730565095226
# Spinny Phone : 0.031220730565095226
# Spinny Circle : 0.031220730565095226
# Spinning Rings : 0.031220730565095226
# Spin It Rich! Casino Slots: Free Slot Machines : 0.031220730565095226
# Spike Run : 0.031220730565095226
# Spider Solitaire ∙ : 0.031220730565095226
# Spider Solitaire Free by MobilityWare : 0.031220730565095226
# Spellspire : 0.031220730565095226
# SpellingCity : 0.031220730565095226
# Spellbinders : 0.031220730565095226
# Speedtest by Ookla : 0.031220730565095226
# Speech Jammer : 0.031220730565095226
# Speakaboos Reading App: Stories & Songs for Kids : 0.031220730565095226
# Speak & Translate － Voice and Text Translator : 0.031220730565095226
# Sparkwave : 0.031220730565095226
# Sparkasse - Your mobile branch : 0.031220730565095226
# Spanish SOLO: Learn Spanish With Lessons On The Go : 0.031220730565095226
# Spa Birthday Party - Nails, Hair, Dress Up & Cake : 0.031220730565095226
# Southwest Airlines : 0.031220730565095226
# Soundtrack Attack - Steven Universe Rhythm Runner : 0.031220730565095226
# Sounds app - Music And Friends : 0.031220730565095226
# SoundHound Song Search & Music Player : 0.031220730565095226
# SoundCloud Pulse: for creators : 0.031220730565095226
# SoundCloud - Music & Audio : 0.031220730565095226
# Sophia - My Little Sis : 0.031220730565095226
# Sonos Controller : 0.031220730565095226
# Sonic Dash 2: Sonic Boom : 0.031220730565095226
# Sonic Dash : 0.031220730565095226
# Sonic CD : 0.031220730565095226
# Sonic & All-Stars Racing Transformed : 0.031220730565095226
# Sonia Tlev : 0.031220730565095226
# SongPop 2 - Guess The Song : 0.031220730565095226
# SongFlip - Free Music Streamer : 0.031220730565095226
# Solo Selfie : 0.031220730565095226
# Solitaire· : 0.031220730565095226
# Solitaire ▪ : 0.031220730565095226
# Solitaire Ⓞ : 0.031220730565095226
# Solitaire ∞ : 0.031220730565095226
# Solitaire ∘ : 0.031220730565095226
# Solitaire TriPeaks: Classic Card Game : 0.031220730565095226
# Solitaire One : 0.031220730565095226
# Solitaire Free: card games for adults : 0.031220730565095226
# Solitaire Deluxe® Social - Classic, Spider, more : 0.031220730565095226
# Solitaire Classic Card Game™ : 0.031220730565095226
# Solitaire : 0.031220730565095226
# SofaScore Live Sports: Scores, VIDEO & Stats : 0.031220730565095226
# Soda World - Your Soda Inc : 0.031220730565095226
# Soda Dungeon : 0.031220730565095226
# Soda Coin Party: Free Casino Pusher : 0.031220730565095226
# Socrative Student : 0.031220730565095226
# Social Picket - Stalker & Spy for Instagram : 0.031220730565095226
# Soccer Stars™ : 0.031220730565095226
# Soccer Star 2016 World Legend : 0.031220730565095226
# Soccer Stadium Sports Car & Bus Parking Simulator 3D Driving Sim : 0.031220730565095226
# Soccer Puzzle for Brain Training -SoccerStrike- : 0.031220730565095226
# Soccer Hit : 0.031220730565095226
# Soccer Cup Championship 2016 : 0.031220730565095226
# Soccer Clicker : 0.031220730565095226
# Snowboarding The Fourth Phase : 0.031220730565095226
# Snow Roll : 0.031220730565095226
# SnoreLab : Record Your Snoring : 0.031220730565095226
# Sniper: Traffic Hunter : 0.031220730565095226
# Sniper Shooter: Gun Shooting Games : 0.031220730565095226
# Sniper Fury: Fun Mobile Shooter Game : 0.031220730565095226
# Sniper 3D Assassin: Shoot to Kill Gun Game : 0.031220730565095226
# Snapseed : 0.031220730565095226
# Snapimals: Discover & Snap Amazing & Cute Animals! : 0.031220730565095226
# Snapchat : 0.031220730565095226
# SnapMatch - Single and Group Matching : 0.031220730565095226
# Snakeio : 0.031220730565095226
# Snakebird : 0.031220730565095226
# Snake.io - Worm.io - Agar Slither Snake Battle : 0.031220730565095226
# Snake splix : 0.031220730565095226
# Snake Slither Run - Hungry Worm Eat Color Dot : 0.031220730565095226
# Snail Sleep-Dream Talk Recording : 0.031220730565095226
# Snail Bob 2 : 0.031220730565095226
# Smurfs Epic Run - Fun Platform Adventure : 0.031220730565095226
# Smule Sing! : 0.031220730565095226
# Smelly Baby - Farty Party : 0.031220730565095226
# Smashy Road: Wanted : 0.031220730565095226
# Smashy Road: Arena : 0.031220730565095226
# Smashy City : 0.031220730565095226
# Smash Slots : 0.031220730565095226
# Smash Monsters - City Rampage : 0.031220730565095226
# Smash Hit : 0.031220730565095226
# Smash Fu - Endless Arcade Smasher : 0.031220730565095226
# SmartNews - Trending News & Stories : 0.031220730565095226
# SmartFit - Wristband : 0.031220730565095226
# Smart Virtual Boyfriend : 0.031220730565095226
# Smart Music: Streaming Videos and Radio : 0.031220730565095226
# Smart Matches ~ Puzzles with Matchsticks : 0.031220730565095226
# Smart Channel -New Style of News Reader- : 0.031220730565095226
# Smart Alarm Clock : sleep cycle & snoring recorder : 0.031220730565095226
# Slots: VIP Deluxe Slots Machines - Free Slot Games : 0.031220730565095226
# Slots: Hot Vegas Slot Machines - Free Slot Games : 0.031220730565095226
# Slots: Get Rich Slot Machines Casino Slot Games : 0.031220730565095226
# Slots: Fast Fortune Slot Machines & Fun Slot Games : 0.031220730565095226
# Slots: DoubleUp Free Slot Games - Slot Machines : 0.031220730565095226
# Slots of Vegas - Play Free Casino slot machines! : 0.031220730565095226
# Slots Real Las Vegas - Free Casino Slot Machine Games - Bet, Spin and Win Jackpot & Bonus : 0.031220730565095226
# Slots Discovery : 0.031220730565095226
# Slots - Pharaoh's Way : 0.031220730565095226
# Slots - Lucky Win Casino Games & Slot Machines : 0.031220730565095226
# Slots - Huuuge Casino: Slot Machines : 0.031220730565095226
# Sloomy : 0.031220730565095226
# Slip Away : 0.031220730565095226
# Slingshot Rush : 0.031220730565095226
# Sling TV: A La Carte TV. Watch Live Shows & Sports : 0.031220730565095226
# Sling Kong : 0.031220730565095226
# SlideStory - Create a slideshow movie and a snap video : 0.031220730565095226
# Slide the Shakes : 0.031220730565095226
# Sleep Talk Recorder : 0.031220730565095226
# Sleep Meister - Sleep Cycle Alarm Lite : 0.031220730565095226
# Sleep Cycle alarm clock : 0.031220730565095226
# Slaymoji - Emoji Keyboard & iMessage Stickers : 0.031220730565095226
# Slash Mobs : 0.031220730565095226
# Slam Dunk Basketball 2 - Play & Do Good : 0.031220730565095226
# Skype for iPhone : 0.031220730565095226
# Skype for iPad : 0.031220730565095226
# Skyline Skaters : 0.031220730565095226
# Skylanders™ Creator : 0.031220730565095226
# Skylanders SuperChargers : 0.031220730565095226
# Skylanders Battlecast : 0.031220730565095226
# SkyView® Free - Explore the Universe : 0.031220730565095226
# Sky Whale - a Game Shakers App : 0.031220730565095226
# Sky Viper Video Viewer : 0.031220730565095226
# Sky Viper Flight Simulator : 0.031220730565095226
# Sky Pillar : 0.031220730565095226
# Sky News : 0.031220730565095226
# Sky Hoppers : 0.031220730565095226
# Sky Force Reloaded : 0.031220730565095226
# Sky Chasers : 0.031220730565095226
# Sky Charms : 0.031220730565095226
# Sky Burger - Build & Match Food Free : 0.031220730565095226
# Skippy Box : 0.031220730565095226
# Skiplagged — Actually Cheap Flights & Hotels : 0.031220730565095226
# Skinseed - Skin Creator for Minecraft Skins : 0.031220730565095226
# SkillTwins Football Game : 0.031220730565095226
# Skiing Yeti Mountain : 0.031220730565095226
# Ski Resort Parking Sim Ice Road Snow Plow Trucker : 0.031220730565095226
# SketchBook Motion : 0.031220730565095226
# Six! : 0.031220730565095226
# Six Flags : 0.031220730565095226
# Sisters: A Virtual Reality Ghost Story : 0.031220730565095226
# Sir Match-a-Lot – Match 3 Puzzle Game : 0.031220730565095226
# Sing Karaoke Songs Unlimited with StarMaker : 0.031220730565095226
# Simulator Run Real Hologram : 0.031220730565095226
# Simulator Hoverboard : 0.031220730565095226
# Simply Piano by JoyTunes - Learn & play piano : 0.031220730565095226
# Simple Reversi Online : 0.031220730565095226
# Simple Radio - Live AM & FM Radio Stations : 0.031220730565095226
# Simple Habit : 0.031220730565095226
# Simple Camera - Fast Minimal Design : 0.031220730565095226
# Simeji - Japanese Keyboard with Emoticons : 0.031220730565095226
# SimSimi : 0.031220730565095226
# SimCity BuildIt : 0.031220730565095226
# Silly Sausage: Doggy Dessert : 0.031220730565095226
# Sideline - 2nd Phone Number : 0.031220730565095226
# Shutterfly: Prints, Photo Books, Cards Made Easy : 0.031220730565095226
# Shuffle Cats : 0.031220730565095226
# Shpock Boot Sale & Classifieds App. Buy & Sell : 0.031220730565095226
# Showroomprive - Private Fashion Sales : 0.031220730565095226
# Show My Homework : 0.031220730565095226
# Shoutrageous! - The Addictive Game of Lists : 0.031220730565095226
# Shopular Coupons, Weekly Deals for Target, Walmart : 0.031220730565095226
# Shopping Mall Girl - Dress Up & Style Game : 0.031220730565095226
# Shopping Mall Car Parking Simulator a Real Driving Racing Game : 0.031220730565095226
# Shopkins: Chef Club : 0.031220730565095226
# Shopkins World! : 0.031220730565095226
# Shop Savvy Barcode Scanner - Price Compare & Deals : 0.031220730565095226
# Shooty Skies - Endless Arcade Flyer : 0.031220730565095226
# Shogi : 0.031220730565095226
# Shell by Bellabeat - Baby Heartbeat Listener : 0.031220730565095226
# Shazam - Discover music, artists, videos & lyrics : 0.031220730565095226
# Shark Boom - Challenge Friends with your Pet : 0.031220730565095226
# Shadow Fight 2 : 0.031220730565095226
# Shadow Bug Rush : 0.031220730565095226
# Seven - 7 Minute Workout Training Challenge : 0.031220730565095226
# Sephora Makeup & Beauty App – Insider Tips & Style : 0.031220730565095226
# Sephojis – Sephora Emoji Keyboard & GIFs : 0.031220730565095226
# SenseSleep - Train Your Brain To Sleep Better : 0.031220730565095226
# SelfieCity : 0.031220730565095226
# Selfeo : 0.031220730565095226
# Seekers Notes: Hidden Mystery : 0.031220730565095226
# SeatGeek – Tickets to Sports, Concerts & Broadway : 0.031220730565095226
# Seashine : 0.031220730565095226
# Sea Hero Quest : 0.031220730565095226
# Scrubby Dubby Saga : 0.031220730565095226
# Score! Hero : 0.031220730565095226
# Science Girl - School Lab Super Star : 0.031220730565095226
# Schoology : 0.031220730565095226
# School of Chaos Online MMORPG : 0.031220730565095226
# School Lunch Food! : 0.031220730565095226
# Scanner App - PDF Document Scan : 0.031220730565095226
# Scanbot - Scanner App & Fax : 0.031220730565095226
# SayHi Translate : 0.031220730565095226
# Save The Line : 0.031220730565095226
# Save Dan : 0.031220730565095226
# Sausage Legend - Fighting Game : 0.031220730565095226
# Santa's Naughty or Nice Scan-O-Matic Free : 0.031220730565095226
# Santa Tracker Christmas Free : 0.031220730565095226
# Santa Tracker - Where is Santa Claus? : 0.031220730565095226
# Santa Kids Hair Salon - Christmas Makeover Games : 0.031220730565095226
# Santa Calls You Free : 0.031220730565095226
# Santa Call & Tracker Free - North Pole Command : 0.031220730565095226
# Sandstorm: Pirate Wars : 0.031220730565095226
# Sam’s Club Scan & Go : 0.031220730565095226
# Samurai Ninja Puzzle ONIMARU : 0.031220730565095226
# Sam's Club: Wholesale Shopping & Bulk Buy Deals : 0.031220730565095226
# Sago Mini Holiday Trucks and Diggers : 0.031220730565095226
# Sago Mini Babies Dress Up : 0.031220730565095226
# SafeTrek - Personal Safety : 0.031220730565095226
# Sacred Legends : 0.031220730565095226
# SW/NG - Living Photos. Memories that Swing. : 0.031220730565095226
# SUDOKU -The puzzle game that makes your brain younger!- : 0.031220730565095226
# STARZ : 0.031220730565095226
# STAR WARS™: FORCE COLLECTION : 0.031220730565095226
# SPIEGEL ONLINE - Nachrichten : 0.031220730565095226
# SPEED:3D Racing : 0.031220730565095226
# SONIC Drive-In : 0.031220730565095226
# SOMA Messenger : 0.031220730565095226
# SNOW - Selfie, Motion sticker, Fun camera : 0.031220730565095226
# SNKRS : 0.031220730565095226
# SNCF : 0.031220730565095226
# SMILE Inc. : 0.031220730565095226
# SLOTS: TRUMP vs. HILLARY CLINTON Free Slot Games : 0.031220730565095226
# SLAAAASH ! -Cut and Smash ! refreshing Puzzle- : 0.031220730565095226
# SHOWTIME : 0.031220730565095226
# SHOWROOM - video live streaming : 0.031220730565095226
# SHEIN Shopping - Women's Clothing & Fashion : 0.031220730565095226
# SHAHID for iPhone : 0.031220730565095226
# SFR TV : 0.031220730565095226
# SFR Mon Compte : 0.031220730565095226
# SBK16 - Official Mobile Game : 0.031220730565095226
# S, - Puzzle Game With Create Level Feature : 0.031220730565095226
# Résultats Foot en Direct : 0.031220730565095226
# Ryder Cup 2016 – Hazeltine National Golf Club : 0.031220730565095226
# Ryanair - Cheapest Fares : 0.031220730565095226
# Runtastic Six Pack Abs Workout & Core Trainer : 0.031220730565095226
# Runtastic Running, Jogging and Walking Tracker : 0.031220730565095226
# Runtastic Results: Workout & Bodyweight Training : 0.031220730565095226
# Runtastic Butt Workout & Booty Trainer Plans : 0.031220730565095226
# Running Man Challenge - Game : 0.031220730565095226
# Run!!! : 0.031220730565095226
# Run Sackboy! Run! : 0.031220730565095226
# Run From Trump : 0.031220730565095226
# Rubin.io : 0.031220730565095226
# Royal Revolt 2 – Defend Your Castle : 0.031220730565095226
# RoverCraft Space Racing : 0.031220730565095226
# Round Balls : 0.031220730565095226
# Rope Racers - Fun Multiplayer Racing Game : 0.031220730565095226
# Rooms of Doom : 0.031220730565095226
# Room Escape [SECRET CODE 2] : 0.031220730565095226
# ...
# Bouncy Kingdom : 0.031220730565095226
# Bouncing Ball 2 : 0.031220730565095226
# Bounce Balls - Strike Game : 0.031220730565095226
# Bottle Flip! : 0.031220730565095226
# Bottle Flip 2k16 : 0.031220730565095226
# Bose SoundTouch : 0.031220730565095226
# Bose Connect : 0.031220730565095226
# Boomerang from Instagram : 0.031220730565095226
# Boom: Best Equalizer & Magical Surround Sound : 0.031220730565095226
# Boom Boom Soccer : 0.031220730565095226
# Boom Boom Football : 0.031220730565095226
# Boom Beach : 0.031220730565095226
# Bookshelf : 0.031220730565095226
# BookShout: Read eBooks & Track Your Reading Goals : 0.031220730565095226
# Book - room escape game - : 0.031220730565095226
# Boo - The World's Cutest Dog Game! : 0.031220730565095226
# Bonk! Presented by The Tonight Show Starring Jimmy Fallon : 0.031220730565095226
# Bonecrusher: Free Awesome Endless Skull & Bone Game : 0.031220730565095226
# Bon Appetit : 0.031220730565095226
# Bold Moves : 0.031220730565095226
# BlurEffect-Blur Photo & Video, Hide Face : 0.031220730565095226
# Blue Apprentice Elementary Science Game by Galxyz : 0.031220730565095226
# Bloxels: Build, Play & Share Your Own Video Games : 0.031220730565095226
# Blossom Blast Saga - Fun Flower Match & Grow Game : 0.031220730565095226
# Bloons TD Battles : 0.031220730565095226
# Blocs Wave - Make & Record Music : 0.031220730565095226
# Blocky Soccer - Endless Arcade Runner : 0.031220730565095226
# Blocky Racer - Endless Arcade Racing : 0.031220730565095226
# Blocky Hockey - Arcade Ice Runner : 0.031220730565095226
# Blocky Football : 0.031220730565095226
# Blocky Basketball - Endless Arcade Dunker : 0.031220730565095226
# Block! Hexa Puzzle : 0.031220730565095226
# Block Сity Wars: game and skin export to minecraft : 0.031220730565095226
# Block Craft 3D: Building Simulator Game For Free : 0.031220730565095226
# Blitz Brigade: Multiplayer FPS shooter online! : 0.031220730565095226
# Blink Health : 0.031220730565095226
# Bleacher Report: Sports news, scores, & highlights : 0.031220730565095226
# BlazBlue RR - the Real Action Game : 0.031220730565095226
# Blair's Fashion Boutique - School Style : 0.031220730565095226
# Blade Sliders : 0.031220730565095226
# Blackjack by MobilityWare : 0.031220730565095226
# Blackbox - think outside the box : 0.031220730565095226
# Blackboard Mobile Learn™ : 0.031220730565095226
# Black Friday 2017 Ads App - BlackFriday.fm : 0.031220730565095226
# Black Box - Black Movie List : 0.031220730565095226
# BlaBlaCar - Trusted Carpooling : 0.031220730565095226
# Bits of Sweets : 0.031220730565095226
# Bitmoji - Your Personal Emoji : 0.031220730565095226
# Bitauto Autoprice : 0.031220730565095226
# Bingo!™ : 0.031220730565095226
# Bingo Pop : 0.031220730565095226
# Billionaire – Business Capitalist Tycoon! : 0.031220730565095226
# Billion Hunter - Casual Monster Clicker RPG : 0.031220730565095226
# Billiards9 : 0.031220730565095226
# Billiards8 (8 Ball & Mission) : 0.031220730565095226
# Bike Unchained : 0.031220730565095226
# Bike Traffic Rider an Extreme Real Endless Road Racer Racing Game : 0.031220730565095226
# Bike Race Level 100 : 0.031220730565095226
# Bike Race - Top Motorcycle Racing Games : 0.031220730565095226
# Big Win Football 2016 : 0.031220730565095226
# Big Fish Casino – Best Vegas Slot Machines & Games : 0.031220730565095226
# Big Bang Racing : 0.031220730565095226
# Bible : 0.031220730565095226
# Beyond 14 : 0.031220730565095226
# BestieBox : 0.031220730565095226
# Bestie-Beauty Camera 360 & Portrait Selfie Editor : 0.031220730565095226
# Best Fiends Forever : 0.031220730565095226
# Best Fiends : 0.031220730565095226
# Best Buy : 0.031220730565095226
# Best 9 for Instagram : 0.031220730565095226
# Bernie Sandwiches - Run For The White House : 0.031220730565095226
# Beneath The Lighthouse : 0.031220730565095226
# Bella's Pizza Place - Italian Food Maker : 0.031220730565095226
# Bejeweled Stars : 0.031220730565095226
# Bejeweled Classic HD : 0.031220730565095226
# Bejeweled Classic : 0.031220730565095226
# Bejeweled Blitz : 0.031220730565095226
# Being SalMan: The Official Game : 0.031220730565095226
# Behind You!! : 0.031220730565095226
# Beer Pong Game : 0.031220730565095226
# Bee Brilliant : 0.031220730565095226
# BeautyPlus - Selfie Camera for a Beautiful Image : 0.031220730565095226
# BeautyCam - AR Carnie selfie : 0.031220730565095226
# Beautiful Japanese Handwriting for iPhone : 0.031220730565095226
# Beautiful Japanese Handwriting : 0.031220730565095226
# Beat the Boss 4 : 0.031220730565095226
# Beat the Boss 2 : 0.031220730565095226
# Beat Racer : 0.031220730565095226
# Beast Poker : 0.031220730565095226
# Bear Pop - Bubble Shooter Game : 0.031220730565095226
# Bear : 0.031220730565095226
# Beach Buggy Racing : 0.031220730565095226
# Bazaart Photo Editor Pro and Picture Collage Maker : 0.031220730565095226
# Battlestar Galactica: Squadrons™ : 0.031220730565095226
# Battleplans - #1 Battle Strategy & Defense Game : 0.031220730565095226
# Battlefield™ Companion : 0.031220730565095226
# Battleborn® Tap : 0.031220730565095226
# BattleHand : 0.031220730565095226
# Battle Golf : 0.031220730565095226
# Battle Copters : 0.031220730565095226
# Battle Camp HD - Collect & Evolve Your Monsters : 0.031220730565095226
# Battle Bears Overclock FPS Epic Multiplayer Shooting Games : 0.031220730565095226
# Batman: Arkham Underworld : 0.031220730565095226
# Batman: Arkham Origins : 0.031220730565095226
# Batman v Superman: Who Will Win : 0.031220730565095226
# Basketball Stars™ : 0.031220730565095226
# Basketball Free Throw : 0.031220730565095226
# Basketball Clicker : 0.031220730565095226
# Basket Fall - Basketball Dunking Sim : 0.031220730565095226
# BarcodeReader「ICONIT」 : 0.031220730565095226
# Barbie Dreamtopia - Magical Hair : 0.031220730565095226
# Bank of America - Mobile Banking for iPad : 0.031220730565095226
# Bank of America - Mobile Banking : 0.031220730565095226
# Bandsintown Concerts : 0.031220730565095226
# Ball Tower : 0.031220730565095226
# Ball Maze! : 0.031220730565095226
# Ball King : 0.031220730565095226
# Ball Escape! : 0.031220730565095226
# Bakery Story 2 : 0.031220730565095226
# Bakery Blitz: Cooking Game : 0.031220730565095226
# Baidu Videos : 0.031220730565095226
# Badoo - Meet New People, Chat, Socialize. : 0.031220730565095226
# Bad Piggies HD : 0.031220730565095226
# Bad Piggies : 0.031220730565095226
# Back To Square One : 0.031220730565095226
# Babysitter Madness - Help the Nanny : 0.031220730565095226
# Babysitter Craziness - Fun Kids Game : 0.031220730565095226
# Baby Twins - Terrible Two : 0.031220730565095226
# Baby Story - Pregnancy Pics Baby Milestones Photo : 0.031220730565095226
# Baby Skins and Aphmau Skins and Boy Skins and Girl Skins For Minecraft PE : 0.031220730565095226
# Baby Panda's Carnival : 0.031220730565095226
# Baby Panda's Bath Time : 0.031220730565095226
# Baby Learns Transportation : 0.031220730565095226
# Baby Kim - Care, Play & Dress Up : 0.031220730565095226
# Baby Full House - Care, Play and Have Fun : 0.031220730565095226
# Baby Food Fair - Make, Eat, Play - Have Fun! : 0.031220730565095226
# Baby Care & Dress Up - Love & Have Fun with Babies : 0.031220730565095226
# Baby Bottle Challenge - Water Bottle Flip : 0.031220730565095226
# Baby Boss - Care, Dress Up and Play : 0.031220730565095226
# Baby Airlines - Airport Adventures : 0.031220730565095226
# Babbel – Learn Languages Spanish, French & more : 0.031220730565095226
# BTN2Go : 0.031220730565095226
# BOSS Tuner : 0.031220730565095226
# BOO! - Video chat camera with filters & stickers : 0.031220730565095226
# BLEACH Brave Souls : 0.031220730565095226
# BIG WIN Basketball : 0.031220730565095226
# BFMTV : l'info en continu : 0.031220730565095226
# BFB Champions 2.0 ~Football Club Manager~ : 0.031220730565095226
# BET NOW - Watch Shows : 0.031220730565095226
# BEAKER by THIX : 0.031220730565095226
# BBTAN by 111% : 0.031220730565095226
# BB-8™ App Enabled Droid Powered by Sphero : 0.031220730565095226
# BARRIER X : 0.031220730565095226
# BAA Marathon : 0.031220730565095226
# B612 - Trendy Filters, Selfiegenic Camera : 0.031220730565095226
# Axe in Face 2 : 0.031220730565095226
# Autohome-Find new＆Used Cars For Sale : 0.031220730565095226
# AutoScout24 - mobile used & new car market : 0.031220730565095226
# AutoRap by Smule : 0.031220730565095226
# Auto Warriors - Tactical Car Combat : 0.031220730565095226
# Auto Palmistry : 0.031220730565095226
# Auto IV Calc for PokemonGO : 0.031220730565095226
# Aussie Rules Hero - Footy Goal Kicking Game : 0.031220730565095226
# Auralux: Constellations : 0.031220730565095226
# Audible – audio books, original series & podcasts : 0.031220730565095226
# Attenborough Story of Life : 0.031220730565095226
# Atom – Movie Tickets and Showtimes : 0.031220730565095226
# Athletics 2: Summer Sports - Free : 0.031220730565095226
# Athlete Shave Salon Games : 0.031220730565095226
# Asterix and Friends : 0.031220730565095226
# Assassin's Creed Pirates : 0.031220730565095226
# Asphalt Xtreme: Offroad Rally Racing : 0.031220730565095226
# Asphalt 8: Airborne : 0.031220730565095226
# Asana Rebel - Yoga Inspired Fitness : 0.031220730565095226
# Artisto – Video and Photo Editor with Art Filters : 0.031220730565095226
# Arrow Ambush : 0.031220730565095226
# Arrow : 0.031220730565095226
# Army of Heroes : 0.031220730565095226
# Arma Mobile Ops : 0.031220730565095226
# Archery King : 0.031220730565095226
# Arcane Online - Fantasy MMORPG : 0.031220730565095226
# Aquarium VR : 0.031220730565095226
# April - Layouts, Photo Collage, and Poster Maker : 0.031220730565095226
# Apple TV Remote : 0.031220730565095226
# Apple Support : 0.031220730565095226
# Apple Store : 0.031220730565095226
# Ao Oni2 : 0.031220730565095226
# Anki OVERDRIVE : 0.031220730565095226
# Anime Power FX : 0.031220730565095226
# Animation Throwdown: The Quest for Cards : 0.031220730565095226
# Animal Jam - Play Wild! : 0.031220730565095226
# Angry Birds Transformers : 0.031220730565095226
# Angry Birds Star Wars II : 0.031220730565095226
# Angry Birds Star Wars HD : 0.031220730565095226
# Angry Birds Star Wars : 0.031220730565095226
# Angry Birds Space HD : 0.031220730565095226
# Angry Birds Space : 0.031220730565095226
# Angry Birds Seasons HD : 0.031220730565095226
# Angry Birds Rio HD : 0.031220730565095226
# Angry Birds Rio : 0.031220730565095226
# Angry Birds POP! - Bubble Shooter : 0.031220730565095226
# Angry Birds HD : 0.031220730565095226
# Angry Birds Go! : 0.031220730565095226
# Angry Birds Friends : 0.031220730565095226
# Angry Birds Epic RPG : 0.031220730565095226
# Angry Birds Blast : 0.031220730565095226
# Angry Birds Action! : 0.031220730565095226
# Angry Birds 2 : 0.031220730565095226
# Angry Birds : 0.031220730565095226
# Amusement Park Tour 2: Fun Xmas : 0.031220730565095226
# Amusement Park Tour : 0.031220730565095226
# Amusement Park Fair Ground Circus Trucker Parking Simulator : 0.031220730565095226
# AmpMe - A Portable Social Party Music Speaker : 0.031220730565095226
# Amex Mobile : 0.031220730565095226
# Ameba : 0.031220730565095226
# Amazon Prime Video : 0.031220730565095226
# Amazon Prime Now : 0.031220730565095226
# Amazon Music : 0.031220730565095226
# Amazon App: shop, scan, compare, and read reviews : 0.031220730565095226
# Amazon Alexa : 0.031220730565095226
# Amazing Thief : 0.031220730565095226
# Amateur Surgeon 4 : 0.031220730565095226
# Alternative Girls : 0.031220730565095226
# Alpha Omega : 0.031220730565095226
# Alpaca World HD+ : 0.031220730565095226
# Almanac Long-Range Weather Forecast : 0.031220730565095226
# Allrecipes Dinner Spinner : 0.031220730565095226
# Alliance: Air War - Airplane Flight Simulator Game : 0.031220730565095226
# Alliance Wars: World Domination : 0.031220730565095226
# All is Lost : 0.031220730565095226
# All Star Quarterback 17 - Football Lifestyle Sim : 0.031220730565095226
# All Limpy Run! : 0.031220730565095226
# All Devices for WhatsApp - Messenger for iPad : 0.031220730565095226
# Alipay - Makes Life Easy : 0.031220730565095226
# Alice in the Mirrors of Albion: Hidden object game : 0.031220730565095226
# AliExpress Shopping App : 0.031220730565095226
# Alarm Clock for Me - Best Wake Up Music & Clock : 0.031220730565095226
# Alarm Clock HD Free - Digital Alarm Clock Display : 0.031220730565095226
# Akinator the Genie FREE : 0.031220730565095226
# Airbnb : 0.031220730565095226
# AirWatch Agent : 0.031220730565095226
# AgingBooth : 0.031220730565095226
# Age of Heroes: Conquest : 0.031220730565095226
# Agar.io : 0.031220730565095226
# Again - room escape game : 0.031220730565095226
# Afterpulse : 0.031220730565095226
# After School - Funny Anonymous School News : 0.031220730565095226
# Aeronaut : 0.031220730565095226
# Adventure Cube : 0.031220730565095226
# Adventure Company : 0.031220730565095226
# Advent Calendar 2017 - The Game : 0.031220730565095226
# Adobe Spark Video, Animated Videos in minutes : 0.031220730565095226
# Adobe Spark Page — Create Stunning Web Pages : 0.031220730565095226
# Adobe Photoshop Mix - Cut out, combine, create : 0.031220730565095226
# Adobe Photoshop Lightroom for iPhone : 0.031220730565095226
# Adobe Photoshop Lightroom for iPad : 0.031220730565095226
# Adobe Illustrator Draw : 0.031220730565095226
# Adobe Acrobat Reader: View, Create, & Convert PDFs : 0.031220730565095226
# AdVenture Capitalist : 0.031220730565095226
# Action Movie FX : 0.031220730565095226
# Ace Fishing: Wild Catch : 0.031220730565095226
# AccuWeather - Weather for Life : 0.031220730565095226
# Acapella from PicPlayPost : 0.031220730565095226
# Ab in den Urlaub – Pauschalreisen günstig buchen : 0.031220730565095226
# Ab & Core Sworkit - Free Workout Trainer : 0.031220730565095226
# ATracker - Daily Task and Time Tracking : 0.031220730565095226
# AT&T Mobile Transfer - Free : 0.031220730565095226
# ASOS : 0.031220730565095226
# AOL: News, Email, Weather & Video : 0.031220730565095226
# AMC : 0.031220730565095226
# AGT: America's Got Talent Official App on NBC : 0.031220730565095226
# AEO|Aerie: Jeans, Dresses, Swimsuits & Bralettes : 0.031220730565095226
# ADP Mobile Solutions : 0.031220730565095226
# ABCmouse.com - Early Learning Academy : 0.031220730565095226
# ABC – Watch Live TV & Stream Full Episodes : 0.031220730565095226
# ABC News - US & World News + Live Video : 0.031220730565095226
# A.P.E.X : 0.031220730565095226
# A Color Story : 0.031220730565095226
# A Call From Santa! Voicemail & Text Messages : 0.031220730565095226
# 94% : 0.031220730565095226
# 8fit - Workouts, meal plans and personal trainer : 0.031220730565095226
# 8-BIT WATERSLIDE : 0.031220730565095226
# 8 Ball Pool™ : 0.031220730565095226
# 7-Eleven, Inc. : 0.031220730565095226
# 6play, TV en direct et en replay : 0.031220730565095226
# 5miles: Buy and Sell Used Stuff Locally : 0.031220730565095226
# 5E Spell Book : 0.031220730565095226
# 50 50 - The Addictive Slicing Game : 0.031220730565095226
# 4x4 Dirt Track Trials Forest Driving Parking Sim : 0.031220730565095226
# 4 Pics 1 Word : 0.031220730565095226
# 4 Images 1 Mot : 0.031220730565095226
# 4 Bilder 1 Wort : 0.031220730565095226
# 3D Maze Level 100 : 0.031220730565095226
# 3D Dubai Parking Simulator Drive Real Extreme Super Sports Car : 0.031220730565095226
# 3D Car Racing Simulator Real Drag Race Rivals Road Chase Driving Games : 0.031220730565095226
# 365Scores : 0.031220730565095226
# 360云盘 : 0.031220730565095226
# 360 Degree : 0.031220730565095226
# 2Face Fitpack - Dein Trainingsprogramm mit persönlichem Ernährungsplan, Kalorienrechner und Trainingsplan : 0.031220730565095226
# 270toWin : 0.031220730565095226
# 25 Days of Christmas: Holiday Advent Calendar 2016 : 0.031220730565095226
# 2048 : 0.031220730565095226
# 2016 US Open Tennis Championships : 0.031220730565095226
# 2016 U.S. Open Golf Championship for iPad : 0.031220730565095226
# 2016 U.S. Open Golf Championship : 0.031220730565095226
# 20 Minutes.fr - l'actualité en continu : 0.031220730565095226
# 1600 : 0.031220730565095226
# 1010! : 0.031220730565095226
# 1000m Zombie Escape! : 0.031220730565095226
# 100! Block Puzzle - Color jigsaw 10x10 board game : 0.031220730565095226
# 100 PICS Quiz - guess the picture trivia games : 0.031220730565095226
# 100 PICS Coloring - free color in book game app : 0.031220730565095226
# 100 Balls : 0.031220730565095226
# 1-Bit Rogue: A dungeon crawler RPG! : 0.031220730565095226
# 1+2=3 : 0.031220730565095226
# . Calculator . : 0.031220730565095226
# *Solitaire* : 0.031220730565095226
# ! OH Fantastic Free Kick + Kick Wall Challenge : 0.031220730565095226

# %% [markdown]
# ## 11. Most Common Apps by Genre: Part Three
#
# En la pantalla anterior, hemos generado tablas de frecuencia para las columnas prime_genre, Genres y Category. Ahora nos centraremos en el análisis de estas tablas de frecuencia.
#
# Recuerda que nuestro conjunto de datos sólo contiene aplicaciones gratuitas en inglés, por lo que debes tener cuidado de no extender tus conclusiones más allá de ese ámbito. Si encuentras que las aplicaciones de juegos son las más numerosas entre las aplicaciones gratuitas en inglés en Google Play, no significa que veamos el mismo patrón en Google Play en su conjunto.
#
#
# **Instrucciones**
#
# Analiza la tabla de frecuencias que has generado para la columna prime_genre del conjunto de datos del App Store.
#
# - ¿Cuál es el género más común?
# - ¿Cuál es el segundo?
# - ¿Qué otros patrones observas?
# - ¿Cuál es la impresión general: la mayoría de las aplicaciones están diseñadas para fines prácticos (educación, compras, utilidades, productividad, estilo de vida) o más bien para el entretenimiento (juegos, fotos y vídeos, redes sociales, deportes, música)?
#
# - ¿Puede recomendar un perfil de aplicaciones para el mercado de la App Store basándose únicamente en esta tabla de frecuencias?
#
# - Si hay un gran número de aplicaciones para un género en particular, ¿implica también que las aplicaciones de ese género suelen tener un gran número de usuarios?
#
# - Analiza la tabla de frecuencias que has generado para la columna Categoría y Géneros del conjunto de datos de Google Play.
#
# - ¿Cuáles son los géneros más comunes?
# - ¿Qué otros patrones observas?
# - Compara los patrones que ves para el mercado de Google Play con los que viste para el mercado de App Store.
# - ¿Puedes recomendar un perfil de aplicación basado en lo que has encontrado hasta ahora? - - ¿Las tablas de frecuencia que has generado revelan los géneros de aplicaciones más frecuentes o qué géneros tienen más usuarios?

# %%
display_table(free_AppleStore,11)
# Out:
# Games : 58.25788323446769
# Entertainment : 7.836403371838902
# Photo & Video : 4.995316890415236
# Education : 3.6840462066812365
# Social Networking : 3.3093974399000934
# Shopping : 2.5913206369029034
# Utilities : 2.466437714642523
# Sports : 2.1542304089915705
# Music : 2.0605682172962845
# Health & Fitness : 2.0293474867311896
# Productivity : 1.7483609116453322
# Lifestyle : 1.5610365282547611
# News : 1.3424914142990947
# Travel : 1.248829222603809
# Finance : 1.0927255697783327
# Weather : 0.8741804558226661
# Food & Drink : 0.8117389946924758
# Reference : 0.5307524196066188
# Business : 0.5307524196066188
# Book : 0.3746487667811427
# Navigation : 0.18732438339057134
# Medical : 0.18732438339057134
# Catalogs : 0.1248829222603809

# %% [markdown]
# dataset  original:
#
# - applestore: 7197
# - free_applestore:    3203
# - 44,5% de las apps son gratis
#
# dataset  original:
#
# - GooglePlay: 10841
# - free_android_clean: 8848
#
# - 81,6%  de las apps son gratis

# %% [markdown]
# ## 12. Most Popular Apps by Genre on the App Store
#
# Las tablas de frecuencias que analizamos en la pantalla anterior nos mostraron que la App Store está dominada por aplicaciones diseñadas para la diversión, mientras que Google Play muestra un panorama más equilibrado de aplicaciones tanto prácticas como divertidas.
#
# Ahora, nos gustaría hacernos una idea sobre el tipo de apps con más usuarios.
#
# Una forma de averiguar qué géneros son los más populares (tienen más usuarios) es calcular el número medio de instalaciones de cada género de aplicación. Para el conjunto de datos de Google Play, podemos encontrar esta información en la columna de instalaciones, pero esta información falta para el conjunto de datos de la App Store.
#
# Como solución, tomaremos el número total de valoraciones de los usuarios como proxy, que podemos encontrar en la app **rating_count_column.**
#
# Empecemos por calcular el número medio de valoraciones de los usuarios por género de aplicación en la App Store. Para ello, necesitaremos
#
# Aislar las apps de cada género.
# Sumar las valoraciones de los usuarios de las aplicaciones de ese género.
# Dividir la suma por el número de aplicaciones que pertenecen a ese género (no por el número total de aplicaciones).
# Para calcular el número medio de valoraciones de los usuarios de cada género, utilizaremos un bucle for dentro de otro bucle for. Este es un ejemplo de un bucle for utilizado dentro de otro bucle for:

# %%
some_strings = ['FIRST','SECOND']
some_integers = [1,2,3,4,5]

for string in some_strings:
    print(string)
    
    for integer in some_integers:
        print(integer)
# Out:
# FIRST
# 1
# 2
# 3
# 4
# 5
# SECOND
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Arriba, podemos ver eso:
#
# Primero iteramos sobre la lista some_strings, y para cada iteración:
# Imprimimos la cadena (variable de iteración).
# Iniciamos otra iteración sobre la lista algunos_integros.
# Para cada iteración sobre esta lista, imprimimos entero (variable de iteración).
# Podemos ver que para cada una de las dos iteraciones sobre la lista algunas_cuerdas (hay dos iteraciones porque algunas_cuerdas sólo tiene dos elementos de lista), hay otra iteración interna que ocurre sobre la lista algunos_integros.
#
# La segunda iteración sobre algunas_cuerdas comienza sólo cuando la iteración sobre algunos_integros se ha completado. Observa que todos los elementos de la lista algunos_integros se imprimen para cada una de las dos iteraciones sobre la lista algunas_cadenas.
#
# Un bucle dentro de otro bucle se llama bucle anidado. Usaremos un bucle anidado para calcular los promedios que mencionamos anteriormente.

# %% [markdown]
# **Instrucciones**
#
# 1. Comience generando una tabla de frecuencias para la columna prime_genre para obtener los géneros únicos de las aplicaciones (a continuación, necesitaremos hacer un bucle sobre los géneros únicos). Puede utilizar la función freq_table() que escribió en una pantalla anterior.
#
# 2. Haga un bucle sobre los géneros únicos del conjunto de datos de la App Store. Para cada iteración (a continuación, asumiremos que la variable de iteración se llama género):
#
# - Inicie una variable llamada total con un valor de 0. Esta variable almacenará la suma de las valoraciones de los usuarios (el número de valoraciones, no las valoraciones reales) específicas de cada género.
#
# - Inicie una variable llamada len_genre con un valor de 0. Esta variable almacenará el número de aplicaciones específicas de cada género.
#
# - Realice un bucle sobre el conjunto de datos de la App Store y, en cada iteración, guarde el género de la aplicación en una variable denominada len_genre:
#
#     - Guarda el género de la aplicación en una variable llamada genre_app.
#
#     - Si genre_app es la misma que genre (la variable de iteración del bucle principal), entonces:
#
#         - Guarda el número de valoraciones de los usuarios de la app como un flotador.
#
#         - Suma el número de valoraciones de los usuarios a la variable total.
#
#         - Incrementa la variable len_genre en 1.
#
#
# - Calcule el número medio de valoraciones de los usuarios dividiendo el total entre len_genre. Esto debe hacerse fuera del bucle anidado.
#
# - Imprime el género de la aplicación y el número medio de valoraciones de los usuarios. Esto también debe hacerse fuera del bucle anidado.
#
# 3. Analice los resultados e intente obtener al menos una recomendación de perfil de aplicación para la App Store. Ten en cuenta que aquí no hay una respuesta fija, y que no pasa nada si el perfil de aplicación que recomiendas es diferente al que se recomienda en el cuaderno de soluciones.

# %%
display_table(prime_genre)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 display_table(prime_genre)
#
# NameError: name 'prime_genre' is not defined

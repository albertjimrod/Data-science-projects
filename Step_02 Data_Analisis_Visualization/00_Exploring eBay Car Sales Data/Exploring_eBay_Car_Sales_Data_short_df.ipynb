# %% [markdown]
# # Exploring Ebay Car Sales Data
#
# ![Imgur](https://image.freepik.com/free-vector/automobiles-models-icon-collection_74855-5435.jpg)

# %% [markdown]
# <a href='https://www.freepik.com/'> Automobiles models icon collection Free Vector @ freepik.com </a>

# %% [markdown]
# ## 1. Introduction
#
# Dataset come from eBay Kleinanzeigen, a classifieds section of the German eBay website.
#
# This is the sort version, 50000 rows.
#
# The aim of this project is to clean the data and analyze the included used car listings and answer the following questions:
#
# - What is the average mileage of the vehicles sold on this page?
#
# - What was the period in which the most vehicles were offered for sale on the site?
#
# - Which is the most offered brand? and which is the least?
#
# - What is the highest average number of kilometers per brand?
#
# - What is the most used type of fuel?
#
# - The most offered brands and the model of each brand?

# %% [markdown]
# #### Data dictionary:
#
# - `dateCrawled` - When this ad was first crawled. All field-values are taken from this date.
# - `name` - Name of the car.
# - `seller` - Whether the seller is private or a dealer.
# - `offerType` - The type of listing
# - `price` - The price on the ad to sell the car.
# - `abtest` - Whether the listing is included in an A/B test.
# - `vehicleType` - The vehicle Type.
# - `yearOfRegistration` - The year in which the car was first registered.
# - `gearbox` - The transmission type.
# - `powerPS` - The power of the car in PS.
# - `model` - The car model name.
# - `kilometer` - How many kilometers the car has driven.
# - `monthOfRegistration` - The month in which the car was first registered.
# - `fuelType` - What type of fuel the car uses.
# - `brand` - The brand of the car.
# - `notRepairedDamage`- If the car has a damage which is not yet repaired.
# - `dateCreated` - The date on which the eBay listing was created.
# - `nrOfPictures` - The number of pictures in the ad.
# - `postalCode` - The postal code for the location of the vehicle.
# - `lastSeenOnline` - When the crawler saw this ad last online.

# %%
import numpy as np
import pandas as pd

# %%
autos = pd.read_csv("autos.csv", encoding = "Latin-1" )

# %% [markdown]
# ## 1. Exploring Data

# %%
autos.head(3)
# Out:
#            dateCrawled                                        name  seller  \
# 0  2016-03-26 17:47:46            Peugeot_807_160_NAVTECH_ON_BOARD  privat
# 1  2016-04-04 13:38:56  BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik  privat
# 2  2016-03-26 18:57:24                  Volkswagen_Golf_1.6_United  privat
#
#   offerType   price   abtest vehicleType  yearOfRegistration    gearbox  \
# 0   Angebot  $5,000  control         bus                2004    manuell
# 1   Angebot  $8,500  control   limousine                1997  automatik
# 2   Angebot  $8,990     test   limousine                2009    manuell
#
#    powerPS   model   odometer  monthOfRegistration fuelType       brand  \
# 0      158  andere  150,000km                    3      lpg     peugeot
# 1      286     7er  150,000km                    6   benzin         bmw
# 2      102    golf   70,000km                    7   benzin  volkswagen
#
#   notRepairedDamage          dateCreated  nrOfPictures  postalCode  \
# 0              nein  2016-03-26 00:00:00             0       79588
# 1              nein  2016-04-04 00:00:00             0       71034
# 2              nein  2016-03-26 00:00:00             0       35394
#
#               lastSeen
# 0  2016-04-06 06:45:54
# 1  2016-04-06 14:45:08
# 2  2016-04-06 20:15:37

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50000 non-null  object
#  1   name                 50000 non-null  object
#  2   seller               50000 non-null  object
#  3   offerType            50000 non-null  object
#  4   price                50000 non-null  object
#  5   abtest               50000 non-null  object
#  6   vehicleType          44905 non-null  object
#  7   yearOfRegistration   50000 non-null  int64
#  8   gearbox              47320 non-null  object
#  9   powerPS              50000 non-null  int64
#  10  model                47242 non-null  object
#  11  odometer             50000 non-null  object
#  12  monthOfRegistration  50000 non-null  int64
#  13  fuelType             45518 non-null  object
#  14  brand                50000 non-null  object
#  15  notRepairedDamage    40171 non-null  object
#  16  dateCreated          50000 non-null  object
#  17  nrOfPictures         50000 non-null  int64
#  18  postalCode           50000 non-null  int64
#  19  lastSeen             50000 non-null  object
# dtypes: int64(5), object(15)
# memory usage: 7.6+ MB

# %% [markdown]
# ### Dataset observations:
#
# - There's a 50000 rows and 20 columns.
#
# - Column's name is not properly writed, so we need to lowerCamelCase it.
#
# - Some of the columns are missing data (indicar un porcentage aproximado de los que falta)
#
# - Some of the columns do not have the appropriate data type

# %% [markdown]
# ## 2. Cleaning Column Names
#
# Working on fixing the column names:
#
#    - `yearOfRegistration`  to `registration_year`
#    - `monthOfRegistration` to `registration_month`
#    - `notRepairedDamage`   to `unrepaired_damagè`
#    - `dateCreated`         to `ad_created`

# %%
column_name = autos.columns
column_name
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos.rename({'yearOfRegistration':'registration_year','monthOfRegistration':'registration_month',
             'notRepairedDamage':'unrepaired_damage','dateCreated':'ad_created',},axis = 1, inplace = True)

# %% [markdown]
# - The rest of the column names from camelcase to snakecase.

# %%
autos.rename({'dateCrawled':'date_crawled','price':'price_in_dollars',
              'offerType':'offer_type','vehicleType':'vehicle_type',
              'powerPS':'CV','fuelType':'fuel_type',
              'nrOfPictures':'nr_pictures','postalCode':'postal_code',
              'lastSeen':'last_seen',},axis = 1, inplace = True)

# %%
autos.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price_in_dollars',
#        'abtest', 'vehicle_type', 'registration_year', 'gearbox', 'CV', 'model',
#        'odometer', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'nr_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %% [markdown]
# ### Changes did it on column name
#
# Rename names on snake format, and powerPS are converted to CV (Cavalli Vapore) means 'Horse Power' in metric system, system used in Europe where the dataframe comes (Germany)
#
# based on this [link](https://www.autoweek.com/news/technology/a1820831/what-ps-metric-horsepower-autoweek-explains/)

# %% [markdown]
# ## 3. Initial Exploration and Cleaning.
#
# Now let's do some basic data exploration to determine what other cleaning tasks need to be done.
# Initially we will look for:
#
# - 1. Text columns where all or almost all values are the same. These can often be dropped as they don't have useful information for analysis.
#
#
# - 2. Examples of numeric data stored as text which can be cleaned and converted.

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date_crawled        50000 non-null  object
#  1   name                50000 non-null  object
#  2   seller              50000 non-null  object
#  3   offer_type          50000 non-null  object
#  4   price_in_dollars    50000 non-null  object
#  5   abtest              50000 non-null  object
#  6   vehicle_type        44905 non-null  object
#  7   registration_year   50000 non-null  int64
#  8   gearbox             47320 non-null  object
#  9   CV                  50000 non-null  int64
#  10  model               47242 non-null  object
#  11  odometer            50000 non-null  object
#  12  registration_month  50000 non-null  int64
#  13  fuel_type           45518 non-null  object
#  14  brand               50000 non-null  object
#  15  unrepaired_damage   40171 non-null  object
#  16  ad_created          50000 non-null  object
#  17  nr_pictures         50000 non-null  int64
#  18  postal_code         50000 non-null  int64
#  19  last_seen           50000 non-null  object
# dtypes: int64(5), object(15)
# memory usage: 7.6+ MB

# %%
autos.describe(include = 'all')
# Out:
#                date_crawled         name  seller offer_type price_in_dollars  \
# count                 50000        50000   50000      50000            50000
# unique                48213        38754       2          2             2357
# top     2016-04-02 11:37:04  Ford_Fiesta  privat    Angebot               $0
# freq                      3           78   49999      49999             1421
# mean                    NaN          NaN     NaN        NaN              NaN
# std                     NaN          NaN     NaN        NaN              NaN
# min                     NaN          NaN     NaN        NaN              NaN
# 25%                     NaN          NaN     NaN        NaN              NaN
# 50%                     NaN          NaN     NaN        NaN              NaN
# 75%                     NaN          NaN     NaN        NaN              NaN
# max                     NaN          NaN     NaN        NaN              NaN
#
#        abtest vehicle_type  registration_year  gearbox            CV  model  \
# count   50000        44905       50000.000000    47320  50000.000000  47242
# unique      2            8                NaN        2           NaN    245
# top      test    limousine                NaN  manuell           NaN   golf
# freq    25756        12859                NaN    36993           NaN   4024
# mean      NaN          NaN        2005.073280      NaN    116.355920    NaN
# std       NaN          NaN         105.712813      NaN    209.216627    NaN
# min       NaN          NaN        1000.000000      NaN      0.000000    NaN
# 25%       NaN          NaN        1999.000000      NaN     70.000000    NaN
# 50%       NaN          NaN        2003.000000      NaN    105.000000    NaN
# 75%       NaN          NaN        2008.000000      NaN    150.000000    NaN
# max       NaN          NaN        9999.000000      NaN  17700.000000    NaN
#
#          odometer  registration_month fuel_type       brand unrepaired_damage  \
# count       50000        50000.000000     45518       50000             40171
# unique         13                 NaN         7          40                 2
# top     150,000km                 NaN    benzin  volkswagen              nein
# freq        32424                 NaN     30107       10687             35232
# mean          NaN            5.723360       NaN         NaN               NaN
# std           NaN            3.711984       NaN         NaN               NaN
# min           NaN            0.000000       NaN         NaN               NaN
# 25%           NaN            3.000000       NaN         NaN               NaN
# 50%           NaN            6.000000       NaN         NaN               NaN
# 75%           NaN            9.000000       NaN         NaN               NaN
# max           NaN           12.000000       NaN         NaN               NaN
#
#                  ad_created  nr_pictures   postal_code            last_seen
# count                 50000      50000.0  50000.000000                50000
# unique                   76          NaN           NaN                39481
# top     2016-04-03 00:00:00          NaN           NaN  2016-04-07 06:17:27
# freq                   1946          NaN           NaN                    8
# mean                    NaN          0.0  50813.627300                  NaN
# std                     NaN          0.0  25779.747957                  NaN
# min                     NaN          0.0   1067.000000                  NaN
# 25%                     NaN          0.0  30451.000000                  NaN
# 50%                     NaN          0.0  49577.000000                  NaN
# 75%                     NaN          0.0  71540.000000                  NaN
# max                     NaN          0.0  99998.000000                  NaN

# %% [markdown]
# ### - 1. Text columns where all or almost all values are the same.
#
# We can see some of columns that only have two values and they aren't relevant for our purpuses, like:
#
# - `seller`
# - `offer_type`
# - `nr_picture`
# - `abtest`
#
# Lets see more in detail the content of each columns.

# %%
selected = ['seller','offer_type','nr_pictures','abtest']

for columna in selected: print(autos[columna].value_counts(),'\n')
# Out:
# privat        49999
# gewerblich        1
# Name: seller, dtype: int64
#
# Angebot    49999
# Gesuch         1
# Name: offer_type, dtype: int64
#
# 0    50000
# Name: nr_pictures, dtype: int64
#
# test       25756
# control    24244
# Name: abtest, dtype: int64

# %% [markdown]
# ### Dataset observations:
#
# Columns candidates to be dropped:
#
#
#    `seller`:
#
#         privat(particular owner) = 49999 and gewerblich(comercial) = 1
#
#
#    `offer_type`:
#
#        Angebot(Offer) = 49999 and Gesuch(Wanted) = 1
#
#    `nr_pictures`:
#
#        total number of pictures is 0:
#
#    `abtest`:
#
#        not useful for dataframe study

# %% [markdown]
# ### -2  Numeric data stored as text that needs to be cleaned:
#
# - `price_in_dollars`
#
# - `odometer`
#
# - `ad_created`
#
# - `date_crawled`
#
# - `last_seen`

# %%
autos['price_in_dollars']
# Out:
# 0         $5,000
# 1         $8,500
# 2         $8,990
# 3         $4,350
# 4         $1,350
#           ...
# 49995    $24,900
# 49996     $1,980
# 49997    $13,200
# 49998    $22,900
# 49999     $1,250
# Name: price_in_dollars, Length: 50000, dtype: object

# %%
autos['odometer']
# Out:
# 0        150,000km
# 1        150,000km
# 2         70,000km
# 3         70,000km
# 4        150,000km
#            ...
# 49995    100,000km
# 49996    150,000km
# 49997      5,000km
# 49998     40,000km
# 49999    150,000km
# Name: odometer, Length: 50000, dtype: object

# %% [markdown]
# ### Character deletion and integer conversion

# %%
autos['price_in_dollars'] = autos['price_in_dollars'].str.replace('$', '')
autos['price_in_dollars'] = autos['price_in_dollars'].str.replace(',', '')
autos['price_in_dollars'] = autos['price_in_dollars'].astype(int)
autos['price_in_dollars']
# Out:
# 0         5000
# 1         8500
# 2         8990
# 3         4350
# 4         1350
#          ...
# 49995    24900
# 49996     1980
# 49997    13200
# 49998    22900
# 49999     1250
# Name: price_in_dollars, Length: 50000, dtype: int64

# %% [markdown]
# ### By removing the characters symbolizing the column units, it is possible to indicate in the column name

# %%
autos.rename({'odometer':'odometer_km'}, axis = 1, inplace = True)
autos['odometer_km'] = autos['odometer_km'].str.replace(',','')
autos['odometer_km'] = autos['odometer_km'].str.replace('km','')
autos['odometer_km'] = autos['odometer_km'].astype(int)
autos['odometer_km']
# Out:
# 0        150000
# 1        150000
# 2         70000
# 3         70000
# 4        150000
#           ...
# 49995    100000
# 49996    150000
# 49997      5000
# 49998     40000
# 49999    150000
# Name: odometer_km, Length: 50000, dtype: int64

# %% [markdown]
# ## 4. Exploring the `odometer_km` and `price` columns

# %% [markdown]
# #### 1. Exploring `odometer_km`:
#
# - Number of differents values
# - Descriptive statistics.
# - list of top 10 km groups

# %% [markdown]
# #### Return unique values of `odometer_km`

# %%
autos['odometer_km'].unique().shape
# Out:
# (13,)

# %% [markdown]
# #### Descriptive statistics 'odometer_km'

# %%
autos['odometer_km'].describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %% [markdown]
# #### Upper limit `odometer_km`

# %%
autos['odometer_km'].value_counts().sort_index(ascending = False).head(10)
# Out:
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# 70000      1230
# 60000      1164
# 50000      1027
# 40000       819
# 30000       789
# Name: odometer_km, dtype: int64

# %% [markdown]
# #### Lower limit `odometer_km`

# %%
autos['odometer_km'].value_counts().sort_index(ascending = True).head(10)
# Out:
# 5000      967
# 10000     264
# 20000     784
# 30000     789
# 40000     819
# 50000    1027
# 60000    1164
# 70000    1230
# 80000    1436
# 90000    1757
# Name: odometer_km, dtype: int64

# %% [markdown]
# #### 2. Exploring `price_in_dollars`:
#
# - Number of differents values
# - Descriptive statistics.
# - list of top 10 km groups

# %% [markdown]
# #### Return unique values of `price_in_dollars`

# %%
autos['price_in_dollars'].unique().shape
# Out:
# (2357,)

# %% [markdown]
# #### Descriptive statistics 'price_in_dollars'

# %%
autos['price_in_dollars'].describe().round()
# Out:
# count       50000.0
# mean         9840.0
# std        481104.0
# min             0.0
# 25%          1100.0
# 50%          2950.0
# 75%          7200.0
# max      99999999.0
# Name: price_in_dollars, dtype: float64

# %% [markdown]
# #### Upper limit `price_in_dollars`

# %%
autos['price_in_dollars'].value_counts().sort_index(ascending = False).head(10)
# Out:
# 99999999    1
# 27322222    1
# 12345678    3
# 11111111    2
# 10000000    1
# 3890000     1
# 1300000     1
# 1234566     1
# 999999      2
# 999990      1
# Name: price_in_dollars, dtype: int64

# %% [markdown]
# #### Lower limit `odometer_km`

# %%
autos['price_in_dollars'].value_counts().sort_index(ascending = True).head(10)
# Out:
# 0     1421
# 1      156
# 2        3
# 3        1
# 5        2
# 8        1
# 9        1
# 10       7
# 11       2
# 12       3
# Name: price_in_dollars, dtype: int64

# %% [markdown]
# #### Note:
#
# Let's take a closer look at the top of the column and choose a value that, even though it is high, allows us to have a reference from which to start.

# %% [markdown]
# ### Exploring `price_in_dollars` outliers on the top of the list:

# %%
autos['price_in_dollars'].value_counts().sort_index(ascending = False).head(15)
# Out:
# 99999999    1
# 27322222    1
# 12345678    3
# 11111111    2
# 10000000    1
# 3890000     1
# 1300000     1
# 1234566     1
# 999999      2
# 999990      1
# 350000      1
# 345000      1
# 299000      1
# 295000      1
# 265000      1
# Name: price_in_dollars, dtype: int64

# %% [markdown]
# Let's see to which vehicle the value of 265000$ corresponds.
#
# In the event that this price is consistent with the vehicle, we can take it as a reference.

# %%
autos[autos["price_in_dollars"] == 265000]
# Out:
#               date_crawled                                               name  \
# 12682  2016-03-28 22:48:01  Porsche_GT3_RS__PCCB__Lift___grosser_Exklusiv_...
#
#        seller offer_type  price_in_dollars   abtest vehicle_type  \
# 12682  privat    Angebot            265000  control        coupe
#
#        registration_year    gearbox   CV model  odometer_km  \
# 12682               2016  automatik  500   911         5000
#
#        registration_month fuel_type    brand unrepaired_damage  \
# 12682                   3    benzin  porsche              nein
#
#                 ad_created  nr_pictures  postal_code            last_seen
# 12682  2016-03-28 00:00:00            0        70193  2016-04-05 03:44:51

# %% [markdown]
# It makes sense, so we will use our comparison from this value upwards and see what we find.
#
# https://www.carindigo.com/used-cars/porsche-911-gt3-rs
#
# As there are not too many values to check, it seems sensible to start from this model and see what we can eliminate and what we cannot.
#
# let's see which vehicles are above this one.

# %%
top_List = autos[(autos["price_in_dollars"] >= 265000)].sort_index(ascending = False)
top_List
# Out:
#               date_crawled                                               name  \
# 47634  2016-04-04 21:25:21                                        Ferrari_FXX
# 47598  2016-03-31 18:56:54  Opel_Vectra_B_1_6i_16V_Facelift_Tuning_Showcar...
# 43049  2016-03-21 19:53:52                                      2_VW_Busse_T3
# 42221  2016-03-08 20:39:05                                  Leasinguebernahme
# 39705  2016-03-22 14:58:27                        Tausch_gegen_gleichwertiges
# 39377  2016-03-08 23:53:51                        Tausche_volvo_v40_gegen_van
# 37585  2016-03-29 11:38:54                                Volkswagen_Jetta_GT
# 36818  2016-03-27 18:37:37                                        Porsche_991
# 35923  2016-04-03 07:56:23  Porsche_911_Targa_Exclusive_Edition__1_von_15_...
# 34723  2016-03-23 16:37:29  Porsche_Porsche_911/930_Turbo_3.0__deutsche_Au...
# 27371  2016-03-09 15:45:47                                         Fiat_Punto
# 24384  2016-03-21 13:57:51                            Schlachte_Golf_3_gt_tdi
# 22947  2016-03-22 12:54:19                         Bmw_530d_zum_ausschlachten
# 14715  2016-03-30 08:37:24                 Rolls_Royce_Phantom_Drophead_Coupe
# 12682  2016-03-28 22:48:01  Porsche_GT3_RS__PCCB__Lift___grosser_Exklusiv_...
# 11137  2016-03-29 23:52:57  suche_maserati_3200_gt_Zustand_unwichtig_laufe...
# 7814   2016-04-04 11:53:31                                        Ferrari_F40
# 2897   2016-03-12 21:50:57   Escort_MK_1_Hundeknochen_zum_umbauen_auf_RS_2000
# 514    2016-03-17 09:53:08                   Ford_Focus_Turnier_1.6_16V_Style
#
#        seller offer_type  price_in_dollars   abtest vehicle_type  \
# 47634  privat    Angebot           3890000     test        coupe
# 47598  privat    Angebot          12345678  control    limousine
# 43049  privat    Angebot            999999     test          bus
# 42221  privat    Angebot          27322222  control    limousine
# 39705  privat    Angebot          99999999  control    limousine
# 39377  privat    Angebot          12345678  control          NaN
# 37585  privat    Angebot            999990     test    limousine
# 36818  privat    Angebot            350000  control        coupe
# 35923  privat    Angebot            295000     test       cabrio
# 34723  privat    Angebot            299000     test        coupe
# 27371  privat    Angebot          12345678  control          NaN
# 24384  privat    Angebot          11111111     test          NaN
# 22947  privat    Angebot           1234566  control        kombi
# 14715  privat    Angebot            345000  control       cabrio
# 12682  privat    Angebot            265000  control        coupe
# 11137  privat    Angebot          10000000  control        coupe
# 7814   privat    Angebot           1300000  control        coupe
# 2897   privat    Angebot          11111111     test    limousine
# 514    privat    Angebot            999999     test        kombi
#
#        registration_year    gearbox   CV        model  odometer_km  \
# 47634               2006        NaN  799          NaN         5000
# 47598               2001    manuell  101       vectra       150000
# 43049               1981    manuell   70  transporter       150000
# 42221               2014    manuell  163           c4        40000
# 39705               1999  automatik  224     s_klasse       150000
# 39377               2018    manuell   95          v40       150000
# 37585               1985    manuell  111        jetta       150000
# 36818               2016    manuell  500          911         5000
# 35923               2015  automatik  400          911         5000
# 34723               1977    manuell  260          911       100000
# 27371               2017        NaN   95        punto       150000
# 24384               1995        NaN    0          NaN       150000
# 22947               1999  automatik  190          NaN       150000
# 14715               2012  automatik  460          NaN        20000
# 12682               2016  automatik  500          911         5000
# 11137               1960    manuell  368          NaN       100000
# 7814                1992        NaN    0          NaN        50000
# 2897                1973    manuell   48       escort        50000
# 514                 2009    manuell  101        focus       125000
#
#        registration_month fuel_type           brand unrepaired_damage  \
# 47634                   7       NaN  sonstige_autos              nein
# 47598                   3    benzin            opel              nein
# 43049                   1    benzin      volkswagen               NaN
# 42221                   2    diesel         citroen               NaN
# 39705                   9    benzin   mercedes_benz               NaN
# 39377                   6       NaN           volvo              nein
# 37585                  12    benzin      volkswagen                ja
# 36818                   3    benzin         porsche              nein
# 35923                   6    benzin         porsche              nein
# 34723                   7    benzin         porsche              nein
# 27371                   0       NaN            fiat               NaN
# 24384                   0       NaN      volkswagen               NaN
# 22947                   2    diesel             bmw               NaN
# 14715                   8    benzin  sonstige_autos              nein
# 12682                   3    benzin         porsche              nein
# 11137                   1    benzin  sonstige_autos              nein
# 7814                   12       NaN  sonstige_autos              nein
# 2897                    3    benzin            ford              nein
# 514                     4    benzin            ford              nein
#
#                 ad_created  nr_pictures  postal_code            last_seen
# 47634  2016-04-04 00:00:00            0        60313  2016-04-05 12:07:37
# 47598  2016-03-31 00:00:00            0         4356  2016-03-31 18:56:54
# 43049  2016-03-21 00:00:00            0        99880  2016-03-28 17:18:28
# 42221  2016-03-08 00:00:00            0        76532  2016-03-08 20:39:05
# 39705  2016-03-22 00:00:00            0        73525  2016-04-06 05:15:30
# 39377  2016-03-08 00:00:00            0        14542  2016-04-06 23:17:31
# 37585  2016-03-29 00:00:00            0        50997  2016-03-29 11:38:54
# 36818  2016-03-27 00:00:00            0        70499  2016-03-27 18:37:37
# 35923  2016-04-03 00:00:00            0        74078  2016-04-03 08:56:20
# 34723  2016-03-23 00:00:00            0        61462  2016-04-06 16:44:50
# 27371  2016-03-09 00:00:00            0        96110  2016-03-09 15:45:47
# 24384  2016-03-21 00:00:00            0        18519  2016-03-21 14:40:18
# 22947  2016-03-22 00:00:00            0        17454  2016-04-02 03:17:32
# 14715  2016-03-30 00:00:00            0        73525  2016-04-07 00:16:26
# 12682  2016-03-28 00:00:00            0        70193  2016-04-05 03:44:51
# 11137  2016-03-29 00:00:00            0        73033  2016-04-06 21:18:11
# 7814   2016-04-04 00:00:00            0        60598  2016-04-05 11:34:11
# 2897   2016-03-12 00:00:00            0        94469  2016-03-12 22:45:27
# 514    2016-03-17 00:00:00            0        12205  2016-04-06 07:17:35

# %%
top_List[["price_in_dollars","brand","model","vehicle_type"]].sort_index(ascending = False)
# Out:
#        price_in_dollars           brand        model vehicle_type
# 47634           3890000  sonstige_autos          NaN        coupe
# 47598          12345678            opel       vectra    limousine
# 43049            999999      volkswagen  transporter          bus
# 42221          27322222         citroen           c4    limousine
# 39705          99999999   mercedes_benz     s_klasse    limousine
# 39377          12345678           volvo          v40          NaN
# 37585            999990      volkswagen        jetta    limousine
# 36818            350000         porsche          911        coupe
# 35923            295000         porsche          911       cabrio
# 34723            299000         porsche          911        coupe
# 27371          12345678            fiat        punto          NaN
# 24384          11111111      volkswagen          NaN          NaN
# 22947           1234566             bmw          NaN        kombi
# 14715            345000  sonstige_autos          NaN       cabrio
# 12682            265000         porsche          911        coupe
# 11137          10000000  sonstige_autos          NaN        coupe
# 7814            1300000  sonstige_autos          NaN        coupe
# 2897           11111111            ford       escort    limousine
# 514              999999            ford        focus        kombi

# %% [markdown]
# It seems to be clearer this way, we see that there are vehicles that make sense to be on this list and that others clearly do not, for example:
#
# Strange values of 1234566, corresponding to a BMW or 11111111 to a Volkswagen even a C4 that is worth 27322222.
#
# Clearly, these cases could be eliminated as error.
#
# However, there are some kind of vehicles called 'sonstige autos' (mean other cars in German) that we are not aware of and because they have an important weight in the list it is important to clarify whether or not we should eliminate them.

# %%
top_List[top_List["brand"] == "sonstige_autos"]
# Out:
#               date_crawled                                               name  \
# 47634  2016-04-04 21:25:21                                        Ferrari_FXX
# 14715  2016-03-30 08:37:24                 Rolls_Royce_Phantom_Drophead_Coupe
# 11137  2016-03-29 23:52:57  suche_maserati_3200_gt_Zustand_unwichtig_laufe...
# 7814   2016-04-04 11:53:31                                        Ferrari_F40
#
#        seller offer_type  price_in_dollars   abtest vehicle_type  \
# 47634  privat    Angebot           3890000     test        coupe
# 14715  privat    Angebot            345000  control       cabrio
# 11137  privat    Angebot          10000000  control        coupe
# 7814   privat    Angebot           1300000  control        coupe
#
#        registration_year    gearbox   CV model  odometer_km  \
# 47634               2006        NaN  799   NaN         5000
# 14715               2012  automatik  460   NaN        20000
# 11137               1960    manuell  368   NaN       100000
# 7814                1992        NaN    0   NaN        50000
#
#        registration_month fuel_type           brand unrepaired_damage  \
# 47634                   7       NaN  sonstige_autos              nein
# 14715                   8    benzin  sonstige_autos              nein
# 11137                   1    benzin  sonstige_autos              nein
# 7814                   12       NaN  sonstige_autos              nein
#
#                 ad_created  nr_pictures  postal_code            last_seen
# 47634  2016-04-04 00:00:00            0        60313  2016-04-05 12:07:37
# 14715  2016-03-30 00:00:00            0        73525  2016-04-07 00:16:26
# 11137  2016-03-29 00:00:00            0        73033  2016-04-06 21:18:11
# 7814   2016-04-04 00:00:00            0        60598  2016-04-05 11:34:11

# %% [markdown]
# High-end vehicles with a very high market value are appearing, will have to be reviewed.

# %% [markdown]
# | name | price in Dollars |registration_year | source |
# | :--- | :----------- |:------ | :--- |
# | Ferrari_FXX | 4,000,000| 2006 |https://www.autoblog.com/2006/06/14/for-sale-2006-ferrari-fxx-slightly-used/?guccounter=1 |
# | Rolls_Royce_Phantom_Drophead_Coupe | From 450,000 | 2012 | https://www.cars.com/shopping/rolls_royce-phantom_drophead_coupe-2012/ |
# |Ferrari_F40| 1,959,900 |1992 | https://www.dupontregistry.com/autos/listing/1992/ferrari/f40/2418434 |
# |Maserati 3200 GT|  | |  **Note** |

# %% [markdown]
# **Note**: In relation to the Maserati, there are several things to consider.
#
#
# - The [3200 Gt](https://es.wikipedia.org/wiki/Maserati_3200_GT) model was in production during the period 1998 to 2001 so the registration date we have from 1960 does not match, however, during the period 1957 - 1964 only one model of this brand was produced, the  [3500 Gt](https://en.wikipedia.org/wiki/Maserati_3500_GT#:~:text=The%20Maserati%203500%20GT%20(Tipo,Maserati%20between%201957%20and%201964.), only 2,222 units were produced between the Coupe and the Spider version.
#
# - If we also take into account the description referred to in the cell of the name:
#
#      ***" Zustand_unwichtig_laufe... // Condition_unimportant_running..."***
#
#
# - The person who placed the advert was looking for a masserati in any condition (just running or not...), this gives us a clue that the model we are talking about is not the newest one, so probably refers to the 60's model.
#
# - As if this were not enough the price we have is 10 000 000 dollars and surely this is wrong because doing a search of what is the value of the car [I have found that this ranges between 863.170,50 USD / 151.290,57 USD](https://www.el-parking.es/coches-usados/maserati-3500-gt.html#!/coches-usados/maserati-3500-gt.html%3Ftri%3Dprix_decroissant)
#
# Therefore, the best thing I can think of is assign the <strong>'average between prices'</strong> to our vehicle.

# %%
autos.iloc[11137,:]
# Out:
# date_crawled                                        2016-03-29 23:52:57
# name                  suche_maserati_3200_gt_Zustand_unwichtig_laufe...
# seller                                                           privat
# offer_type                                                      Angebot
# price_in_dollars                                               10000000
# abtest                                                          control
# vehicle_type                                                      coupe
# registration_year                                                  1960
# gearbox                                                         manuell
# CV                                                                  368
# model                                                               NaN
# odometer_km                                                      100000
# registration_month                                                    1
# fuel_type                                                        benzin
# brand                                                    sonstige_autos
# unrepaired_damage                                                  nein
# ad_created                                          2016-03-29 00:00:00
# nr_pictures                                                           0
# postal_code                                                       73033
# last_seen                                           2016-04-06 21:18:11
# Name: 11137, dtype: object

# %% [markdown]
# Change the **'average between prices'** price of the Masserati = 507230$

# %%
autos.iloc[11137,4] = 507230

# %% [markdown]
# ### So... finally what do we have to remove from this top list?
#
# Everything other than 'Sonstige_autos' and 'Porsche'

# %%
remove_bad_price_bool = ((top_List["brand"] != 'sonstige_autos') & (top_List["brand"] != 'porsche'))

# %%
bad_cars = top_List[remove_bad_price_bool] # type dataframe! This is the dataframe to remove from check_price
bad_cars
# Out:
#               date_crawled                                               name  \
# 47598  2016-03-31 18:56:54  Opel_Vectra_B_1_6i_16V_Facelift_Tuning_Showcar...
# 43049  2016-03-21 19:53:52                                      2_VW_Busse_T3
# 42221  2016-03-08 20:39:05                                  Leasinguebernahme
# 39705  2016-03-22 14:58:27                        Tausch_gegen_gleichwertiges
# 39377  2016-03-08 23:53:51                        Tausche_volvo_v40_gegen_van
# 37585  2016-03-29 11:38:54                                Volkswagen_Jetta_GT
# 27371  2016-03-09 15:45:47                                         Fiat_Punto
# 24384  2016-03-21 13:57:51                            Schlachte_Golf_3_gt_tdi
# 22947  2016-03-22 12:54:19                         Bmw_530d_zum_ausschlachten
# 2897   2016-03-12 21:50:57   Escort_MK_1_Hundeknochen_zum_umbauen_auf_RS_2000
# 514    2016-03-17 09:53:08                   Ford_Focus_Turnier_1.6_16V_Style
#
#        seller offer_type  price_in_dollars   abtest vehicle_type  \
# 47598  privat    Angebot          12345678  control    limousine
# 43049  privat    Angebot            999999     test          bus
# 42221  privat    Angebot          27322222  control    limousine
# 39705  privat    Angebot          99999999  control    limousine
# 39377  privat    Angebot          12345678  control          NaN
# 37585  privat    Angebot            999990     test    limousine
# 27371  privat    Angebot          12345678  control          NaN
# 24384  privat    Angebot          11111111     test          NaN
# 22947  privat    Angebot           1234566  control        kombi
# 2897   privat    Angebot          11111111     test    limousine
# 514    privat    Angebot            999999     test        kombi
#
#        registration_year    gearbox   CV        model  odometer_km  \
# 47598               2001    manuell  101       vectra       150000
# 43049               1981    manuell   70  transporter       150000
# 42221               2014    manuell  163           c4        40000
# 39705               1999  automatik  224     s_klasse       150000
# 39377               2018    manuell   95          v40       150000
# 37585               1985    manuell  111        jetta       150000
# 27371               2017        NaN   95        punto       150000
# 24384               1995        NaN    0          NaN       150000
# 22947               1999  automatik  190          NaN       150000
# 2897                1973    manuell   48       escort        50000
# 514                 2009    manuell  101        focus       125000
#
#        registration_month fuel_type          brand unrepaired_damage  \
# 47598                   3    benzin           opel              nein
# 43049                   1    benzin     volkswagen               NaN
# 42221                   2    diesel        citroen               NaN
# 39705                   9    benzin  mercedes_benz               NaN
# 39377                   6       NaN          volvo              nein
# 37585                  12    benzin     volkswagen                ja
# 27371                   0       NaN           fiat               NaN
# 24384                   0       NaN     volkswagen               NaN
# 22947                   2    diesel            bmw               NaN
# 2897                    3    benzin           ford              nein
# 514                     4    benzin           ford              nein
#
#                 ad_created  nr_pictures  postal_code            last_seen
# 47598  2016-03-31 00:00:00            0         4356  2016-03-31 18:56:54
# 43049  2016-03-21 00:00:00            0        99880  2016-03-28 17:18:28
# 42221  2016-03-08 00:00:00            0        76532  2016-03-08 20:39:05
# 39705  2016-03-22 00:00:00            0        73525  2016-04-06 05:15:30
# 39377  2016-03-08 00:00:00            0        14542  2016-04-06 23:17:31
# 37585  2016-03-29 00:00:00            0        50997  2016-03-29 11:38:54
# 27371  2016-03-09 00:00:00            0        96110  2016-03-09 15:45:47
# 24384  2016-03-21 00:00:00            0        18519  2016-03-21 14:40:18
# 22947  2016-03-22 00:00:00            0        17454  2016-04-02 03:17:32
# 2897   2016-03-12 00:00:00            0        94469  2016-03-12 22:45:27
# 514    2016-03-17 00:00:00            0        12205  2016-04-06 07:17:35

# %%
len(bad_cars)
# Out:
# 11

# %%
for bad in bad_cars.index:
    autos.drop([bad], inplace = True)

# %% [markdown]
# ### Exploring price outliers on the botton of the list:

# %%
autos["price_in_dollars"].describe().round()
# Out:
# count      49989.0
# mean        5835.0
# std        20520.0
# min            0.0
# 25%         1100.0
# 50%         2950.0
# 75%         7200.0
# max      3890000.0
# Name: price_in_dollars, dtype: float64

# %% [markdown]
# We see that the minimum value is 0 and until we do not reach 25% of the total dataset the price does not reach 1100€.

# %%
autos["price_in_dollars"].value_counts().sort_index(ascending = False)
# Out:
# 3890000       1
# 1300000       1
# 507230        1
# 350000        1
# 345000        1
#            ...
# 5             2
# 3             1
# 2             3
# 1           156
# 0          1421
# Name: price_in_dollars, Length: 2350, dtype: int64

# %% [markdown]
# Let's see if prices vary a lot or if they are very spread out within this range (25%).

# %%
autos[autos['price_in_dollars'].between(0,1100)].describe()
# Out:
#        price_in_dollars  registration_year            CV    odometer_km  \
# count      12538.000000       12538.000000  12538.000000   12538.000000
# mean         556.422396        2002.788563     74.677461  136162.466103
# std          339.147087         146.343951    174.629327   34988.383373
# min            0.000000        1111.000000      0.000000    5000.000000
# 25%          300.000000        1996.000000     45.000000  150000.000000
# 50%          599.000000        1999.000000     71.000000  150000.000000
# 75%          850.000000        2001.000000    101.000000  150000.000000
# max         1100.000000        9999.000000  15016.000000  150000.000000
#
#        registration_month  nr_pictures   postal_code
# count        12538.000000      12538.0  12538.000000
# mean             4.831552          0.0  47992.659595
# std              3.947714          0.0  25833.421398
# min              0.000000          0.0   1069.000000
# 25%              1.000000          0.0  27376.250000
# 50%              4.000000          0.0  46240.000000
# 75%              8.000000          0.0  66482.000000
# max             12.000000          0.0  99988.000000

# %% [markdown]
# if i want to know what is the total sum of the price of these vehicles in the different price ranges
#
# i.e. how much 75 of the 25 of the total means

# %%
seventy_five = autos[autos['price_in_dollars'].between(850,1100)]
seventy_five.loc[:,'price_in_dollars'].sum()
# Out:
# 3227534

# %% [markdown]
# how much 50 out of 25 of the total amount means

# %%
fifty_percent = autos[autos['price_in_dollars'].between(599,850)]
fifty_percent.loc[:,'price_in_dollars'].sum()
# Out:
# 2462601

# %% [markdown]
# how much 25 out of 25 of the total amount means

# %%
cuart = autos[autos['price_in_dollars'].between(300,599)]
cuart.loc[:,'price_in_dollars'].sum()
# Out:
# 1431649

# %% [markdown]
# What is the sum of the price of the entire data set without taking into account the range 0 to 25

# %%
sum_total_dataset = autos[autos['price_in_dollars'].between(1100,10000000)]
sum_total_dataset.loc[:,'price_in_dollars'].sum()
# Out:
# 285130563

# %% [markdown]
# In this way the importance in the overall data set can be compared.
#
#
# | price ranges | price in Dollars | percentage over total |
# | :---          | :-----  | :-----      |
# | [850 ~  1100] | 3227534 | 1,095478069 % |
# | [599 ~ 850]   | 2462601 | 0,835847241 % |
# | [300 ~ 599]   | 1431649 | 0,485925193 % |

# %% [markdown]
# It seems that it is not too relevant, so in order to take advantage of the maximum amount of information I will take into account a range that goes from the maximum that we have already defined before to a minimum price of **850 €.**

# %% [markdown]
# Once we have the data concerning the prices worked, both at the top and at the bottom, we make a clean copy of our dataframe and call it:
#
#
# - `auto_clean`

# %%
auto_clean = autos[autos['price_in_dollars'].between(850,10000000)].copy()

# %%
auto_clean['price_in_dollars'].describe().round()
# Out:
# count      40786.0
# mean        7060.0
# std        22537.0
# min          850.0
# 25%         1950.0
# 50%         3999.0
# 75%         8500.0
# max      3890000.0
# Name: price_in_dollars, dtype: float64

# %% [markdown]
# ## 5. Exploring the date columns

# %%
auto_clean[['date_crawled','ad_created','last_seen']].describe()
# Out:
#                date_crawled           ad_created            last_seen
# count                 40786                40786                40786
# unique                39611                   76                32824
# top     2016-04-04 16:40:33  2016-04-03 00:00:00  2016-04-06 21:17:51
# freq                      3                 1608                    7

# %%
print(auto_clean['date_crawled'].str[:10].value_counts(normalize=True, dropna=False).sort_index(ascending = True))
# Out:
# 2016-03-05    0.025573
# 2016-03-06    0.014147
# 2016-03-07    0.035600
# 2016-03-08    0.032683
# 2016-03-09    0.032462
# 2016-03-10    0.033075
# 2016-03-11    0.032658
# 2016-03-12    0.037415
# 2016-03-13    0.016035
# 2016-03-14    0.036434
# 2016-03-15    0.033639
# 2016-03-16    0.029177
# 2016-03-17    0.030770
# 2016-03-18    0.012921
# 2016-03-19    0.035110
# 2016-03-20    0.038028
# 2016-03-21    0.037439
# 2016-03-22    0.032805
# 2016-03-23    0.032315
# 2016-03-24    0.028956
# 2016-03-25    0.030721
# 2016-03-26    0.032879
# 2016-03-27    0.031310
# 2016-03-28    0.035208
# 2016-03-29    0.033713
# 2016-03-30    0.033100
# 2016-03-31    0.031261
# 2016-04-01    0.034424
# 2016-04-02    0.036238
# 2016-04-03    0.039156
# 2016-04-04    0.036802
# 2016-04-05    0.013264
# 2016-04-06    0.003212
# 2016-04-07    0.001471
# Name: date_crawled, dtype: float64

# %%
print(auto_clean['ad_created'].str[:10].sort_index(ascending = False).value_counts(normalize=True, dropna=False))
# Out:
# 2016-04-03    0.039425
# 2016-03-20    0.038150
# 2016-03-21    0.037684
# 2016-03-12    0.037268
# 2016-04-04    0.037194
#                 ...
# 2016-02-16    0.000025
# 2016-02-22    0.000025
# 2016-01-29    0.000025
# 2016-02-09    0.000025
# 2016-02-26    0.000025
# Name: ad_created, Length: 76, dtype: float64

# %% [markdown]
# Between March and April 2016 there was the highest concentration of vehicles for sale ads.

# %%
print(auto_clean['last_seen'].str[:10].value_counts(normalize=True, dropna=False).sort_index(ascending = True))
# Out:
# 2016-03-05    0.001128
# 2016-03-06    0.003800
# 2016-03-07    0.004781
# 2016-03-08    0.006522
# 2016-03-09    0.009121
# 2016-03-10    0.010126
# 2016-03-11    0.011622
# 2016-03-12    0.022753
# 2016-03-13    0.008581
# 2016-03-14    0.012038
# 2016-03-15    0.015103
# 2016-03-16    0.015618
# 2016-03-17    0.026700
# 2016-03-18    0.007478
# 2016-03-19    0.014932
# 2016-03-20    0.019811
# 2016-03-21    0.020301
# 2016-03-22    0.020988
# 2016-03-23    0.018266
# 2016-03-24    0.018928
# 2016-03-25    0.018143
# 2016-03-26    0.015961
# 2016-03-27    0.014858
# 2016-03-28    0.019786
# 2016-03-29    0.021061
# 2016-03-30    0.023537
# 2016-03-31    0.022998
# 2016-04-01    0.022998
# 2016-04-02    0.025425
# 2016-04-03    0.024567
# 2016-04-04    0.023537
# 2016-04-05    0.129554
# 2016-04-06    0.231550
# 2016-04-07    0.137425
# Name: last_seen, dtype: float64

# %%
auto_clean['registration_year'].describe()
# Out:
# count    40786.000000
# mean      2005.389864
# std         84.381634
# min       1000.000000
# 25%       2000.000000
# 50%       2005.000000
# 75%       2009.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %%
auto_clean['registration_year'].value_counts().sort_index(ascending = False).head(25)
# Out:
# 9999       2
# 9000       1
# 8888       1
# 6200       1
# 5911       1
# 5000       2
# 4500       1
# 4100       1
# 2800       1
# 2019       1
# 2018     435
# 2017    1113
# 2016     733
# 2015     362
# 2014     649
# 2013     795
# 2012    1306
# 2011    1617
# 2010    1585
# 2009    2076
# 2008    2205
# 2007    2261
# 2006    2660
# 2005    2816
# 2004    2645
# Name: registration_year, dtype: int64

# %%
auto_clean['registration_year']
# Out:
# 0        2004
# 1        1997
# 2        2009
# 3        2007
# 4        2003
#          ...
# 49995    2011
# 49996    1996
# 49997    2014
# 49998    2013
# 49999    1996
# Name: registration_year, Length: 40786, dtype: int64

# %% [markdown]
# The maximum and minimum dates are wrong, we must find out which are the values to work with.
#
# We see that beyond 2019 the values of the dates do not make sense, however we must remember that the data capture was done in 2016 so 2019 would be a date that would be equally wrong and we should limit the highest year to 2016.

# %%
auto_clean['registration_year'].value_counts().sort_index(ascending = False).tail(5)
# Out:
# 1931    1
# 1929    1
# 1927    1
# 1001    1
# 1000    1
# Name: registration_year, dtype: int64

# %% [markdown]
# At the bottom, the minimum meaningful value is 1927, so our dataset should be between 1927 and 2019.

# %%
auto_clean = auto_clean[auto_clean['registration_year'].between(1927,2016)].copy()

# %%
auto_clean['registration_year'].describe()
# Out:
# count    39224.000000
# mean      2003.713619
# std          7.022507
# min       1927.000000
# 25%       2000.000000
# 50%       2004.000000
# 75%       2008.000000
# max       2016.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# Once we have corrected the incorrect values we have that our 75% of the vehicles were registered in 2008.

# %%
auto_clean['registration_year'].value_counts(normalize=True, dropna=False, bins = 20).sort_index(ascending = False).round(3)
# Out:
# (2011.55, 2016.0]     0.098
# (2007.1, 2011.55]     0.191
# (2002.65, 2007.1]     0.330
# (1998.2, 2002.65]     0.225
# (1993.75, 1998.2]     0.104
# (1989.3, 1993.75]     0.024
# (1984.85, 1989.3]     0.011
# (1980.4, 1984.85]     0.004
# (1975.95, 1980.4]     0.005
# (1971.5, 1975.95]     0.002
# (1967.05, 1971.5]     0.003
# (1962.6, 1967.05]     0.002
# (1958.15, 1962.6]     0.001
# (1953.7, 1958.15]     0.000
# (1949.25, 1953.7]     0.000
# (1944.8, 1949.25]     0.000
# (1940.35, 1944.8]     0.000
# (1935.9, 1940.35]     0.000
# (1931.45, 1935.9]     0.000
# (1926.91, 1931.45]    0.000
# Name: registration_year, dtype: float64

# %% [markdown]
# This is the distribution of the dates of registration by groups of 20, in which we can see how the period between 2002 and 2007 is the one with the highest number of registrations.

# %% [markdown]
# ## 7. Exploring Price by Brand
#
# Brands with the highest number of vehicles on the sales list

# %%
top_ten_brands=auto_clean['brand'].value_counts()
top_ten_brands
# Out:
# volkswagen        8249
# bmw               4761
# mercedes_benz     4258
# audi              3724
# opel              3656
# ford              2398
# renault           1559
# peugeot           1105
# fiat               868
# skoda              721
# seat               701
# smart              635
# mazda              559
# toyota             558
# citroen            555
# nissan             554
# hyundai            413
# mini               406
# sonstige_autos     399
# volvo              358
# kia                296
# honda              294
# mitsubishi         281
# porsche            278
# alfa_romeo         255
# chevrolet          252
# suzuki             232
# chrysler           131
# dacia              122
# jeep               105
# land_rover          98
# daihatsu            77
# subaru              73
# jaguar              69
# saab                57
# daewoo              42
# trabant             36
# rover               33
# lancia              31
# lada                25
# Name: brand, dtype: int64

# %%
selected_brands=auto_clean['brand'].value_counts().index[:10]

# %% [markdown]
# ### Average price per vehicle brand

# %%
brands_price = {}

for brand in selected_brands:
    sel_brand = auto_clean[auto_clean['brand'] == brand ]
    brands_price[brand] = sel_brand['price_in_dollars'].mean().round()

brands_price_sorted = sorted(brands_price.items(),key = lambda kv: kv[1],reverse=True)
brands_price_sorted
# Out:
# [('audi', 10088.0),
#  ('mercedes_benz', 9094.0),
#  ('bmw', 8952.0),
#  ('skoda', 6739.0),
#  ('volkswagen', 6364.0),
#  ('ford', 4939.0),
#  ('opel', 3911.0),
#  ('peugeot', 3772.0),
#  ('fiat', 3710.0),
#  ('renault', 3297.0)]

# %% [markdown]
# ### Average number of kilometers per brand

# %%
brands_km = {}

for brand in sorted(selected_brands):
    sel_brand = auto_clean[auto_clean['brand'] == brand ]
    brands_km[brand] = sel_brand['odometer_km'].mean().round()

brands_km_sorted = sorted(brands_km.items(),key = lambda kv: kv[1], reverse=True)
brands_km_sorted
# Out:
# [('bmw', 132200.0),
#  ('mercedes_benz', 130461.0),
#  ('audi', 128012.0),
#  ('volkswagen', 126561.0),
#  ('opel', 125495.0),
#  ('peugeot', 123362.0),
#  ('renault', 123307.0),
#  ('ford', 121253.0),
#  ('fiat', 110478.0),
#  ('skoda', 110430.0)]

# %% [markdown]
# ### List of car brands by average price and average mileage

# %%
listado = {}

template_string = "Mean price {money:.2f}$ and {km:.2f} mean Kilometers"

for vehiculo in brands_price:
    mean_price = brands_price[vehiculo]
    mean_km = brands_km[vehiculo]
    output = template_string.format(money = mean_price, km = mean_km )
    listado[vehiculo] = output
    

listado
# Out:
# {'volkswagen': 'Mean price 6364.00$ and 126561.00 mean Kilometers',
#  'bmw': 'Mean price 8952.00$ and 132200.00 mean Kilometers',
#  'mercedes_benz': 'Mean price 9094.00$ and 130461.00 mean Kilometers',
#  'audi': 'Mean price 10088.00$ and 128012.00 mean Kilometers',
#  'opel': 'Mean price 3911.00$ and 125495.00 mean Kilometers',
#  'ford': 'Mean price 4939.00$ and 121253.00 mean Kilometers',
#  'renault': 'Mean price 3297.00$ and 123307.00 mean Kilometers',
#  'peugeot': 'Mean price 3772.00$ and 123362.00 mean Kilometers',
#  'fiat': 'Mean price 3710.00$ and 110478.00 mean Kilometers',
#  'skoda': 'Mean price 6739.00$ and 110430.00 mean Kilometers'}

# %%
brands_price
# Out:
# {'volkswagen': 6364.0,
#  'bmw': 8952.0,
#  'mercedes_benz': 9094.0,
#  'audi': 10088.0,
#  'opel': 3911.0,
#  'ford': 4939.0,
#  'renault': 3297.0,
#  'peugeot': 3772.0,
#  'fiat': 3710.0,
#  'skoda': 6739.0}

# %%
brands_km
# Out:
# {'audi': 128012.0,
#  'bmw': 132200.0,
#  'fiat': 110478.0,
#  'ford': 121253.0,
#  'mercedes_benz': 130461.0,
#  'opel': 125495.0,
#  'peugeot': 123362.0,
#  'renault': 123307.0,
#  'skoda': 110430.0,
#  'volkswagen': 126561.0}

# %%
brands_price
brands_km

frame = {'brands average price':brands_price,
         'brands average kilometer':brands_km}

output = pd.DataFrame(frame)
output
# Out:
#                brands average price  brands average kilometer
# volkswagen                   6364.0                  126561.0
# bmw                          8952.0                  132200.0
# mercedes_benz                9094.0                  130461.0
# audi                        10088.0                  128012.0
# opel                         3911.0                  125495.0
# ford                         4939.0                  121253.0
# renault                      3297.0                  123307.0
# peugeot                      3772.0                  123362.0
# fiat                         3710.0                  110478.0
# skoda                        6739.0                  110430.0

# %% [markdown]
# list of car brands by number of vehicles with their average price and average mileage

# %% [markdown]
# ## 8. Storing Aggregate Data in a DataFrame

# %%
brands_price_series = pd.Series(brands_price)
print(brands_price_series)
# Out:
# volkswagen        6364.0
# bmw               8952.0
# mercedes_benz     9094.0
# audi             10088.0
# opel              3911.0
# ford              4939.0
# renault           3297.0
# peugeot           3772.0
# fiat              3710.0
# skoda             6739.0
# dtype: float64

# %%
brands_km_series = pd.Series(brands_km)
print(brands_km_series)
# Out:
# audi             128012.0
# bmw              132200.0
# fiat             110478.0
# ford             121253.0
# mercedes_benz    130461.0
# opel             125495.0
# peugeot          123362.0
# renault          123307.0
# skoda            110430.0
# volkswagen       126561.0
# dtype: float64

# %%
brands_price_series
brands_km_series

frame = {'mean_price':brands_price_series,
        'mean_kilometers':brands_km_series}

output = pd.DataFrame(frame)
output
# Out:
#                mean_price  mean_kilometers
# audi              10088.0         128012.0
# bmw                8952.0         132200.0
# fiat               3710.0         110478.0
# ford               4939.0         121253.0
# mercedes_benz      9094.0         130461.0
# opel               3911.0         125495.0
# peugeot            3772.0         123362.0
# renault            3297.0         123307.0
# skoda              6739.0         110430.0
# volkswagen         6364.0         126561.0

# %% [markdown]
# List of car brands by highest price, their average price and average mileage.

# %% [markdown]
# ## 9. Next Steps
#
# ### 9.1 Identify categorical data
#
# Using German words, translate them and map the values to their equivalents, in this case to Spanish, because there are categories that are unknown here.

# %%
 auto_clean['vehicle_type'].value_counts(dropna = False)
# Out:
# limousine     11059
# kombi          7891
# kleinwagen     7613
# bus            3797
# cabrio         2893
# coupe          2243
# suv            1937
# NaN            1482
# andere          309
# Name: vehicle_type, dtype: int64

# %%
auto_clean['vehicle_type'].value_counts().dropna()
# Out:
# limousine     11059
# kombi          7891
# kleinwagen     7613
# bus            3797
# cabrio         2893
# coupe          2243
# suv            1937
# andere          309
# Name: vehicle_type, dtype: int64

# %%
categorical_vehicle_type = auto_clean['vehicle_type'].value_counts().index[:]

# %%
category_translator = {'bus':'monovolumen','limousine':'sedan', 'kleinwagen':'compacto','kombi':'familiar',
                       'coupe':'coupe','suv':'suv','cabrio':'cabrio','andere':'otros'}

# %%
for category in categorical_vehicle_type:
    bool_category = auto_clean['vehicle_type'] == category
    auto_clean.loc[bool_category,'vehicle_type'] = category_translator[category]

# %%
auto_clean.head(5)
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type  price_in_dollars   abtest vehicle_type  \
# 0  privat    Angebot              5000  control  monovolumen
# 1  privat    Angebot              8500  control        sedan
# 2  privat    Angebot              8990     test        sedan
# 3  privat    Angebot              4350  control     compacto
# 4  privat    Angebot              1350     test     familiar
#
#    registration_year    gearbox   CV   model  odometer_km  registration_month  \
# 0               2004    manuell  158  andere       150000                   3
# 1               1997  automatik  286     7er       150000                   6
# 2               2009    manuell  102    golf        70000                   7
# 3               2007  automatik   71  fortwo        70000                   6
# 4               2003    manuell    0   focus       150000                   7
#
#   fuel_type       brand unrepaired_damage           ad_created  nr_pictures  \
# 0       lpg     peugeot              nein  2016-03-26 00:00:00            0
# 1    benzin         bmw              nein  2016-04-04 00:00:00            0
# 2    benzin  volkswagen              nein  2016-03-26 00:00:00            0
# 3    benzin       smart              nein  2016-03-12 00:00:00            0
# 4    benzin        ford              nein  2016-04-01 00:00:00            0
#
#    postal_code            last_seen
# 0        79588  2016-04-06 06:45:54
# 1        71034  2016-04-06 14:45:08
# 2        35394  2016-04-06 20:15:37
# 3        33729  2016-03-15 03:16:28
# 4        39218  2016-04-01 14:38:50

# %%
auto_clean['vehicle_type'].describe()
# Out:
# count     37742
# unique        8
# top       sedan
# freq      11059
# Name: vehicle_type, dtype: object

# %% [markdown]
# ### fuel_type column

# %%
auto_clean['fuel_type'].value_counts(dropna = False)
# Out:
# benzin     22913
# diesel     13571
# NaN         2026
# lpg          586
# cng           63
# hybrid        37
# elektro       17
# andere        11
# Name: fuel_type, dtype: int64

# %%
auto_clean['fuel_type'].value_counts().dropna()
# Out:
# benzin     22913
# diesel     13571
# lpg          586
# cng           63
# hybrid        37
# elektro       17
# andere        11
# Name: fuel_type, dtype: int64

# %%
auto_clean['fuel_type'].describe()
# Out:
# count      37198
# unique         7
# top       benzin
# freq       22913
# Name: fuel_type, dtype: object

# %%
#auto_clean.loc['fuel_type'] = auto_clean['fuel_type'].value_counts().dropna().copy()

# %%
auto_clean[auto_clean['fuel_type'] == 'andere']
# Out:
#               date_crawled                                               name  \
# 4220   2016-03-17 15:49:34                                         Ford_focus
# 9494   2016-03-19 17:36:18                                  Mercedes_Benz_200
# 12066  2016-03-10 03:01:55                             Wohnwagen_LMC__10_2009
# 24358  2016-03-28 12:53:43                                 Mazda_Rx8_4950_VB
# 27772  2016-03-17 16:36:19  Wartburg_Wartburg_353__2_Takter__Oldtimergutac...
# 29824  2016-03-16 01:48:03                                     Piaggio_Ape_50
# 35050  2016-03-22 13:51:53  Citroen_Berlingo_Chrono_Multispace_Raum_/_Spar...
# 35486  2016-03-22 11:50:33                          Trabi_Kombi...._Tuning...
# 38252  2016-03-20 20:14:08         Mercedes_Benz_200_Elegance_Vollausstattung
# 42288  2016-03-20 19:37:02  Trabant_de_Luxe_Limousine__Fahrbereit__TÜV_bis...
# 49589  2016-03-25 16:49:57                             Opel_Omega_Caravan_2.0
#
#        seller offer_type  price_in_dollars   abtest vehicle_type  \
# 4220   privat    Angebot               900     test        sedan
# 9494   privat    Angebot              8000  control        sedan
# 12066  privat    Angebot              9700  control        otros
# 24358  privat    Angebot              4950     test        otros
# 27772  privat    Angebot              2900     test        sedan
# 29824  privat    Angebot              4800     test        otros
# 35050  privat    Angebot               850  control        otros
# 35486  privat    Angebot              1700  control     familiar
# 38252  privat    Angebot              8000     test        sedan
# 42288  privat    Angebot               999     test        sedan
# 49589  privat    Angebot               850  control     familiar
#
#        registration_year    gearbox   CV     model  odometer_km  \
# 4220                2002    manuell   85     focus       150000
# 9494                2003  automatik  163    andere       150000
# 12066               2009        NaN    0       NaN         5000
# 24358               2004    manuell  231  rx_reihe       150000
# 27772               1985        NaN    0       NaN        80000
# 29824               2014    manuell    3       NaN         5000
# 35050               2001        NaN    0    andere       150000
# 35486               1989    manuell   26       NaN       100000
# 38252               2003  automatik  163    andere       150000
# 42288               1990    manuell   26       601        40000
# 49589               1995    manuell    0     omega       150000
#
#        registration_month fuel_type           brand unrepaired_damage  \
# 4220                   10    andere            ford              nein
# 9494                    9    andere   mercedes_benz              nein
# 12066                  10    andere  sonstige_autos               NaN
# 24358                   6    andere           mazda              nein
# 27772                  12    andere  sonstige_autos              nein
# 29824                   9    andere  sonstige_autos              nein
# 35050                   0    andere         citroen               NaN
# 35486                   1    andere         trabant              nein
# 38252                   9    andere   mercedes_benz              nein
# 42288                   8    andere         trabant              nein
# 49589                  11    andere            opel              nein
#
#                 ad_created  nr_pictures  postal_code            last_seen
# 4220   2016-03-17 00:00:00            0        40233  2016-04-06 23:46:59
# 9494   2016-03-19 00:00:00            0        60326  2016-04-07 03:17:50
# 12066  2016-03-10 00:00:00            0        26789  2016-03-15 14:46:26
# 24358  2016-03-28 00:00:00            0        32339  2016-04-06 16:15:26
# 27772  2016-03-17 00:00:00            0        27711  2016-03-17 17:40:13
# 29824  2016-03-15 00:00:00            0        86825  2016-04-05 23:16:43
# 35050  2016-03-22 00:00:00            0        23829  2016-03-28 03:47:05
# 35486  2016-03-22 00:00:00            0        35305  2016-04-06 19:48:31
# 38252  2016-03-19 00:00:00            0        60326  2016-04-07 04:17:41
# 42288  2016-03-13 00:00:00            0        39579  2016-03-31 04:53:06
# 49589  2016-03-25 00:00:00            0        40468  2016-03-27 04:16:35

# %%
categorical_type_fuel = auto_clean['fuel_type'].value_counts().index[:]
categorical_type_fuel.value_counts()
# Out:
# lpg        1
# andere     1
# elektro    1
# diesel     1
# benzin     1
# cng        1
# hybrid     1
# dtype: int64

# %% [markdown]
# the categories we have in our dataset

# %%
categorical_type_fuel_translator = {'benzin':'gasolina', 'diesel':'diesel', 'lpg':'lpg', 'cng':'cng',
                                    'hybrid':'híbrido', 'elektro':'electrico', 'andere':'otros'}

# %%
for category in categorical_type_fuel:
    bool_fuel = auto_clean['fuel_type'] == category
    auto_clean.loc[bool_fuel,'fuel_type'] = categorical_type_fuel_translator[category]

# %%
auto_clean['fuel_type'].value_counts()
# Out:
# gasolina     22913
# diesel       13571
# lpg            586
# cng             63
# híbrido         37
# electrico       17
# otros           11
# Name: fuel_type, dtype: int64

# %%
condicion_1 = auto_clean['fuel_type'] == 'híbrido' # testing hybrid category
auto_clean[condicion_1]
# Out:
#               date_crawled                                               name  \
# 1127   2016-03-10 12:06:22                  Toyota_Auris_1.8_Hybrid_Executive
# 1710   2016-03-31 19:39:57  Toyota_Yaris_Hybrid_1.5_VVT_i_Club_Panorama__A...
# 2062   2016-03-18 17:48:58  Toyota_Auris_1.8_VVT_i_Hybrid_Automatik_Tourin...
# 8128   2016-03-09 00:57:29                    Toyota_Prius__Hybrid__Executive
# 8565   2016-03-21 02:00:33                                 Lexus_400_h_Luxory
# 10325  2016-03-17 17:25:22                        Toyota_Auris_Touring_Sports
# 10724  2016-03-26 19:45:30                           Opel_Combo_zu_verkaufen!
# 10969  2016-03-14 15:53:33                  Toyota_Auris_1.8_Hybrid_Executive
# 11279  2016-04-02 18:47:48  Audi_A6_2.0_TFSI_hybrid_tiptronic__LED__Navi__...
# 12840  2016-03-22 18:52:35  Honda_civic_Hybrid_1.3i_DSI_IMA_VTEC_CVT__Navi...
# 13179  2016-03-26 20:57:29  Hustender_VW_T4_Bus_Multivan_Bulli_mit_Aufstel...
# 13949  2016-03-12 14:57:14              Toyota_Auris_1.8_VVT_i_Hyprid_Edition
# 15216  2016-03-28 14:50:12                                  Mercedes_Benz_300
# 15480  2016-03-15 11:53:18                    Toyota_Prius__Hybrid__Executive
# 17229  2016-03-26 11:52:19                         Lexus_CT_200h_Dynamic_Line
# 18017  2016-03-29 13:49:02        Mitsubishi_Outlander_2.0_4WD_Plug_In_Hybrid
# 18947  2016-03-09 14:36:20         Honda_Civic_Hybrid_1.3i_DSI_i_VTEC_IMA_CVT
# 19620  2016-03-25 19:57:35                       Lexus_CT_200h_Executive_Line
# 24209  2016-04-02 19:52:03                                      Lexus_CT_200h
# 25070  2016-03-13 20:37:36          BMW_X6_ActiveHybrid_Vollausstattung_485PS
# 26270  2016-03-18 10:48:32               Toyota_Prius___Hybrid_Benzin/Elektro
# 26482  2016-03-23 11:54:19       Honda_CR_Z_1.5_i_VTEC_Sport_50_Jahre_Edition
# 26774  2016-03-19 04:43:08  Toyota_Auris_Hybrid_Life_Top_Zustand_Garantie_...
# 27158  2016-03-29 15:55:42                    Toyota_Prius__Hybrid__Executive
# 28905  2016-03-25 12:57:52        Audi_A3_e_tron_S_line_PHEV_Werksdienstwagen
# 30349  2016-03-08 10:56:13   Auris_1.8_VVT_i_Hybrid_Automatik_Life_Plus__Navi
# 33776  2016-04-01 00:58:36  Honda_Insight_1.3_Comfort_VOLL_VOLL_F1_SCHALTU...
# 34751  2016-03-12 18:06:19                        Toyota_Auris_Touring_Sports
# 36477  2016-03-20 22:56:16                      Lexus_RX_400h__hybrid__Luxury
# 37270  2016-03-08 12:55:43                              Toyota_Prius__Hybrid_
# 37448  2016-04-04 13:58:36  Toyota_Prius__Hybrid__Executive_technisch_ohne...
# 39301  2016-03-21 21:48:03  Renault_Clio_1.2_16v_schwarz_Tuev_bis_01/2017_...
# 41723  2016-03-09 16:47:02  Honda_Civic_Hybrid_1.3i_DSI_i_VTEC_IMA_CVT_Ele...
# 42663  2016-03-10 14:36:59                         Lexus_RX_400_Hybrid_Luxery
# 43581  2016-03-23 22:37:20  Toyota_Auris_1.8_VVT_i_Hybrid_Automatik_START_...
# 46450  2016-03-12 17:37:22                           Honda_CR_Z_1.5_i_VTEC_GT
# 49975  2016-03-27 20:51:39          Honda_Jazz_1.3_DSi_i_VTEC_IMA_CVT_Comfort
#
#        seller offer_type  price_in_dollars   abtest vehicle_type  \
# 1127   privat    Angebot              9850  control        sedan
# 1710   privat    Angebot             14900  control     compacto
# 2062   privat    Angebot             19500     test     familiar
# 8128   privat    Angebot              8999     test        sedan
# 8565   privat    Angebot             11900     test          suv
# 10325  privat    Angebot             15500     test     familiar
# 10724  privat    Angebot              2000  control          NaN
# 10969  privat    Angebot              7950  control        sedan
# 11279  privat    Angebot             28500  control        sedan
# 12840  privat    Angebot              5999  control        sedan
# 13179  privat    Angebot              2700  control  monovolumen
# 13949  privat    Angebot             17400     test        sedan
# 15216  privat    Angebot             30500     test        sedan
# 15480  privat    Angebot              6200     test        sedan
# 17229  privat    Angebot             19600  control        sedan
# 18017  privat    Angebot             34500  control        sedan
# 18947  privat    Angebot              5500     test        sedan
# 19620  privat    Angebot             17999     test        sedan
# 24209  privat    Angebot             13999  control        sedan
# 25070  privat    Angebot             48999  control          suv
# 26270  privat    Angebot             10900  control        sedan
# 26482  privat    Angebot             11799     test        coupe
# 26774  privat    Angebot              9990     test        sedan
# 27158  privat    Angebot             11800  control        sedan
# 28905  privat    Angebot             37900     test     familiar
# 30349  privat    Angebot             16900     test     compacto
# 33776  privat    Angebot              5300     test        sedan
# 34751  privat    Angebot             17999     test     familiar
# 36477  privat    Angebot             12500     test          suv
# 37270  privat    Angebot             11690     test        sedan
# 37448  privat    Angebot              5850  control        sedan
# 39301  privat    Angebot              1650  control     compacto
# 41723  privat    Angebot              6950     test        sedan
# 42663  privat    Angebot             12500     test          suv
# 43581  privat    Angebot             14890     test        sedan
# 46450  privat    Angebot              9990     test        coupe
# 49975  privat    Angebot              9700  control     compacto
#
#        registration_year    gearbox   CV        model  odometer_km  \
# 1127                2010  automatik  136        auris       100000
# 1710                2014  automatik   75        yaris        20000
# 2062                2014  automatik   99        auris        50000
# 8128                2006  automatik   77       andere        30000
# 8565                2005  automatik  200          NaN       150000
# 10325               2013  automatik   99        auris        30000
# 10724               2016    manuell   90        combo       150000
# 10969               2011  automatik   99        auris       150000
# 11279               2012  automatik  211           a6        50000
# 12840               2009  automatik   95        civic       150000
# 13179               1993    manuell  110  transporter       150000
# 13949               2014  automatik   99        auris        40000
# 15216               2013  automatik  204     e_klasse        80000
# 15480               2006  automatik   77       andere       150000
# 17229               2011  automatik  136          NaN        70000
# 18017               2014        NaN  121    outlander        20000
# 18947               2006  automatik   95        civic        50000
# 19620               2012  automatik   99          NaN        40000
# 24209               2011  automatik   99          NaN       100000
# 25070               2010  automatik  485      x_reihe        60000
# 26270               2009  automatik  136       andere        90000
# 26482               2011    manuell  114     cr_reihe        80000
# 26774               2011  automatik  136        auris       100000
# 27158               2009  automatik   99       andere        90000
# 28905               2015  automatik  150           a3        20000
# 30349               2013  automatik  136        auris        50000
# 33776               2009  automatik   88       andere       100000
# 34751               2014  automatik  136        auris        30000
# 36477               2005  automatik  211          NaN       150000
# 37270               2011  automatik   99       andere       125000
# 37448               2005  automatik   77       andere       150000
# 39301               2002    manuell   75         clio       150000
# 41723               2008  automatik   90        civic        60000
# 42663               2004  automatik  211          NaN       150000
# 43581               2013  automatik   99        auris        30000
# 46450               2012    manuell  114     cr_reihe        70000
# 49975               2012  automatik   88         jazz       100000
#
#        registration_month fuel_type           brand unrepaired_damage  \
# 1127                    9   híbrido          toyota              nein
# 1710                    5   híbrido          toyota              nein
# 2062                    4   híbrido          toyota              nein
# 8128                   10   híbrido          toyota              nein
# 8565                    9   híbrido  sonstige_autos              nein
# 10325                   7   híbrido          toyota              nein
# 10724                  10   híbrido            opel               NaN
# 10969                   4   híbrido          toyota              nein
# 11279                   5   híbrido            audi              nein
# 12840                   5   híbrido           honda               NaN
# 13179                   7   híbrido      volkswagen               NaN
# 13949                  10   híbrido          toyota              nein
# 15216                  11   híbrido   mercedes_benz              nein
# 15480                   5   híbrido          toyota              nein
# 17229                   4   híbrido  sonstige_autos              nein
# 18017                   8   híbrido      mitsubishi              nein
# 18947                   5   híbrido           honda              nein
# 19620                  12   híbrido  sonstige_autos              nein
# 24209                   4   híbrido  sonstige_autos              nein
# 25070                   6   híbrido             bmw              nein
# 26270                   9   híbrido          toyota              nein
# 26482                  11   híbrido           honda              nein
# 26774                   8   híbrido          toyota              nein
# 27158                   6   híbrido          toyota              nein
# 28905                   1   híbrido            audi              nein
# 30349                  11   híbrido          toyota              nein
# 33776                  12   híbrido           honda              nein
# 34751                   1   híbrido          toyota              nein
# 36477                   9   híbrido  sonstige_autos              nein
# 37270                   2   híbrido          toyota              nein
# 37448                   8   híbrido          toyota              nein
# 39301                   8   híbrido         renault               NaN
# 41723                   3   híbrido           honda              nein
# 42663                  10   híbrido  sonstige_autos              nein
# 43581                   5   híbrido          toyota              nein
# 46450                   2   híbrido           honda              nein
# 49975                  11   híbrido           honda              nein
#
#                 ad_created  nr_pictures  postal_code            last_seen
# 1127   2016-03-10 00:00:00            0        56637  2016-04-05 20:46:24
# 1710   2016-03-31 00:00:00            0        85757  2016-04-06 13:45:27
# 2062   2016-03-18 00:00:00            0        53894  2016-04-03 21:45:15
# 8128   2016-03-08 00:00:00            0        70188  2016-04-07 05:15:53
# 8565   2016-03-21 00:00:00            0        66679  2016-04-03 23:45:00
# 10325  2016-03-17 00:00:00            0        65197  2016-03-23 17:50:52
# 10724  2016-03-26 00:00:00            0        26624  2016-04-06 09:17:48
# 10969  2016-03-14 00:00:00            0        10589  2016-03-17 04:17:12
# 11279  2016-04-02 00:00:00            0        90443  2016-04-06 18:45:57
# 12840  2016-03-22 00:00:00            0        59075  2016-03-22 19:42:37
# 13179  2016-03-26 00:00:00            0        12059  2016-03-26 20:57:29
# 13949  2016-03-12 00:00:00            0        97289  2016-03-15 00:45:56
# 15216  2016-03-28 00:00:00            0        91301  2016-04-06 19:16:25
# 15480  2016-03-15 00:00:00            0        80992  2016-03-23 19:44:28
# 17229  2016-03-26 00:00:00            0        83022  2016-04-05 23:17:09
# 18017  2016-03-29 00:00:00            0        24976  2016-04-05 23:17:23
# 18947  2016-03-09 00:00:00            0         9603  2016-03-11 10:46:13
# 19620  2016-03-25 00:00:00            0        12305  2016-04-07 03:16:33
# 24209  2016-04-02 00:00:00            0        54516  2016-04-06 20:17:20
# 25070  2016-03-13 00:00:00            0        48143  2016-04-06 18:46:04
# 26270  2016-03-18 00:00:00            0        83404  2016-04-05 22:16:26
# 26482  2016-03-23 00:00:00            0        49451  2016-04-05 11:49:08
# 26774  2016-03-18 00:00:00            0        83308  2016-04-06 02:15:34
# 27158  2016-03-29 00:00:00            0        84513  2016-04-06 01:44:54
# 28905  2016-03-25 00:00:00            0        85049  2016-04-06 15:44:40
# 30349  2016-03-08 00:00:00            0        81829  2016-04-07 08:15:21
# 33776  2016-04-01 00:00:00            0        45883  2016-04-01 06:52:59
# 34751  2016-03-12 00:00:00            0        35756  2016-03-20 21:16:00
# 36477  2016-03-20 00:00:00            0        66679  2016-04-07 11:17:05
# 37270  2016-03-08 00:00:00            0        12249  2016-04-05 16:44:44
# 37448  2016-04-04 00:00:00            0        30559  2016-04-06 15:46:07
# 39301  2016-03-21 00:00:00            0        28325  2016-03-24 11:44:37
# 41723  2016-03-09 00:00:00            0        14776  2016-04-07 05:45:28
# 42663  2016-03-10 00:00:00            0        56073  2016-04-06 07:16:17
# 43581  2016-03-23 00:00:00            0         2977  2016-04-06 13:17:24
# 46450  2016-03-12 00:00:00            0        51465  2016-04-07 08:45:11
# 49975  2016-03-27 00:00:00            0        84385  2016-04-05 19:45:34

# %% [markdown]
# ### 9.2 Convert dates into numerical data.

# %%
auto_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39224 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date_crawled        39224 non-null  object
#  1   name                39224 non-null  object
#  2   seller              39224 non-null  object
#  3   offer_type          39224 non-null  object
#  4   price_in_dollars    39224 non-null  int64
#  5   abtest              39224 non-null  object
#  6   vehicle_type        37742 non-null  object
#  7   registration_year   39224 non-null  int64
#  8   gearbox             37852 non-null  object
#  9   CV                  39224 non-null  int64
#  10  model               37688 non-null  object
#  11  odometer_km         39224 non-null  int64
#  12  registration_month  39224 non-null  int64
#  13  fuel_type           37198 non-null  object
#  14  brand               39224 non-null  object
#  15  unrepaired_damage   33572 non-null  object
#  16  ad_created          39224 non-null  object
#  17  nr_pictures         39224 non-null  int64
#  18  postal_code         39224 non-null  int64
#  19  last_seen           39224 non-null  object
# dtypes: int64(7), object(13)
# memory usage: 6.3+ MB

# %%
replace_columns = ['date_crawled', 'ad_created', 'last_seen']

for column in replace_columns:
    auto_clean[column] = auto_clean[column].str[:10]
    auto_clean[column] = auto_clean[column].str.replace('-','')

# %%
auto_clean
# Out:
#       date_crawled                                               name  seller  \
# 0         20160326                   Peugeot_807_160_NAVTECH_ON_BOARD  privat
# 1         20160404         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik  privat
# 2         20160326                         Volkswagen_Golf_1.6_United  privat
# 3         20160312  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...  privat
# 4         20160401  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...  privat
# ...            ...                                                ...     ...
# 49995     20160327   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon  privat
# 49996     20160328  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...  privat
# 49997     20160402                     Fiat_500_C_1.2_Dualogic_Lounge  privat
# 49998     20160308                 Audi_A3_2.0_TDI_Sportback_Ambition  privat
# 49999     20160314                                Opel_Vectra_1.6_16V  privat
#
#       offer_type  price_in_dollars   abtest vehicle_type  registration_year  \
# 0        Angebot              5000  control  monovolumen               2004
# 1        Angebot              8500  control        sedan               1997
# 2        Angebot              8990     test        sedan               2009
# 3        Angebot              4350  control     compacto               2007
# 4        Angebot              1350     test     familiar               2003
# ...          ...               ...      ...          ...                ...
# 49995    Angebot             24900  control        sedan               2011
# 49996    Angebot              1980  control       cabrio               1996
# 49997    Angebot             13200     test       cabrio               2014
# 49998    Angebot             22900  control     familiar               2013
# 49999    Angebot              1250  control        sedan               1996
#
#          gearbox   CV   model  odometer_km  registration_month fuel_type  \
# 0        manuell  158  andere       150000                   3       lpg
# 1      automatik  286     7er       150000                   6  gasolina
# 2        manuell  102    golf        70000                   7  gasolina
# 3      automatik   71  fortwo        70000                   6  gasolina
# 4        manuell    0   focus       150000                   7  gasolina
# ...          ...  ...     ...          ...                 ...       ...
# 49995  automatik  239      q5       100000                   1    diesel
# 49996    manuell   75   astra       150000                   5  gasolina
# 49997  automatik   69     500         5000                  11  gasolina
# 49998    manuell  150      a3        40000                  11    diesel
# 49999    manuell  101  vectra       150000                   1  gasolina
#
#             brand unrepaired_damage ad_created  nr_pictures  postal_code  \
# 0         peugeot              nein   20160326            0        79588
# 1             bmw              nein   20160404            0        71034
# 2      volkswagen              nein   20160326            0        35394
# 3           smart              nein   20160312            0        33729
# 4            ford              nein   20160401            0        39218
# ...           ...               ...        ...          ...          ...
# 49995        audi              nein   20160327            0        82131
# 49996        opel              nein   20160328            0        44807
# 49997        fiat              nein   20160402            0        73430
# 49998        audi              nein   20160308            0        35683
# 49999        opel              nein   20160313            0        45897
#
#       last_seen
# 0      20160406
# 1      20160406
# 2      20160406
# 3      20160315
# 4      20160401
# ...         ...
# 49995  20160401
# 49996  20160402
# 49997  20160404
# 49998  20160405
# 49999  20160406
#
# [39224 rows x 20 columns]

# %%
all_brands= auto_clean['brand'].unique()
sorted(all_brands)
# Out:
# ['alfa_romeo',
#  'audi',
#  'bmw',
#  'chevrolet',
#  'chrysler',
#  'citroen',
#  'dacia',
#  'daewoo',
#  'daihatsu',
#  'fiat',
#  'ford',
#  'honda',
#  'hyundai',
#  'jaguar',
#  'jeep',
#  'kia',
#  'lada',
#  'lancia',
#  'land_rover',
#  'mazda',
#  'mercedes_benz',
#  'mini',
#  'mitsubishi',
#  'nissan',
#  'opel',
#  'peugeot',
#  'porsche',
#  'renault',
#  'rover',
#  'saab',
#  'seat',
#  'skoda',
#  'smart',
#  'sonstige_autos',
#  'subaru',
#  'suzuki',
#  'toyota',
#  'trabant',
#  'volkswagen',
#  'volvo']

# %% [markdown]
# ### 9.3 Find the most common make/model combinations
#
# The top three brands on our list also have their own favourite models, as can be seen below.

# %%
def combi_marca_modelo(marca):
    bool_fiat = auto_clean['brand'] == marca 
    print(auto_clean.loc[bool_fiat,'model'].value_counts()[:5]) # top 5

# %%
combi_marca_modelo('audi')
# Out:
# a4        1125
# a3         788
# a6         771
# andere     212
# tt         144
# Name: model, dtype: int64

# %%
combi_marca_modelo('mercedes_benz')
# Out:
# c_klasse    1064
# e_klasse     911
# a_klasse     476
# andere       423
# clk          236
# Name: model, dtype: int64

# %%
combi_marca_modelo('bmw')
# Out:
# 3er        2353
# 5er        1083
# 1er         512
# x_reihe     296
# 7er         124
# Name: model, dtype: int64

# %%
def combi_marca_modelo_top(marca):
    bool_fiat = auto_clean['brand'] == marca
    return auto_clean.loc[bool_fiat,'model'][0:1].max()
    #return auto_clean[bool_fiat]

# %%
marc_modelo = {}

for brand in sorted(all_brands):
    marc_modelo[brand] = combi_marca_modelo_top(brand)

marc_modelo = pd.Series(marc_modelo)
marc_modelo
# Out:
# alfa_romeo               156
# audi                      a3
# bmw                      7er
# chevrolet             andere
# chrysler             voyager
# citroen             berlingo
# dacia                sandero
# daewoo                nubira
# daihatsu              terios
# fiat                  andere
# ford                   focus
# honda                  civic
# hyundai              i_reihe
# jaguar                andere
# jeep                wrangler
# kia                 carnival
# lada                     NaN
# lancia                 lybra
# land_rover        freelander
# mazda                 andere
# mercedes_benz       e_klasse
# mini                  cooper
# mitsubishi              colt
# nissan               primera
# opel                  andere
# peugeot               andere
# porsche                  911
# renault                 clio
# rover                 andere
# saab                  andere
# seat                   altea
# skoda                octavia
# smart                 fortwo
# sonstige_autos           NaN
# subaru                andere
# suzuki                 grand
# toyota                andere
# trabant                  NaN
# volkswagen              golf
# volvo                 andere
# dtype: object

# %% [markdown]
# ### Model within each brand that is repeated more times within our data set, the order is given by the brand of the vehicle.

# %% [markdown]
# ### 9.4 Divide the odometer into groups
#
# Use aggregation to see if the prices follow any pattern in mileage.

# %%
km_group = auto_clean['odometer_km'].value_counts()
km_group
# Out:
# 150000    23990
# 125000     4362
# 100000     1875
# 90000      1555
# 80000      1319
# 70000      1142
# 60000      1082
# 50000       971
# 40000       781
# 30000       733
# 20000       692
# 5000        502
# 10000       220
# Name: odometer_km, dtype: int64

# %%
km_group = auto_clean['odometer_km'].value_counts().index[:]

# %%
price_group = auto_clean['price_in_dollars'].value_counts().index[:]
price_group
# Out:
# Int64Index([  1500,   2500,   1200,   1000,   3500,   2000,    999,    850,
#               4500,    900,
#             ...
#              34940,  12395,  25590,   4111,   1996, 169000,   5998,   3949,
#               3195,  10830],
#            dtype='int64', length=2110)

# %%
avg_price_by_km_non_damage = {}

for km in km_group:
    selected_km = auto_clean[auto_clean['odometer_km'] == km ]
    mean = selected_km['price_in_dollars'].mean().round()
    combined = mean
    avg_price_by_km_non_damage[km] = combined

# %%
avg_price_by_km_non_damage
# Out:
# {150000: 4601.0,
#  125000: 6864.0,
#  100000: 9150.0,
#  90000: 9070.0,
#  80000: 10115.0,
#  70000: 11341.0,
#  60000: 12893.0,
#  50000: 15455.0,
#  40000: 15808.0,
#  30000: 17205.0,
#  20000: 19753.0,
#  5000: 21454.0,
#  10000: 22487.0}

# %%
avg_price_by_km = {}

for km in km_group:
    selected_km = auto_clean[auto_clean['odometer_km'] == km ]
    mean = selected_km['price_in_dollars'].mean().round()
    vehiculos = selected_km['price_in_dollars'].value_counts(normalize = True, sort = True)
    combined = (mean, vehiculos)
    avg_price_by_km[km] = combined

# %%
avg_price_by_km
# Out:
# {150000: (4601.0,
#   1500     0.023927
#   1200     0.021217
#   1000     0.021092
#   2500     0.018799
#   2000     0.014548
#              ...
#   2580     0.000042
#   69993    0.000042
#   18940    0.000042
#   2410     0.000042
#   32800    0.000042
#   Name: price_in_dollars, Length: 1287, dtype: float64),
#  125000: (6864.0,
#   2500     0.016277
#   3500     0.012838
#   4500     0.011463
#   2000     0.009858
#   1500     0.009629
#              ...
#   8850     0.000229
#   12980    0.000229
#   29400    0.000229
#   45800    0.000229
#   28900    0.000229
#   Name: price_in_dollars, Length: 775, dtype: float64),
#  100000: (9150.0,
#   6500      0.011200
#   2500      0.011200
#   1500      0.010667
#   1200      0.010133
#   2900      0.009600
#               ...
#   15200     0.000533
#   17250     0.000533
#   875       0.000533
#   27500     0.000533
#   299000    0.000533
#   Name: price_in_dollars, Length: 599, dtype: float64),
#  90000: (9070.0,
#   2500     0.016077
#   3500     0.014148
#   5500     0.011576
#   3800     0.008360
#   10500    0.007717
#              ...
#   7299     0.000643
#   7650     0.000643
#   23700    0.000643
#   25750    0.000643
#   2050     0.000643
#   Name: price_in_dollars, Length: 567, dtype: float64),
#  80000: (10115.0,
#   9500     0.013647
#   3500     0.011372
#   4500     0.010614
#   13000    0.009856
#   4800     0.009098
#              ...
#   15890    0.000758
#   870      0.000758
#   3550     0.000758
#   27499    0.000758
#   99900    0.000758
#   Name: price_in_dollars, Length: 553, dtype: float64),
#  70000: (11341.0,
#   3500     0.015762
#   4500     0.010508
#   5000     0.009632
#   7000     0.009632
#   8900     0.008757
#              ...
#   24200    0.000876
#   23490    0.000876
#   19399    0.000876
#   19400    0.000876
#   14590    0.000876
#   Name: price_in_dollars, Length: 508, dtype: float64),
#  60000: (12893.0,
#   10500    0.012015
#   5500     0.010166
#   22500    0.010166
#   13500    0.010166
#   14000    0.009242
#              ...
#   21450    0.000924
#   23499    0.000924
#   990      0.000924
#   44000    0.000924
#   38900    0.000924
#   Name: price_in_dollars, Length: 498, dtype: float64),
#  50000: (15455.0,
#   14500    0.012358
#   7500     0.012358
#   5500     0.011329
#   13500    0.011329
#   5900     0.010299
#              ...
#   3600     0.001030
#   7699     0.001030
#   7700     0.001030
#   9750     0.001030
#   32490    0.001030
#   Name: price_in_dollars, Length: 489, dtype: float64),
#  40000: (15808.0,
#   7900     0.014085
#   7500     0.012804
#   10500    0.012804
#   17500    0.010243
#   15500    0.008963
#              ...
#   13899    0.001280
#   4690     0.001280
#   24150    0.001280
#   12888    0.001280
#   12290    0.001280
#   Name: price_in_dollars, Length: 430, dtype: float64),
#  30000: (17205.0,
#   13500    0.013643
#   19500    0.010914
#   10000    0.010914
#   15500    0.008186
#   8500     0.008186
#              ...
#   6799     0.001364
#   14995    0.001364
#   36500    0.001364
#   12950    0.001364
#   25600    0.001364
#   Name: price_in_dollars, Length: 443, dtype: float64),
#  20000: (19753.0,
#   8500      0.013006
#   1500      0.011561
#   13900     0.010116
#   12900     0.010116
#   16000     0.008671
#               ...
#   5650      0.001445
#   345000    0.001445
#   20390     0.001445
#   37400     0.001445
#   9650      0.001445
#   Name: price_in_dollars, Length: 430, dtype: float64),
#  5000: (21454.0,
#   1500     0.043825
#   1000     0.027888
#   900      0.019920
#   2800     0.017928
#   2500     0.017928
#              ...
#   17695    0.001992
#   14900    0.001992
#   64280    0.001992
#   1299     0.001992
#   12800    0.001992
#   Name: price_in_dollars, Length: 265, dtype: float64),
#  10000: (22487.0,
#   7800     0.018182
#   19900    0.018182
#   13800    0.013636
#   10500    0.013636
#   13900    0.013636
#              ...
#   40900    0.004545
#   43900    0.004545
#   32150    0.004545
#   14999    0.004545
#   12800    0.004545
#   Name: price_in_dollars, Length: 181, dtype: float64)}

# %% [markdown]
# a car with 150,000 km and worth that much money...(¿?)

# %%
auto_clean[auto_clean['price_in_dollars'] == 69993]
# Out:
#       date_crawled               name  seller offer_type  price_in_dollars  \
# 41891     20160308  Porsche_993_Targa  privat    Angebot             69993
#
#         abtest vehicle_type  registration_year    gearbox   CV model  \
# 41891  control        coupe               1996  automatik  286   911
#
#        odometer_km  registration_month fuel_type    brand unrepaired_damage  \
# 41891       150000                   5  gasolina  porsche              nein
#
#       ad_created  nr_pictures  postal_code last_seen
# 41891   20160308            0         1445  20160407

# %% [markdown]
# Clearly it is not an outlyer. 😅

# %% [markdown]
# ### 9.4 How much cheaper are damaged cars than their undamaged counterparts?
#
# we retrieved the dictionary we had made called the 'avg_price_by_km_non_damage' and we create another dictionary that compiles those vehicles that are indeed damaged.

# %%
avg_price_by_km_damage = {}

for km in km_group:
    selected_km = auto_clean[(auto_clean['odometer_km'] == km) &
                             (auto_clean['unrepaired_damage'] == 'ja') ]
    mean = selected_km['price_in_dollars'].mean()
    avg_price_by_km_damage[km] = mean.round()

# %%
avg_price_by_km_damage
# Out:
# {150000: 2930.0,
#  125000: 3841.0,
#  100000: 4707.0,
#  90000: 4405.0,
#  80000: 6057.0,
#  70000: 5648.0,
#  60000: 7955.0,
#  50000: 9357.0,
#  40000: 13433.0,
#  30000: 6899.0,
#  20000: 7706.0,
#  5000: 3289.0,
#  10000: 4566.0}

# %%
series_nondamage = pd.Series(avg_price_by_km_non_damage) 
df_nondamage = pd.DataFrame(series_nondamage)
df_nondamage = df_nondamage.rename(columns = {0:'price_not_damage'})

series_damage = pd.Series(avg_price_by_km_damage)
df_damage = pd.DataFrame(series_damage)
df_damage = df_damage.rename(columns = {0:'price_damage'})

series_diference = series_nondamage - series_damage
df_diference = pd.DataFrame(series_diference)
df_diference = df_diference.rename(columns = {0:'price_difference'})

series_diference_percent = (series_damage * 100) / series_nondamage.round(2)
df_diference_percent = pd.DataFrame(series_diference_percent)
df_diference_percent = df_diference_percent.rename(columns = {0:'%difference_damage_notdamage '})


df = pd.concat([df_nondamage, df_damage, df_diference, df_diference_percent], axis = 1)
df
# Out:
#         price_not_damage  price_damage  price_difference  \
# 150000            4601.0        2930.0            1671.0
# 125000            6864.0        3841.0            3023.0
# 100000            9150.0        4707.0            4443.0
# 90000             9070.0        4405.0            4665.0
# 80000            10115.0        6057.0            4058.0
# 70000            11341.0        5648.0            5693.0
# 60000            12893.0        7955.0            4938.0
# 50000            15455.0        9357.0            6098.0
# 40000            15808.0       13433.0            2375.0
# 30000            17205.0        6899.0           10306.0
# 20000            19753.0        7706.0           12047.0
# 5000             21454.0        3289.0           18165.0
# 10000            22487.0        4566.0           17921.0
#
#         %difference_damage_notdamage
# 150000                      63.681808
# 125000                      55.958625
# 100000                      51.442623
# 90000                       48.566703
# 80000                       59.881364
# 70000                       49.801605
# 60000                       61.700147
# 50000                       60.543513
# 40000                       84.975962
# 30000                       40.098808
# 20000                       39.011796
# 5000                        15.330475
# 10000                       20.305065

# %% [markdown]
# ## Conclusions
#
# The conclusions we can draw from our study are several:
#
#  1. The 75% of the vehicles for sale have an average mileage of about 150,000 km and if we count the vehicles with a minimum selling price of 850 we have that 75% of the total have an average price of 8750.
#
#  2. Once we have corrected the values we have that our 75% of the vehicles were registered in 2008 and that most of the registrations were between the period 2002 / 2007.
#
#  3. The most offered vehicle brand is Volkswagen.
#
#  4. The highest average price belongs to Audi, then Mercedes and finally to BMW.
#
#  5. The average number of kilometers per brand is led by BMW followed by Mercedes and Audi.
#
#  6. most of the vehicles are sedan type and are gasoline cars followed by diesel and lpg cars.
#
#
# Taking into account the order of average price per vehicle brand
# we know that the most repeated per model is:
#
#    - Audi with A4 followed by the A3 and A6.
#
#    - Mercedes the  C Class followed E Class and the A Class.
#
#    - BMW with the 3 Series, the 5 Series in second place and the 1 Series in third place .
#
#
# Finally we can see the differences between the price kilometer of the damaged and non-damaged cars and we observe that the biggest difference in price is given in vehicles with 40000 Kilometers 150000Km and 60000Km.

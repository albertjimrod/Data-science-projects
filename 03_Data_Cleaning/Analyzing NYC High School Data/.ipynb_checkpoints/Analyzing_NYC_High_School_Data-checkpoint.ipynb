# %% [markdown]
# https://app.dataquest.io/c/25/m/136/data-cleaning-walkthrough

# %%
! ls -l
# Out:
# total 52
# -rw-rw-r-- 1 ion ion 41689 jul  7 08:56 Analyzing_NYC_High_School_Data.ipynb
# -rw-rw-r-- 1 ion ion    15 jul  7 08:56 README.md
# drwxrwxr-x 2 ion ion  4096 jul  7 08:56 schools

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import re

data_files = [
    "ap_2010.csv",
    "class_size.csv",
    "demographics.csv",
    "graduation.csv",
    "hs_directory.csv",
    "sat_results.csv"
]

data = {}
# data content into dictionary

for f in data_files:
    datum = pd.read_csv("schools/{0}".format(f))
    data[f.replace(".csv","")] = datum
    
data
# Out:
# {'ap_2010':         DBN                                         SchoolName  \
#  0    01M448                       UNIVERSITY NEIGHBORHOOD H.S.
#  1    01M450                             EAST SIDE COMMUNITY HS
#  2    01M515                                LOWER EASTSIDE PREP
#  3    01M539                     NEW EXPLORATIONS SCI,TECH,MATH
#  4    02M296              High School of Hospitality Management
#  ..      ...                                                ...
#  253  31R605                         STATEN ISLAND TECHNICAL HS
#  254  32K545                      EBC-HS FOR PUB SERVICE (BUSH)
#  255  32K552                          Academy of Urban Planning
#  256  32K554               All City Leadership Secondary School
#  257  32K556  Bushwick Leaders High School for Academic Exce...
#
#      AP Test Takers  Total Exams Taken Number of Exams with scores 3 4 or 5
#  0                39                49                                   10
# ...

# %% [markdown]
# quiero representar un grafico bar.plot que muestre la correlacion entre esos campos y `sat_score`

# %%
data.keys()
# Out:
# dict_keys(['ap_2010', 'class_size', 'demographics', 'graduation', 'hs_directory', 'sat_results'])

# %%
data['ap_2010']
# Out:
#         DBN                                         SchoolName  \
# 0    01M448                       UNIVERSITY NEIGHBORHOOD H.S.
# 1    01M450                             EAST SIDE COMMUNITY HS
# 2    01M515                                LOWER EASTSIDE PREP
# 3    01M539                     NEW EXPLORATIONS SCI,TECH,MATH
# 4    02M296              High School of Hospitality Management
# ..      ...                                                ...
# 253  31R605                         STATEN ISLAND TECHNICAL HS
# 254  32K545                      EBC-HS FOR PUB SERVICE (BUSH)
# 255  32K552                          Academy of Urban Planning
# 256  32K554               All City Leadership Secondary School
# 257  32K556  Bushwick Leaders High School for Academic Exce...
#
#     AP Test Takers  Total Exams Taken Number of Exams with scores 3 4 or 5
# 0                39                49                                   10
# ...

# %% [markdown]
# no puedo hacerlo porque los datos son  de tipo cadena de texto y debo convertirlos al tipo que toca además debo comprobar que no me falte nada.
